# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('behavioral - incorrect scan')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

word_list_1=('front door','frontdoor')
word_list_2=('rear door','reardoor')

word_list_3=('step','apartment building','apartment office','car','clubhouse','drainage ditch','driveway','fence','front entrance','garage','garbage',
    'garbage can','gate','hallway','hill','hours later','house','lawn','locker','mail box','mail room',
    'mailbox','road','side walk','sidewalk','staircase','street','trash','unsafe location')

df['attribute_1'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list_1)),expand=False).str.lower()
df['attribute_2'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list_2)),expand=False).str.lower()
df['attribute_3'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list_3)),expand=False).str.lower()

# df['Status_1']=df['Additional_Details_Data'].str.contains('as delivered before doing the delivery|driver left the package at the front door but driver marked the package as delivered to rear door')



df['Status']=df['Additional_Details_Data'].str.contains('step|not a business address|mailroom|road|hours later|street|lawn|unsafe location|sidewalk|hill|staircase|house|fence|mail room|hallway|garbage|apartment office|front entrance|hallway|side walk|apartment building|clubhouse|driveway|garbage can|drainage ditch|mail box|gate|garage|car|locker|mailbox|trash')



df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Behavioral - Incorrect Scan.csv',index = False)
df
# Out:
#         ShortId                                            details  \
# 9     305223253  ****Station submitted TTs will need to have da...
# 10    305254339  Delivery Station (Station Code, City, State): ...
# 16    305926593  Delivery Station (Station Code, City, State): ...
# 38    305982759  Delivery Station (Station Code, City, State): ...
# 52    306037816  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6819  305741974  Delivery Station (Station Code, City, State): ...
# 6830  305396738  Delivery Station (Station Code, City, State): ...
# 6852  423523554  Delivery Station (Station Code, City, State): ...
# 6854  306193107  Copy and paste the Amazon Flex delivery partne...
# 6865  304786672  Delivery Station (Station Code, City, State): ...
#
#                             root_cause              tid  \
# 9     t2 - behavioral - incorrect scan              NaN
# ...
