# %%
import pandas as pd
import numpy as np

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df1 = df1[df1['root_cause'] == 'duplicate']
df1['Data']=df1['Data'].apply(lambda st: st[st.find("https://tt"):])
df1['Data']=df1['Data'].apply(lambda x: x[:32])

df1['inside_caseid']=df1['Data'].apply(lambda st: st[st.find("com/")+4:])
df1 = df1.rename(columns = {"case_id": "ShortId"}) 
df1.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_duplicate_t1.csv', index = False)

df1
# Out:
#         ShortId                                            details root_cause  \
# 23    425870687  Delivery Station (Station Code, City, State): ...  duplicate
# 40    425889886  Delivery Station (Station Code, City, State): ...  duplicate
# 91    425839677  Delivery Station (Station Code, City, State): ...  duplicate
# 127   425901953  Delivery Station (Station Code, City, State): ...  duplicate
# 159   425884328  Delivery Station (Station Code, City, State): ...  duplicate
# ...         ...                                                ...        ...
# 1755  310210723  Delivery Station (Station Code, City, State): ...  duplicate
# 1789  310232453  Delivery Station (Station Code, City, State): ...  duplicate
# 1809  310201761  Delivery Station (Station Code, City, State): ...  duplicate
# 1821  310210805  Delivery Station (Station Code, City, State): ...  duplicate
# 1833  310231852  Delivery Station (Station Code, City, State): ...  duplicate
#
#                   tid                              Data  \
# 23    TBA148867574000  https://tt.amazon.com/0425875106
# 40    TBA177967441000  https://tt.amazon.com/0425890277
# 91    TBA146447925000  https://tt.amazon.com/0425839990
# 127   TBA186972316000  https://tt.amazon.com/0425901364
# 159   TBA183570455000  https://tt.amazon.com/0425889544
# ...               ...                               ...
# 1755  TBA000558708401  https://tt.amazon.com/0310208166
# 1789  TBA201430491000  https://tt.amazon.com/0310204979
# 1809  TBA000830088901  https://tt.amazon.com/0310203228
# 1821  TBA000653963201  https://tt.amazon.com/0310210317
# 1833  TBA000948799301  https://tt.amazon.com/0310230299
#
#                                              Infraction Additional_Details  \
# 23      as duplicate of https://tt.amazon.com/042587510                NaN
# 40      as duplicate of https://tt.amazon.com/042589027                NaN
# 91      as duplicate of https://tt.amazon.com/042583999                NaN
# 127                  of:https://tt.amazon.com/042590136                NaN
# 159   as duplicate of  :https://tt.amazon.com/042588954                NaN
# ...                                                 ...                ...
# 1755  as duplicate of : https://tt.amazon.com/031020816                NaN
# 1789    as duplicate of https://tt.amazon.com/031020497                NaN
# 1809    as duplicate of https://tt.amazon.com/031020322                NaN
# 1821    as duplicate of https://tt.amazon.com/031021031                NaN
# 1833    as duplicate of https://tt.amazon.com/031023029                NaN
#
#      Infraction1 Infraction2 First_Status inside_caseid
# 23           NaN         NaN           NS    0425875106
# 40           NaN         NaN           NS    0425890277
# 91           NaN         NaN           NS    0425839990
# 127          NaN         NaN           NS    0425901364
# 159          NaN         NaN           NS    0425889544
# ...          ...         ...          ...           ...
# 1755         NaN         NaN           NS    0310208166
# 1789         NaN         NaN           NS    0310204979
# 1809         NaN         NaN           NS    0310203228
# 1821         NaN         NaN           NS    0310210317
# 1833         NaN         NaN           NS    0310230299
#
# [86 rows x 11 columns]

# %%
# df1['inside_caseid']=df1['Data'].apply(lambda st: st[st.find("com/")+5:])
# df2 = df2.rename(columns = {"case_id": "ShortId"}) 
# # df1["inside_caseid"] = pd.to_numeric(df1["inside_caseid"],errors='coerce')
# df1["inside_caseid"] =df1["inside_caseid"].fillna('No data available')

# # df1["inside_caseid"]=df1["inside_caseid"].astype(int).astype(str)
# df1.to_csv(r'C:\Users\majidmm\Documents\MTI\duplicate_t1.csv', index = False)
# # df1.dropna()
# df1

# %%
df2=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_duplicate_t1.csv')
df2 = df2.rename(columns = {"inside_caseid":"case_id"}) 

df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\audit_query.csv',usecols=('case_id','details','root_cause','tid'),encoding='ISO-8859-1')
# df3 = df3[df3['root_cause'] == 'Duplicate']


df2["case_id"] = pd.to_numeric(df2["case_id"],errors='coerce')
df3["case_id"] = pd.to_numeric(df3["case_id"],errors='coerce')

df4=df2.merge(df3,on='case_id',how='left')
# df6=pd.concat([df2, df3],join="inner")
df4['details_x']=df4['details_x'].astype(str)

df4['details_y']=df4['details_y'].astype(str)

df4['DAID_1']=df4['details_x'].apply(lambda st: st[st.find("(Transporter ID):")+17:st.find("Zip code of occurrence")])
df4['DAID_2']=df4['details_y'].apply(lambda st: st[st.find("(Transporter ID):")+17:st.find("Zip code of occurrence")])



df4['tid_Status']=np.where(df4['tid_x']==df4['tid_y'],'True','False')
df4['daid_Status']=np.where(df4['DAID_1']==df4['DAID_2'],'True','False')


df4.drop_duplicates(subset ="ShortId",keep = False, inplace = True) 


df4.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_duplicate_t2.csv', index = False)
df4
# Out:
#          ShortId                                          details_x  \
# 0      425870687  Delivery Station (Station Code, City, State): ...
# 1      425889886  Delivery Station (Station Code, City, State): ...
# 2      425839677  Delivery Station (Station Code, City, State): ...
# 3      425901953  Delivery Station (Station Code, City, State): ...
# 4      425884328  Delivery Station (Station Code, City, State): ...
# ...          ...                                                ...
# 10603  310210723  Delivery Station (Station Code, City, State): ...
# 10604  310232453  Delivery Station (Station Code, City, State): ...
# 10605  310201761  Delivery Station (Station Code, City, State): ...
# 10606  310210805  Delivery Station (Station Code, City, State): ...
# 10607  310231852  Delivery Station (Station Code, City, State): ...
#
#       root_cause_x            tid_x                              Data  \
# 0        duplicate  TBA148867574000  https://tt.amazon.com/0425875106
# 1        duplicate  TBA177967441000  https://tt.amazon.com/0425890277
# 2        duplicate  TBA146447925000  https://tt.amazon.com/0425839990
# 3        duplicate  TBA186972316000  https://tt.amazon.com/0425901364
# 4        duplicate  TBA183570455000  https://tt.amazon.com/0425889544
# ...            ...              ...                               ...
# 10603    duplicate  TBA000558708401  https://tt.amazon.com/0310208166
# 10604    duplicate  TBA201430491000  https://tt.amazon.com/0310204979
# 10605    duplicate  TBA000830088901  https://tt.amazon.com/0310203228
# 10606    duplicate  TBA000653963201  https://tt.amazon.com/0310210317
# 10607    duplicate  TBA000948799301  https://tt.amazon.com/0310230299
#
#                                               Infraction  Additional_Details  \
# 0        as duplicate of https://tt.amazon.com/042587510                 NaN
# 1        as duplicate of https://tt.amazon.com/042589027                 NaN
# 2        as duplicate of https://tt.amazon.com/042583999                 NaN
# 3                     of:https://tt.amazon.com/042590136                 NaN
# 4      as duplicate of  :https://tt.amazon.com/042588954                 NaN
# ...                                                  ...                 ...
# 10603  as duplicate of : https://tt.amazon.com/031020816                 NaN
# 10604    as duplicate of https://tt.amazon.com/031020497                 NaN
# 10605    as duplicate of https://tt.amazon.com/031020322                 NaN
# 10606    as duplicate of https://tt.amazon.com/031021031                 NaN
# 10607    as duplicate of https://tt.amazon.com/031023029                 NaN
#
#        Infraction1 Infraction2 First_Status      case_id  \
# 0              NaN         NaN           NS  425875106.0
# 1              NaN         NaN           NS  425890277.0
# 2              NaN         NaN           NS  425839990.0
# 3              NaN         NaN           NS  425901364.0
# 4              NaN         NaN           NS  425889544.0
# ...            ...         ...          ...          ...
# 10603          NaN         NaN           NS  310208166.0
# 10604          NaN         NaN           NS  310204979.0
# 10605          NaN         NaN           NS  310203228.0
# 10606          NaN         NaN           NS  310210317.0
# 10607          NaN         NaN           NS  310230299.0
#
#                                                details_y  \
# 0      Delivery Station (Station Code, City, State): ...
# 1      Delivery Station (Station Code, City, State): ...
# 2      Delivery Station (Station Code, City, State): ...
# 3      Delivery Station (Station Code, City, State): ...
# 4      Who reported the incident?: Customer / Witness...
# ...                                                  ...
# 10603  Delivery Station (Station Code, City, State): ...
# 10604  Delivery Station (Station Code, City, State): ...
# 10605  Delivery Station (Station Code, City, State): ...
# 10606  Delivery Station (Station Code, City, State): ...
# 10607  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause_y            tid_y  \
# 0                                  Not a Tier Infraction  TBA148867574000
# 1                                  Not a Tier Infraction  TBA177967441000
# 2      T2 - Behavioral - Incorrectly scanned delivere...  TBA146447925000
# 3            T2 - Package Mishandling - Throwing/tossing  TBA186972316000
# 4         T2 - Unsafe driving behavior - Property Damage  TBA183570455000
# ...                                                  ...              ...
# 10603                              Not a Tier Infraction  TBA000558708401
# 10604                              Not a Tier Infraction  TBA201430491000
# 10605                              Not a Tier Infraction  TBA000830088901
# 10606                              Not a Tier Infraction  TBA000653963201
# 10607                              Not a Tier Infraction  TBA000948799301
#
#                       DAID_1  \
# 0       A1CYOCB75FHCMC
# 1         A2NDJPAX1MWBVK
# 2       A11MLOF3MZIM9M
# 3              106136388
# 4       A26G97N10AMKA9
# ...                      ...
# 10603      AKY3LZRYYXKM3
# 10604   A1GORARA6ELJ09
# 10605    AV8MU31KU4HC3
# 10606   A36PXL6SNH21VF
# 10607   A24FVSSA1SPBMH
#
#                                                   DAID_2 tid_Status  \
# 0                                   A1CYOCB75FHCMC             True
# 1                                     A2NDJPAX1MWBVK           True
# 2                                   A11MLOF3MZIM9M             True
# 3                                          106136388           True
# 4       incident?: Customer / Witness    Station Name...       True
# ...                                                  ...        ...
# 10603                                  AKY3LZRYYXKM3           True
# 10604                                         0000             True
# 10605                                AV8MU31KU4HC3             True
# 10606                               A36PXL6SNH21VF             True
# 10607                               A24FVSSA1SPBMH             True
#
#       daid_Status
# 0            True
# 1            True
# 2            True
# 3            True
# 4           False
# ...           ...
# 10603        True
# 10604       False
# 10605        True
# 10606        True
# 10607        True
#
# [84 rows x 18 columns]
