# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('not a tier')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

df['Second_Status']=df['Data'].str.contains('wrong address|dnr|no notes|no instruction|wrong location|delivery attempt|issue not a tier infraction. please resolve accordingly.|no evidence|on hold cases|please resolve as no issue|as per pod|incorrect location|notes in rclp conflict with notes in comp/psui|utl|wrong item|damaged|packaging issue|please resolve as not a tier infraction|not knocking or ringing the doorbell|wrong house|no specific instructions |did not receive|wrong package|weather|as per the pod|ring the door bell|unable to proceed with information provided|delayed at station|no delivery notes|delivered as per instructions|appeal received and approved|delivered on same day|as per comp/psui, no|item is missing|delivered to front door|as per comp, no delivery instructions|address line|no cx notes found in comp/psui|no specific delivery instructions|no proof|wrong door|address notes|didn''t knock|as per comp/psui no|left at the front door|customer did not specify|unable to locate address|wrong apartment|wrong floor|customer is not complaining about the da|wrong building|please process as no infraction')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Not a tier.csv',columns=('ShortId','tid','root_cause','Data','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId                                            details  \
# 0     306710846  Delivery Station (Station Code, City, State): ...
# 3     306718532  Delivery Station (Station Code, City, State): ...
# 4     306598879  Delivery Station (Station Code, City, State): ...
# 5     306671140  Delivery Station (Station Code, City, State): ...
# 6     306703171  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6098  306065835  Delivery Station (Station Code, City, State): ...
# 6100  306079269  Delivery Station (Station Code, City, State): ...
# 6102  305882368  Delivery Station (Station Code, City, State): ...
# 6103  305906027  Delivery Station (Station Code, City, State): ...
# 6104  305874049  Delivery Station (Station Code, City, State): ...
#
#                  root_cause              tid  \
# 0     not a tier infraction  TBA903227162000
# 3     not a tier infraction  TBA850126754000
# 4     not a tier infraction  TBA896062011000
# 5     not a tier infraction  TBA898797972000
# 6     not a tier infraction  TBA899026227000
# ...                     ...              ...
# 6098  not a tier infraction  TBA861844710000
# 6100  not a tier infraction  TBA857410563000
# 6102  not a tier infraction              NaN
# 6103  not a tier infraction  TBA846768922000
# 6104  not a tier infraction  TBA839573832000
#
#                                                    Data  \
# 0     package was delivered to front door as per cus...
# 3     delivered not received as per pod package was ...
# 4     delivered to wrong location, resolving as no i...
# 5     issue is not an infraction, package delivered ...
# 6     customer stated that the package was placed at...
# ...                                                 ...
# 6098  driver scanned 'uta',away from customer's loca...
# 6100  customer stated that the driver left the packa...
# 6102  did you consult the available (tm/rs) on the f...
# 6103  did you consult the available (tm/rs) on the f...
# 6104  delivered to wrong location resolving as no is...
#
#                                              Infraction Additional_Details  \
# 0                                                   NaN                NaN
# 3     not received as per pod package was delivered ...                NaN
# 4              to wrong location, resolving as no issue                NaN
# 5     ot an infraction, package delivered to wrong a...                NaN
# 6     tated that the package was placed at the upsat...                NaN
# ...                                                 ...                ...
# 6098  nned 'uta',away from customer's location.resol...                NaN
# 6100  tated that the driver left the package outside...                NaN
# 6102  nsult the available (tm/rs) on the floor? (y/n...                NaN
# 6103  nsult the available (tm/rs) on the floor? (y/n...                NaN
# 6104  to wrong location resolving as no issue. \r\n,...                NaN
#
#      Infraction1 Infraction2 First_Status  Second_Status
# 0            NaN         NaN           NS           True
# 3            NaN      locker           NS           True
# 4            NaN         NaN           NS           True
# 5            NaN         NaN           NS           True
# 6            NaN         NaN           NS           True
# ...          ...         ...          ...            ...
# 6098         NaN         NaN           NS          False
# 6100         NaN         NaN           NS          False
# 6102         NaN         NaN           NS           True
# 6103         NaN      locker           NS           True
# 6104         NaN      locker           NS           True
#
# [3464 rows x 11 columns]
