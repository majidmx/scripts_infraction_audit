# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('unsafe driving behavior')==True]
df=df[df['root_cause'].str.contains('unsafe driving behavior - property damage')==False]
df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

word_list=('wrong direction','drove on her lawn','drove on the yard','360 degrees turn','grass','drove on to the customer''s yard','mud','block','drove on their backyard','over 35 MPH','fly','smash','shatter','drove over','mess','cutting off traffic','drove over the customers lawn','spin','tire track','through her lawn','wrong side','drove by his front lawn','pace that was unsafe','360 in the parking','pulling in customers lawn','driving through the grass','drove on the customer lawn','rut','ran into','displace','damage','reckless','wrong way','destroy','60miles/hour','drove off our driveway sinking into our yard','fast','hit','knock','mark','speed','rush','drover over','drove off our driveway')


df['attribute'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list)),expand=False).str.lower()

df['Status']=df['Additional_Details_Data'].str.contains('wrong direction|drove on her lawn|drove on the yard|360 degrees turn|grass|drove on to the customer''s yard|mud|block|drove on their backyard|over 35 MPH|fly|smash|shatter|drove over|mess|cutting off traffic|drove over the customers lawn|spin|tire track|through her lawn|wrong side|drove by his front lawn|pace that was unsafe|360 in the parking|pulling in customers lawn|driving through the grass|drove on the customer lawn|rut|ran into|displace|damage|reckless|wrong way|destroy|60miles/hour|drove off our driveway sinking into our yard|speed|mark|hit|fast|knock|rush|drove off our driveway')

df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Unsafe driving behavior.csv',index = False)


df
# Out:
#         ShortId                                            details  \
# 66    306038534  Delivery Station (Station Code, City, State): ...
# 97    306047928  Delivery Station (Station Code, City, State): ...
# 306   305940104  Delivery Station (Station Code, City, State): ...
# 317   305935055  Delivery Station (Station Code, City, State): ...
# 329   305949510  Delivery Station (Station Code, City, State):D...
# ...         ...                                                ...
# 6196  306303378  Delivery Station (Station Code, City, State): ...
# 6207  306297305  Delivery Station (Station Code, City, State): ...
# 6256  306298305  Delivery Station (Station Code, City, State): ...
# 6560  306329881  Delivery Station (Station Code, City, State): ...
# 6712  306207385  Delivery Station (Station Code, City, State): ...
#
#                         root_cause              tid  \
# 66    t2 - unsafe driving behavior  TBA857691342000
# 97    t2 - unsafe driving behavior  TBA858049538000
# 306   t2 - unsafe driving behavior  TBA855767836000
# 317   t2 - unsafe driving behavior  TBA854289548000
# 329   t2 - unsafe driving behavior  TBA779183408000
# ...                            ...              ...
# 6196  t2 - unsafe driving behavior  TBA872996480000
# 6207  t2 - unsafe driving behavior  TBA872444875000
# 6256  t2 - unsafe driving behavior  TBA870106051000
# 6560  t2 - unsafe driving behavior  TBA849116343000
# 6712  t2 - unsafe driving behavior  TBA869763044000
#
#                                                    Data  \
# 66    contact id: a1h5jhp248o40d\r\n\r\nduplicate ti...
# 97    contact id: a2gstacmow9s8v\r\n\r\nduplicate ti...
# 306   contact id:a2l709ypww25ij\r\n\r\nduplicate tic...
# 317   contact id:a1gkl8v2vl75zq\r\n\r\nduplicate tic...
# 329   contact id:a10b74y9gmen5b\r\n\r\nduplicate tic...
# ...                                                 ...
# 6196  contact id: a1ameg65mge5p5\r\n\r\nduplicate ti...
# 6207  contact id: a1qyczhya3nttd\r\n\r\nduplicate ti...
# 6256  contact id :   a1d2elb910nqp4\r\n\r\nattached ...
# 6560  contact id:ar41xcteatt4t\r\n\r\nduplicate tick...
# 6712  contact id:a3tbu4ir67v7d1\r\n\r\nattached pod ...
#
#                                         Infraction_Data  \
# 66     da reputation \u2013 unsafe driving behavior\r\n
# 97     da reputation \u2013 unsafe driving behavior\r\n
# 306    da reputation \u2013 unsafe driving behavior\r\n
# 317    da reputation \u2013 unsafe driving behavior\r\n
# 329    tier 2da reputation \u2013 unsafe driving beh...
# ...                                                 ...
# 6196   da reputation \u2013 unsafe driving behavior\r\n
# 6207   da reputation \u2013 unsafe driving behavior\r\n
# 6256   da reputation \u2013 unsafe driving behavior\r\n
# 6560   da reputation \u2013 unsafe driving behavior\r\n
# 6712   da reputation \u2013 unsafe driving behavior\r\n
#
#                                 Additional_Details_Data  \
# 66    additional details: the driver backed up and d...
# 97    additional details: driver was speeding throug...
# 306   additional details: it's just that i'm very co...
# 317   additional details:customer called to say that...
# 329   additional details: driver drove over customer...
# ...                                                 ...
# 6196  additional details: please inform the driver n...
# 6207  additional details: customer has complained th...
# 6256  additional details: driver drive out of our pa...
# 6560  additional details:the driver passed over the ...
# 6712  additional details: customer is complaining th...
#
#                                              Infraction  \
# 66     da reputation \u2013 unsafe driving behavior\r\n
# 97     da reputation \u2013 unsafe driving behavior\r\n
# 306    da reputation \u2013 unsafe driving behavior\r\n
# 317    da reputation \u2013 unsafe driving behavior\r\n
# 329   tier 2da reputation \u2013 unsafe driving beha...
# ...                                                 ...
# 6196   da reputation \u2013 unsafe driving behavior\r\n
# 6207   da reputation \u2013 unsafe driving behavior\r\n
# 6256   da reputation \u2013 unsafe driving behavior\r\n
# 6560   da reputation \u2013 unsafe driving behavior\r\n
# 6712   da reputation \u2013 unsafe driving behavior\r\n
#
#                                      Additional Details Infraction1  \
# 66    Additional Details: The driver backed up and d...         NaN
# 97    Additional Details: Driver was speeding throug...         NaN
# 306   Additional Details: It's just that I'm very co...         NaN
# 317   Additional Details:Customer called to say that...         NaN
# 329   Additional Details: Driver drove over customer...         NaN
# ...                                                 ...         ...
# 6196  Additional Details: please inform the driver n...         NaN
# 6207  Additional Details: Customer has complained th...         NaN
# 6256  Additional Details: Driver drive out of our pa...         NaN
# 6560  Additional Details:The driver passed over the ...         NaN
# 6712  Additional Details: Customer is complaining th...         NaN
#
#      Infraction2  First_Status          attribute Status
# 66           NaN         False             damage   True
# 97           NaN         False              speed   True
# 306          NaN         False                fly   True
# 317          NaN         False               mark   True
# 329          NaN         False         drove over   True
# ...          ...           ...                ...    ...
# 6196         NaN         False                hit   True
# 6207         NaN         False  drove on her lawn   True
# 6256         NaN         False    wrong direction   True
# 6560         NaN         False                rut   True
# 6712         NaN         False           reckless   True
#
# [67 rows x 14 columns]
