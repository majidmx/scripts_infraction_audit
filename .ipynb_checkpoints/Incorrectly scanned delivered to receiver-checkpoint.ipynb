# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\all_infractions_data.csv')
df=df[df['root_cause'].str.contains('Behavioral - Incorrectly scanned delivered to receiver')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

df['Status_1']=df['Additional_Details_Data'].str.contains('no one was at home|customer didn''t sign for their package|item was not handed|package was never handed|customer was not in the address|no one was there to receive|package wasn''t handed|not deliver to receiver|not delivered to any receiver|delivered to receiver when it was not|left the packages outside|was never handed to her|is not at home|no one home|no one at the time of delivery|not handed directly to anyone|was left un attended|wasn''t handed to her|did not hand over the package to the customer|customer is not at home|was not left with the customer|left outside|customer was not home')


df['Status_2']=(df['Additional_Details_Data'].str.contains('place|found|put|drop|left|shove|deliver|kept|sit|handed|under'))&(df['Additional_Details_Data'].str.contains('other amazon boxes|side walk|car|top|at|outside|on|in|to|over|under|bottom|near|behind'))&(df['Additional_Details_Data'].str.contains('parking lot|trash can|garage|planter bed|location|locker|yard|pile of snow|address|customers home|mail room|office|leasing|business area|mail box|bush|road|grass|porch|lock box|stair|unattended|building|gate|street|ground|driveway|desk|sidewalk|customer''s business|door|apartment|mailbox|floor|lobby|steps|front porch|bush|waste management|curb'))

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\query_delivered_to_receiver.csv',encoding='ISO-8859-1')


df2=df.merge(df1,left_on='tid',right_on='Tracking Id',how='left')


df2.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Incorrectly scanned delivered to receiver.csv',index = False)
df2
# Out:
#        ShortId                                            details  \
# 0    424157197  Delivery Station (Station Code, City, State): ...
# 1    305179252  Delivery Station (Station Code, City, State): ...
# 2    424156309  Delivery Station (Station Code, City, State): ...
# 3    305255551  Delivery Station (Station Code, City, State): ...
# 4    305264399  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 335  424119284  Delivery Station (Station Code, City, State): ...
# 336  424118310  Delivery Station (Station Code, City, State): ...
# 337  424116085  Delivery Station (Station Code, City, State): ...
# 338  305050242  Delivery Station (Station Code, City, State): ...
# 339  304672293  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 0    T2 - Behavioral - Incorrectly scanned delivere...  TBA806525888000
# 1    T2 - Behavioral - Incorrectly scanned delivere...  TBA792133353000
# 2    T2 - Behavioral - Incorrectly scanned delivere...  TBA792735131000
# 3    T2 - Behavioral - Incorrectly scanned delivere...  TBA806704515000
# 4    T2 - Behavioral - Incorrectly scanned delivere...  TBA810378034000
# ..                                                 ...              ...
# 335  T2 - Behavioral - Incorrectly scanned delivere...  TBA742451391000
# 336  T2 - Behavioral - Incorrectly scanned delivere...  TBA771787532000
# 337  T2 - Behavioral - Incorrectly scanned delivere...  TBA766067580000
# 338  T2 - Behavioral - Incorrectly scanned delivere...  TBA799245139000
# 339  T2 - Behavioral - Incorrectly scanned delivere...  TBA753302420000
#
#                                                   Data  \
# 0    customer stated that the driver left the packa...
# 1    contact id:a3dxqenidc09eu\r\n\r\nduplicate tic...
# 2    contact id:ar6j98ntn8nst\r\n\r\nda details   :...
# 3    contact id: a3j3a1cjjz06ux\r\n\r\nduplicate ti...
# 4    contact id:ao4wy2hn94gsp\r\n\r\nduplicate tick...
# ..                                                 ...
# 335  contact id: a1s3b6rf0wwjsd\r\n\r\nattached pod...
# 336  contact id: a3spxwk9ary3nr\r\n\r\nattached pod...
# 337  contact id: a3ml16o0w772ov\r\n\r\nattached pod...
# 338  contact id:a1pd5btl9kg94y\r\n\r\nduplicate tic...
# 339  did you consult the available (tm/rs) on the f...
#
#                                        Infraction_Data  \
# 0    da reputation - behavioral - scanned delivered...
# 1    da reputation - behavioral - scanned delivered...
# 2    da reputation - behavioral - scanned delivered...
# 3     da reputation - behavioral - scanned delivere...
# 4    da reputation - behavioral - scanned delivered...
# ..                                                 ...
# 335  tier 2 da reputation - behavioral - scanned de...
# 336  tier 2 da reputation - behavioral - scanned de...
# 337   da reputation - behavioral - scanned delivere...
# 338  da reputation - behavioral - scanned delivered...
# 339  da reputation - behavioral - scanned delivered...
#
#                                Additional_Details_Data Status_1  Status_2  \
# 0    additional details:customer stated that the dr...    False      True
# 1    additional details:scanned as delivered to res...    False      True
# 2    additional details:the customer contacted abou...    False      True
# 3    additional details: the driver scanned the pac...    False      True
# 4    additional details:driver scanned as \delivere...    False      True
# ..                                                 ...      ...       ...
# 335  additional details:package was left on sidewal...    False      True
# 336  additional details driver throws the package t...    False     False
# 337  additional details: we were not home when the ...    False     False
# 338  additional details:driver marked it delivered ...    False      True
# 339  additional details:driver left the package una...    False      True
#
#       Consigner Order Id  ...  Code TBA Deposit Code Amazon Deposit Code  \
# 0    111-4547718-9910640  ...  DEW2              NaN                 NaN
# 1    114-0490071-1897839  ...  DSF6              NaN                 NaN
# 2    113-2997805-4665866  ...  DJX1              NaN                 NaN
# 3    112-9855471-3069851  ...  DNJ3              NaN                 NaN
# 4    113-1926834-9677060  ...  DEW8              NaN                 NaN
# ..                   ...  ...   ...              ...                 ...
# 335  112-5423194-6591412  ...  DLA8              NaN                 NaN
# 336  111-2994561-1394665  ...  DEW2              NaN                 NaN
# 337  114-4377896-9469037  ...  DSM1              NaN                 NaN
# 338  113-3478210-6747426  ...  DBA2              NaN                 NaN
# 339  112-9699399-0125034  ...  HBA1              NaN                 NaN
#
#     Route Sequence  sort_zone          packaging sellerName inductedCycle  \
# 0             79.0     D-1.2D  No Packaging Need        NaN       CYCLE_2
# 1            117.0    H-42.3B  No Packaging Need        NaN       CYCLE_1
# 2             64.0     B-6.1B  No Packaging Need        NaN       CYCLE_2
# 3             73.0    D-10.3B  No Packaging Need        NaN       CYCLE_2
# 4             46.0    G-16.2B  No Packaging Need        NaN       CYCLE_1
# ..             ...        ...                ...        ...           ...
# 335           47.0    B-30.2C  No Packaging Need        NaN       CYCLE_1
# 336          105.0     G-4.3B  No Packaging Need        NaN       CYCLE_2
# 337          106.0    D-25.1E  No Packaging Need        NaN       CYCLE_1
# 338          122.0     B-6.4B  No Packaging Need        NaN       CYCLE_2
# 339           15.0        NaN  No Packaging Need        NaN        AMXL_1
#
#     assignedCycle sideLineUntilTime
# 0         CYCLE_1               NaN
# 1         CYCLE_1               NaN
# 2         CYCLE_1               NaN
# 3         CYCLE_1               NaN
# 4         CYCLE_1               NaN
# ..            ...               ...
# 335       CYCLE_1               NaN
# 336       CYCLE_1               NaN
# 337       CYCLE_1               NaN
# 338       CYCLE_1               NaN
# 339           NaN               NaN
#
# [340 rows x 68 columns]
