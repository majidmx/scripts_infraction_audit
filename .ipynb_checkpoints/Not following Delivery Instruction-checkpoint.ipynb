# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('not following delivery instruction')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\comp_data.csv',encoding='ISO-8859-1')

df2=df.merge(df1,left_on='tid',right_on='Tracking Id',how='left')

df2['Customer Notes']=df2['Customer Notes'].str.lower()
df2['Reason']=df2['Reason'].str.lower()


word_list=['front door only','leave safe in mailroom','leave safe in customer','leave safe in locker','mail room','leave safe in front door','leave safe in rear door','leave safe in receptionist']
word_list_1=['front door only','leave safe in mailroom','leave safe in customer','locker','mail room','front door','rear door','receptionist']

df2['Attribute'] = df2['Customer Notes'].str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()


df2['Attribute_1'] = df2['Attribute'].str.extract('({})'.format('|'.join(word_list_1)), 
                        expand=False).str.lower()

df2['Attribute_1'] = df2['Attribute_1'].fillna('No data available')
df2['Attribute_1'] = df2['Attribute_1'].astype(str)

df2['Attribute_1'] = df2['Attribute_1'].replace('leave safe in customer', "receiver") 
df2['Attribute_1'] = df2['Attribute_1'].replace('leave safe in mailroom', "mail room") 
df2['Attribute_1'] = df2['Attribute_1'].replace('front door only', "front door") 


df2['Second_Status']=np.where(df2['Reason']==df2['Attribute_1'],'True','False')


df2.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_1stcheck.csv',index = False)


df2
# Out:
#        ShortId                                            details  \
# 0    306710650  Delivery Station (Station Code, City, State): ...
# 1    306697493  Delivery Station (Station Code, City, State): ...
# 2    306701957  Delivery Station (Station Code, City, State): ...
# 3    306670006  Delivery Station (Station Code, City, State): ...
# 4    306665716  ****Station submitted TTs will need to have da...
# ..         ...                                                ...
# 555  306571559  Delivery Station (Station Code, City, State): ...
# 556  305108810  ****Station submitted TTs will need to have da...
# 557  306848085  Delivery Station (Station Code, City, State): ...
# 558  306172227  Delivery Station (Station Code, City, State): ...
# 559  306058894  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 0    t2 - package mishandling - not following deliv...  TBA897534444000
# 1    t2 - package mishandling - not following deliv...  TBA902965015000
# 2    t2 - package mishandling - not following deliv...  TBA899838471000
# 3    t2 - package mishandling - not following deliv...  TBA899511144000
# 4    t2 - package mishandling - not following deliv...              TBA
# ..                                                 ...              ...
# 555  t2 - package mishandling - not following deliv...  TBA840296900000
# 556  t2 - package mishandling - not following deliv...  TBA753752120000
# 557  t2 - package mishandling - not following deliv...  TBA905751850000
# 558  t2 - package mishandling - not following deliv...  TBA857593757000
# 559  t2 - package mishandling - not following deliv...  TBA860878918000
#
#                                                   Data  \
# 0    as per contact id: agmgsrqzgt8s7 driver did no...
# 1    contact id: a2pk20lxqmtn1u\r\n\r\nattached pod...
# 2    driver didn't follow customer's instructions h...
# 3    contact id:a1tjn2fvlciz1x\r\n\r\nduplicate tic...
# 4    sds process tier 2 - da reputation - package m...
# ..                                                 ...
# 555  additional details from contact:da ignored the...
# 556  please provide tbas going forward. \n\n* this ...
# 557  contact id: aumhzbhahcuqp\r\n\r\nduplicate tic...
# 558  multiple packages (15 packages) were left outs...
# 559  contact id: ae4kazmequ1h\r\n\r\nattached pod (...
#
#                                             Infraction  \
# 0    da reputation - package mishandling - not foll...
# 1    da reputation - package mishandling - not foll...
# 2    da reputation - package mishandling - not foll...
# 3    da reputation - package mishandling - not foll...
# 4    da reputation - package mishandling - not foll...
# ..                                                 ...
# 555  da reputation - package mishandling - not foll...
# 556  da reputation - package mishandling - not foll...
# 557  da reputation - package mishandling - not foll...
# 558  da reputation - package mishandling - not foll...
# 559  da reputation - package mishandling - not foll...
#
#                                     Additional_Details    Infraction1  \
# 0    additional details:driver did not follow notes...  not following
# 1    additional details: customer complaining on a ...  not following
# 2    additional details: driver didn't follow deliv...  not following
# 3    additional details:customer is saying that the...  not following
# 4    additional details:driver deliverer the packag...  not following
# ..                                                 ...            ...
# 555  additional details:da ignored the instructions...  not following
# 556  additional details: driver scanned package as ...  not following
# 557  additional details:customer complains that the...  not following
# 558  additional details:apartment manager contacted...  not following
# 559  additional details: customer advised was sitti...  not following
#
#        Infraction2 First_Status  ... Route Sequence sort_zone  \
# 0    not following         True  ...           45.0   B-48.3C
# 1    not following         True  ...            7.0    C-8.3D
# 2    not following         True  ...            2.0   G-10.2A
# 3    not following         True  ...           32.0   J-36.2D
# 4    not following         True  ...            NaN       NaN
# ..             ...          ...  ...            ...       ...
# 555  not following         True  ...          102.0    C-8.4C
# 556  not following         True  ...           84.0   D-13.1G
# 557  not following         True  ...           24.0    B-8.1D
# 558  not following         True  ...           36.0   D-22.1B
# 559  not following         True  ...           47.0   C-20.1B
#
#              packaging sellerName inductedCycle  assignedCycle  \
# 0    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 1    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 2    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 3    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 4                  NaN        NaN           NaN            NaN
# ..                 ...        ...           ...            ...
# 555  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 556  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 557  No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 558  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 559  No Packaging Need        NaN       CYCLE_1        CYCLE_1
#
#     sideLineUntilTime                 Attribute        Attribute_1  \
# 0                 NaN                       NaN  No data available
# 1                 NaN  leave safe in front door         front door
# 2                 NaN   leave safe in rear door          rear door
# 3                 NaN  leave safe in front door         front door
# 4                 NaN                       NaN  No data available
# ..                ...                       ...                ...
# 555               NaN    leave safe in customer           receiver
# 556               NaN  leave safe in front door         front door
# 557               NaN  leave safe in front door         front door
# 558               NaN  leave safe in front door         front door
# 559               NaN                       NaN  No data available
#
#     Second_Status
# 0           False
# 1            True
# 2           False
# 3           False
# 4           False
# ..            ...
# 555         False
# 556         False
# 557          True
# 558         False
# 559         False
#
# [560 rows x 72 columns]

# %% [markdown]
# In Below , False states SDS raised correctly.

# %%
df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_1stcheck.csv')

df3=df3[df3['Attribute_1'].str.contains('No data available')==False]
df3['Second_Status']=df3['Second_Status'].astype(str)
df3=df3[df3['Second_Status'].str.contains('False')==True]
df3.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_false.csv',columns=('ShortId','root_cause','tid','Infraction_Data','Additional_Details_Data','Customer Notes','Attribute','Reason','Attribute_1','First_Status','Second_Status'),index = False)
df3
# Out:
#        ShortId                                            details  \
# 2    306701957  Delivery Station (Station Code, City, State): ...
# 3    306670006  Delivery Station (Station Code, City, State): ...
# 5    306713365  Delivery Station (Station Code, City, State): ...
# 6    306710815  Delivery Station (Station Code, City, State): ...
# 7    306691516  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 553  306132298  Delivery Station (Station Code, City, State): ...
# 554  306067518  Delivery Station (Station Code, City, State): ...
# 555  306571559  Delivery Station (Station Code, City, State): ...
# 556  305108810  ****Station submitted TTs will need to have da...
# 558  306172227  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 2    t2 - package mishandling - not following deliv...  TBA899838471000
# 3    t2 - package mishandling - not following deliv...  TBA899511144000
# 5    t2 - package mishandling - not following deliv...  TBA904312720000
# 6    t2 - package mishandling - not following deliv...  TBA770849970000
# 7    t2 - package mishandling - not following deliv...  TBA896587572000
# ..                                                 ...              ...
# 553  t2 - package mishandling - not following deliv...  TBA853354350000
# 554  t2 - package mishandling - not following deliv...  TBA837762237000
# 555  t2 - package mishandling - not following deliv...  TBA840296900000
# 556  t2 - package mishandling - not following deliv...  TBA753752120000
# 558  t2 - package mishandling - not following deliv...  TBA857593757000
#
#                                                   Data  \
# 2    driver didn't follow customer's instructions h...
# 3    contact id:a1tjn2fvlciz1x\r\n\r\nduplicate tic...
# 5    contact id:a1fx3djc0d0jzo\r\n\r\nattached pod ...
# 6    contact id: a2thqpqfstz024\r\n\r\nattached pod...
# 7                                    no data available
# ..                                                 ...
# 553  contact id: a3pe7y28golyls\r\n\r\nattached pod...
# 554  contact id: a18iw61jjhczj1\r\n\r\nduplicate ti...
# 555  additional details from contact:da ignored the...
# 556  please provide tbas going forward. \n\n* this ...
# 558  multiple packages (15 packages) were left outs...
#
#                                             Infraction  \
# 2    da reputation - package mishandling - not foll...
# 3    da reputation - package mishandling - not foll...
# 5    da reputation - package mishandling - not foll...
# 6    da reputation - package mishandling - not foll...
# 7                                               ailabl
# ..                                                 ...
# 553  da reputation - package mishandling - not foll...
# 554  da reputation - package mishandling - not foll...
# 555  da reputation - package mishandling - not foll...
# 556  da reputation - package mishandling - not foll...
# 558  da reputation - package mishandling - not foll...
#
#                                     Additional_Details    Infraction1  \
# 2    additional details: driver didn't follow deliv...  not following
# 3    additional details:customer is saying that the...  not following
# 5    additional details: driver delivered package a...  not following
# 6    additional details: customer is complaining th...  not following
# 7                                                  NaN  not following
# ..                                                 ...            ...
# 553  additional details: when customer came home or...  not following
# 554  additional details: customer reached out compl...  not following
# 555  additional details:da ignored the instructions...  not following
# 556  additional details: driver scanned package as ...  not following
# 558  additional details:apartment manager contacted...  not following
#
#        Infraction2 First_Status  ... Route Sequence sort_zone  \
# 2    not following         True  ...            2.0   G-10.2A
# 3    not following         True  ...           32.0   J-36.2D
# 5    not following         True  ...           74.0   A-11.3B
# 6    not following         True  ...           99.0    B-9.3C
# 7              NaN           NS  ...          136.0   E-16.4A
# ..             ...          ...  ...            ...       ...
# 553  not following         True  ...           36.0   E-17.2B
# 554  not following         True  ...           28.0   B-17.4E
# 555  not following         True  ...          102.0    C-8.4C
# 556  not following         True  ...           84.0   D-13.1G
# 558  not following         True  ...           36.0   D-22.1B
#
#              packaging sellerName inductedCycle  assignedCycle  \
# 2    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 3    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 5    No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 6    No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 7    No Packaging Need        NaN       CYCLE_1        CYCLE_2
# ..                 ...        ...           ...            ...
# 553  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 554  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 555  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 556  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 558  No Packaging Need        NaN       CYCLE_1        CYCLE_1
#
#     sideLineUntilTime                 Attribute Attribute_1 Second_Status
# 2                 NaN   leave safe in rear door   rear door         False
# 3                 NaN  leave safe in front door  front door         False
# 5                 NaN    leave safe in customer    receiver         False
# 6                 NaN  leave safe in front door  front door         False
# 7                 NaN      leave safe in locker      locker         False
# ..                ...                       ...         ...           ...
# 553               NaN  leave safe in front door  front door         False
# 554               NaN  leave safe in front door  front door         False
# 555               NaN    leave safe in customer    receiver         False
# 556               NaN  leave safe in front door  front door         False
# 558               NaN  leave safe in front door  front door         False
#
# [335 rows x 72 columns]

# %%
df_3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_1stcheck.csv')

df_3=df_3[df_3['Attribute_1'].str.contains('No data available')==True]
df_3['Second_Status']=df_3['Second_Status'].astype(str)
df_3=df_3[df_3['Second_Status'].str.contains('False')==True]
df_3.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_False_Nodataavailable.csv',columns=('ShortId','root_cause','tid','Infraction_Data','Additional_Details_Data','Customer Notes','Attribute','Reason','Attribute_1','First_Status','Second_Status'),index = False)
df_3
# Out:
#        ShortId                                            details  \
# 0    306710650  Delivery Station (Station Code, City, State): ...
# 4    306665716  ****Station submitted TTs will need to have da...
# 8    306708734  Delivery Station (Station Code, City, State): ...
# 17   306593574  Delivery Station (Station Code, City, State): ...
# 21   306673204  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 540  306075078  Delivery Station (Station Code, City, State): ...
# 542  306152496  Delivery Station (Station Code, City, State): ...
# 547  306160294  Delivery Station (Station Code, City, State): ...
# 549  306142486  Delivery Station (Station Code, City, State): ...
# 559  306058894  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 0    t2 - package mishandling - not following deliv...  TBA897534444000
# 4    t2 - package mishandling - not following deliv...              TBA
# 8    t2 - package mishandling - not following deliv...  TBA892747757000
# 17   t2 - package mishandling - not following deliv...  TBA890514507000
# 21   t2 - package mishandling - not following deliv...  TBA891568558000
# ..                                                 ...              ...
# 540  t2 - package mishandling - not following deliv...  TBA862734221000
# 542  t2 - package mishandling - not following deliv...  TBA834147894000
# 547  t2 - package mishandling - not following deliv...  TBA862093600000
# 549  t2 - package mishandling - not following deliv...  TBA862631081000
# 559  t2 - package mishandling - not following deliv...  TBA860878918000
#
#                                                   Data  \
# 0    as per contact id: agmgsrqzgt8s7 driver did no...
# 4    sds process tier 2 - da reputation - package m...
# 8    contact id:a19tjxz31mnxs8\r\n\r\nduplicate tic...
# 17   contact id:a1x58ygexscg5n\r\n\r\nduplicate tic...
# 21   contact id: a2ncnocs82ou6e\r\n\r\nattached pod...
# ..                                                 ...
# 540  \r\ncontact id: a9x4ef4kdwpz5\r\n\r\nattached ...
# 542  contact id: a8rokm4a4z050\r\n\r\nattached pod ...
# 547  contact id: a1kqv83w813yjy\r\n\r\nduplicate ti...
# 549  contact id: a1cpm4e50p3r3o\r\n \r\nattached po...
# 559  contact id: ae4kazmequ1h\r\n\r\nattached pod (...
#
#                                             Infraction  \
# 0    da reputation - package mishandling - not foll...
# 4    da reputation - package mishandling - not foll...
# 8    tier 2da reputation - package mishandling - no...
# 17   tier 2da reputation - package mishandling - no...
# 21   da reputation - package mishandling - not foll...
# ..                                                 ...
# 540  da reputation - package mishandling - not foll...
# 542  da reputation - package mishandling - not foll...
# 547  da reputation - package mishandling - not foll...
# 549  da reputation - package mishandling - not foll...
# 559  da reputation - package mishandling - not foll...
#
#                                     Additional_Details    Infraction1  \
# 0    additional details:driver did not follow notes...  not following
# 4    additional details:driver deliverer the packag...  not following
# 8    additional details:the customer says there are...  not following
# 17   additional details:customer complains that dri...  not following
# 21   additional details: da left package outside bu...  not following
# ..                                                 ...            ...
# 540  additional details: the driver ignored the del...  not following
# 542  additional details: driver left the package in...  not following
# 547  additional details: customer has complained th...  not following
# 549  additional details: customer has huge sign at ...  not following
# 559  additional details: customer advised was sitti...  not following
#
#        Infraction2 First_Status  ... Route Sequence sort_zone  \
# 0    not following         True  ...           45.0   B-48.3C
# 4    not following         True  ...            NaN       NaN
# 8    not following         True  ...           77.0   A-22.3C
# 17   not following         True  ...           28.0   A-35.2E
# 21   not following         True  ...           46.0    D-6.2A
# ..             ...          ...  ...            ...       ...
# 540  not following         True  ...           76.0    B-9.1E
# 542  not following         True  ...           17.0    D-4.4A
# 547  not following         True  ...           38.0       NaN
# 549  not following         True  ...           67.0    L-1.4B
# 559  not following         True  ...           47.0   C-20.1B
#
#              packaging sellerName inductedCycle  assignedCycle  \
# 0    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 4                  NaN        NaN           NaN            NaN
# 8    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 17   No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 21   No Packaging Need        NaN       CYCLE_2        CYCLE_1
# ..                 ...        ...           ...            ...
# 540  No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 542  No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 547  No Packaging Need        NaN      AD_HOC_1            NaN
# 549  No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 559  No Packaging Need        NaN       CYCLE_1        CYCLE_1
#
#     sideLineUntilTime Attribute        Attribute_1 Second_Status
# 0                 NaN       NaN  No data available         False
# 4                 NaN       NaN  No data available         False
# 8                 NaN       NaN  No data available         False
# 17                NaN       NaN  No data available         False
# 21                NaN       NaN  No data available         False
# ..                ...       ...                ...           ...
# 540               NaN       NaN  No data available         False
# 542               NaN       NaN  No data available         False
# 547               NaN       NaN  No data available         False
# 549               NaN       NaN  No data available         False
# 559               NaN       NaN  No data available         False
#
# [152 rows x 72 columns]

# %%
df_4=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_1stcheck.csv')

df_4=df_4[df_4['Attribute_1'].str.contains('No data available')==False]
df_4['Second_Status']=df_4['Second_Status'].astype(str)
df_4=df_4[df_4['Second_Status'].str.contains('True')==True]
df_4.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_True.csv',columns=('ShortId','root_cause','tid','Infraction_Data','Additional_Details_Data','Customer Notes','Attribute','Reason','Attribute_1','First_Status','Second_Status'),index = False)
df_4
# Out:
#        ShortId                                            details  \
# 1    306697493  Delivery Station (Station Code, City, State): ...
# 9    306704817  ****Station submitted TTs will need to have da...
# 13   306596774  Delivery Station (Station Code, City, State): ...
# 16   306698113  Delivery Station (Station Code, City, State): ...
# 19   306708640  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 510  307114514  Delivery Station (Station Code, City, State): ...
# 528  306071145  Delivery Station (Station Code, City, State): ...
# 534  306076354  Delivery Station (Station Code, City, State): ...
# 543  306197218  Delivery Station (Station Code, City, State): ...
# 557  306848085  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 1    t2 - package mishandling - not following deliv...  TBA902965015000
# 9    t2 - package mishandling - not following deliv...  TBA885719634000
# 13   t2 - package mishandling - not following deliv...  TBA887860503000
# 16   t2 - package mishandling - not following deliv...  TBA904228383000
# 19   t2 - package mishandling - not following deliv...  TBA893017782000
# ..                                                 ...              ...
# 510  t2 - package mishandling - not following deliv...  TBA920960378000
# 528  t2 - package mishandling - not following deliv...  TBA850204503000
# 534  t2 - package mishandling - not following deliv...  TBA861684777000
# 543  t2 - package mishandling - not following deliv...  TBA861558164000
# 557  t2 - package mishandling - not following deliv...  TBA905751850000
#
#                                                   Data  \
# 1    contact id: a2pk20lxqmtn1u\r\n\r\nattached pod...
# 9    sds process tier 2 - da reputation - package m...
# 13   contact id: a37ve5eio7s8p0\r\n\r\nattached pod...
# 16   contact id : apukj8a5humz7\r\nas per the call ...
# 19   contact id: a3euxhex0r4mj1\r\n\r\nattached pod...
# ..                                                 ...
# 510  contact id: a3hxmyzqe85dtp\r\n \r\nduplicate t...
# 528  did you consult the available (tm/rs) on the f...
# 534  contact id: a3n06tueb2j70q\r\n\r\nattached pod...
# 543  contact id:a2lxqbic4f6oyu\r\n\r\nduplicate tic...
# 557  contact id: aumhzbhahcuqp\r\n\r\nduplicate tic...
#
#                                             Infraction  \
# 1    da reputation - package mishandling - not foll...
# 9    tier 2 da reputation - package mishandling - n...
# 13   da reputation - package mishandling - not foll...
# 16   da reputation - package mishandling - not foll...
# 19   da reputation - package mishandling - not foll...
# ..                                                 ...
# 510  da reputation - package mishandling - not foll...
# 528                                                NaN
# 534  da reputation - package mishandling - not foll...
# 543  tier 2da reputation - package mishandling - no...
# 557  da reputation - package mishandling - not foll...
#
#                                     Additional_Details    Infraction1  \
# 1    additional details: customer complaining on a ...  not following
# 9    additional details: notified by po manager of ...  not following
# 13   additional details: driver marked as \unable t...  not following
# 16   additional details: deliver instructions weren...  not following
# 19   additional details: the customer is in a wheel...  not following
# ..                                                 ...            ...
# 510  additional details: driver did not followed in...  not following
# 528  additional details: customers notes state: \us...  not following
# 534  additional details: customer is complaining on...  not following
# 543  additional details:customer complains that dri...  not following
# 557  additional details:customer complains that the...  not following
#
#        Infraction2 First_Status  ... Route Sequence sort_zone  \
# 1    not following         True  ...            7.0    C-8.3D
# 9    not following         True  ...           51.0   C-16.1C
# 13   not following         True  ...           14.0   A-15.1D
# 16   not following         True  ...           11.0    B-8.1B
# 19   not following         True  ...          102.0    A-7.1A
# ..             ...          ...  ...            ...       ...
# 510  not following         True  ...          113.0   A-31.3B
# 528            NaN           NS  ...           57.0   H-27.2A
# 534  not following         True  ...          104.0   A-18.1D
# 543  not following         True  ...          102.0   B-20.3A
# 557  not following         True  ...           24.0    B-8.1D
#
#              packaging sellerName inductedCycle  assignedCycle  \
# 1    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 9    No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 13   No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 16   No Packaging Need        NaN       CYCLE_2        CYCLE_1
# 19   No Packaging Need        NaN       CYCLE_2        CYCLE_2
# ..                 ...        ...           ...            ...
# 510  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 528  No Packaging Need        NaN       CYCLE_1            NaN
# 534  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 543  No Packaging Need        NaN       CYCLE_1        CYCLE_1
# 557  No Packaging Need        NaN       CYCLE_2        CYCLE_1
#
#     sideLineUntilTime                 Attribute Attribute_1 Second_Status
# 1                 NaN  leave safe in front door  front door          True
# 9                 NaN    leave safe in mailroom   mail room          True
# 13                NaN  leave safe in front door  front door          True
# 16                NaN  leave safe in front door  front door          True
# 19                NaN   leave safe in rear door   rear door          True
# ..                ...                       ...         ...           ...
# 510               NaN  leave safe in front door  front door          True
# 528               NaN    leave safe in mailroom   mail room          True
# 534               NaN  leave safe in front door  front door          True
# 543               NaN  leave safe in front door  front door          True
# 557               NaN  leave safe in front door  front door          True
#
# [73 rows x 72 columns]

# %%
df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_false.csv')
df2=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_False_Nodataavailable.csv')
df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_NfDI_True.csv')



df = pd.concat([df1, df2,df3], ignore_index=True)
df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Verified_Collated_NFDI.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df
# Out:
#        ShortId                                         root_cause  \
# 0    306701957  t2 - package mishandling - not following deliv...
# 1    306670006  t2 - package mishandling - not following deliv...
# 2    306713365  t2 - package mishandling - not following deliv...
# 3    306710815  t2 - package mishandling - not following deliv...
# 4    306691516  t2 - package mishandling - not following deliv...
# ..         ...                                                ...
# 555  307114514  t2 - package mishandling - not following deliv...
# 556  306071145  t2 - package mishandling - not following deliv...
# 557  306076354  t2 - package mishandling - not following deliv...
# 558  306197218  t2 - package mishandling - not following deliv...
# 559  306848085  t2 - package mishandling - not following deliv...
#
#                  tid  Infraction_Data  Additional_Details_Data  \
# 0    TBA899838471000              NaN                      NaN
# 1    TBA899511144000              NaN                      NaN
# 2    TBA904312720000              NaN                      NaN
# 3    TBA770849970000              NaN                      NaN
# 4    TBA896587572000              NaN                      NaN
# ..               ...              ...                      ...
# 555  TBA920960378000              NaN                      NaN
# 556  TBA850204503000              NaN                      NaN
# 557  TBA861684777000              NaN                      NaN
# 558  TBA861558164000              NaN                      NaN
# 559  TBA905751850000              NaN                      NaN
#
#                                         Customer Notes  \
# 0                              leave safe in rear door
# 1    gate code: access:205|call::205\nleave safe in...
# 2    gate code: dial 8640\nleave safe in customer e...
# 3                     leave safe in front door receive
# 4                                 leave safe in locker
# ..                                                 ...
# 555                   leave safe in front door receive
# 556      gate code: 822#\nleave safe in mailroom staff
# 557                   leave safe in front door receive
# 558                   leave safe in front door receive
# 559  gate code: leave at back house\nleave safe in ...
#
#                     Attribute      Reason Attribute_1 First_Status  \
# 0     leave safe in rear door  front door   rear door         True
# 1    leave safe in front door   mail room  front door         True
# 2      leave safe in customer   mail room    receiver         True
# 3    leave safe in front door    receiver  front door         True
# 4        leave safe in locker   mail room      locker           NS
# ..                        ...         ...         ...          ...
# 555  leave safe in front door  front door  front door         True
# 556    leave safe in mailroom   mail room   mail room           NS
# 557  leave safe in front door  front door  front door         True
# 558  leave safe in front door  front door  front door         True
# 559  leave safe in front door  front door  front door         True
#
#      Second_Status
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 555           True
# 556           True
# 557           True
# 558           True
# 559           True
#
# [560 rows x 11 columns]
