# %% [markdown]
# # General Filter

# %% [markdown]
# Collated Sim Data

# %%
import pandas as pd
import numpy as np

sim_data=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\sim_data.csv',usecols=('ShortId','Data'),low_memory=False)

# sim_data=sim_data[sim_data['Title'].str.contains('Comment')==True]
df=sim_data.groupby(['ShortId'])['Data'].apply(lambda x: ','.join(x)).reset_index()


df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Collated_sim_data.csv',index=False)
df
# Out:
#          ShortId                                               Data
# 0      302423725  Assigning to team member to review.,SDS Proces...
# 1      305796444  Cx Account ID: A2IUQMKDA6O4CM\r\nRelevant Cont...
# 2      307760199  The driver is a DSP/DA. \r\n\r\nDA AM CONSOLE ...
# 3      307888143  Customer states driver entered the home and de...
# 4      307898729  Customer states that the Driver makes racial c...
# ...          ...                                                ...
# 2370   425820433  Evidence provided by DSP is attached in Relate...
# 2371   425820642  Appeal received but not yet approved and escal...
# 2372   425822259  Appeal received and approved as DSP states COV...
# 2373   425823749  Appeal received and approved as DSP states of ...
# 2374  E103857937  Link to video of incident: \r\nhttps://video.n...
#
# [2375 rows x 2 columns]

# %% [markdown]
# Collated Infractions data final

# %%
df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Collated_sim_data.csv',usecols=('ShortId','Data'))
df1['ShortId']=df1['ShortId'].astype(str)

audit_query=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\audit_query.csv',usecols=('case_id','details','root_cause','tid'),encoding='ISO-8859-1')

audit_query_1 = audit_query.rename(columns = {"case_id": "ShortId"}) 

audit_query_1['ShortId'].dropna(inplace=True)


x=audit_query_1.merge(df1,on='ShortId',how='left')
x['Data'] = x.Data.fillna('No data available')

x = x[(x['root_cause'] != 'Positive Feedback')&(x['root_cause'] != 'Offboarding - Combined Threshold')]

x['Infraction']=x['Data'].apply(lambda st: st[st.find("Infraction")+11:st.find("Additional Details")])
x['Additional_Details']=x['Data'].apply(lambda st: st[st.find("Additional Details:"):st.find("Delivery Tip")])

x=x[x['Data'].str.contains('Appeal Successful|Appeal Rejected|Overturned during MTI process|DSP DA station tickets are now processed through RIVER')==False]

x.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Collated_Infractions_data_final.csv',index=False)
x
# Out:
#         ShortId                                            details  \
# 0     425807774  Delivery Station (Station Code, City, State): ...
# 1     425785875  Delivery Station (Station Code, City, State): ...
# 2     425753665  Delivery Station (Station Code, City, State): ...
# 3     425766291  Delivery Station (Station Code, City, State): ...
# 4     425754705  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 2018  308433267  Delivery Station (Station Code, City, State): ...
# 2019  307898729  Delivery Station (Station Code, City, State): ...
# 2020  424795196  Delivery Station (Station Code, City, State): ...
# 2021  424802461  Delivery Station (Station Code, City, State): ...
# 2022  305796444  ***SDS ECR***    Filing Ticket to track incide...
#
#                                              root_cause              tid  \
# 0                                 Not a Tier Infraction  TBA179223693000
# 1                                 Not a Tier Infraction  TBA098191158000
# 2                      T2 - Behavioral - Incorrect Scan  TBA167720746000
# 3                      T2 - Behavioral - Incorrect Scan  TBA167716842000
# 4                                 Not a Tier Infraction  TBA163973858000
# ...                                                 ...              ...
# 2018                              Not a Tier Infraction  TBA995816169000
# 2019  T2 - Behavioral - Unprofessional behavior towa...  TBA961190323000
# 2020                  T2 - Behavioral - Property Damage  TBA083261880000
# 2021                T1 - Behavioral - Theft of Property  TBA014837712000
# 2022  T1 - Unsafe driving behavior - Property Damage...              TBA
#
#                                                    Data  \
# 0                                     No data available
# 1     The customer didn't mention what were the inst...
# 2     Contact ID: A1KA9E85N9QDT7\r\n\r\nDuplicate ti...
# 3                                     No data available
# 4     Driver attempted delivery after business hours...
# ...                                                 ...
# 2018  customer has no evidence that driver opened th...
# 2019  Customer states that the Driver makes racial c...
# 2020  Incorrectly raised property damage ticket. Inf...
# 2021  DA has received a Tier-1 suspension based on c...
# 2022  Cx Account ID: A2IUQMKDA6O4CM\r\nRelevant Cont...
#
#                                              Infraction  \
# 0                                                ailabl
# 1     er didn't mention what were the instructions a...
# 2       DA Reputation \u2013 Behavioral \u2013 Incor...
# 3                                                ailabl
# 4     empted delivery after business hours. Not a ti...
# ...                                                 ...
# 2018  as no evidence that driver opened the package ...
# 2019   DA reputation - Behavioral - Insulting, unpro...
# 2020  Appeals / DSP DA / Property Damage - Infractio...
# 2021  \r\nBody: \r\nHello Plan B Advantage, Inc DBA ...
# 2022   \r\n\r\nHello George Cassell Logistics, \r\n\...
#
#                                      Additional_Details
# 0
# 1
# 2     Additional Details:  Da marked as Unable to ac...
# 3
# 4
# ...                                                 ...
# 2018
# 2019  Additional Details: Customer complained that t...
# 2020  Additional Details: Driver opened storm door a...
# 2021  Additional Details: The DA was captured on cam...
# 2022  Additional Details: DA was captured on video b...
#
# [1970 rows x 7 columns]

# %% [markdown]
# # Match Infractions - First check

# %%
df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Collated_Infractions_data_final.csv')


df3['root_cause']=df3['root_cause'].str.lower() 
df3['Infraction']=df3['Infraction'].str.lower()
df3['Data']=df3['Data'].str.lower() 



word_list=['badge','bags left','behavior towards a customer','business closed','dangerous','delivered to receiver','not following','did not follow sop','headphones','incorrect scan',
    'inside lobby','lawn','leaving keys','left in driveway','left in road','left unattended','locker','mail box','mailroom/leasing','no safe location',
    'non-swa','on/near garbage','ovesize','safety vest','seat belt','station employee','station standard work compliance','tailgating','throwing','unable to access',
    'unauthorized entry','under the roof','unsafe driving at station','property damage','unsecure packages']

df3['Infraction1'] = df3.root_cause.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df3['Infraction2'] = df3.Infraction.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df3['First_Status']=np.where(df3['Infraction1']==df3['Infraction2'],'True','NS')

df4_1=df3[df3['Data'].str.contains('Appeal Successful|Appeal Rejected|Overturned during MTI process|DSP DA station tickets are now processed through RIVER')==False]
df4_1['Infraction'] = df4_1['Infraction'].str.strip()

# z=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\comp_data.csv',encoding='ISO-8859-1')
# y=df4_1.merge(z,left_on='tid',right_on='Tracking Id',how='left')

df4_1.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv',index = False)

df4_1
# Out:
#         ShortId                                            details  \
# 0     425807774  Delivery Station (Station Code, City, State): ...
# 1     425785875  Delivery Station (Station Code, City, State): ...
# 2     425753665  Delivery Station (Station Code, City, State): ...
# 3     425766291  Delivery Station (Station Code, City, State): ...
# 4     425754705  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 1965  308433267  Delivery Station (Station Code, City, State): ...
# 1966  307898729  Delivery Station (Station Code, City, State): ...
# 1967  424795196  Delivery Station (Station Code, City, State): ...
# 1968  424802461  Delivery Station (Station Code, City, State): ...
# 1969  305796444  ***SDS ECR***    Filing Ticket to track incide...
#
#                                              root_cause              tid  \
# 0                                 not a tier infraction  TBA179223693000
# 1                                 not a tier infraction  TBA098191158000
# 2                      t2 - behavioral - incorrect scan  TBA167720746000
# 3                      t2 - behavioral - incorrect scan  TBA167716842000
# 4                                 not a tier infraction  TBA163973858000
# ...                                                 ...              ...
# 1965                              not a tier infraction  TBA995816169000
# 1966  t2 - behavioral - unprofessional behavior towa...  TBA961190323000
# 1967                  t2 - behavioral - property damage  TBA083261880000
# 1968                t1 - behavioral - theft of property  TBA014837712000
# 1969  t1 - unsafe driving behavior - property damage...              TBA
#
#                                                    Data  \
# 0                                     no data available
# 1     the customer didn't mention what were the inst...
# 2     contact id: a1ka9e85n9qdt7\r\n\r\nduplicate ti...
# 3                                     no data available
# 4     driver attempted delivery after business hours...
# ...                                                 ...
# 1965  customer has no evidence that driver opened th...
# 1966  customer states that the driver makes racial c...
# 1967  incorrectly raised property damage ticket. inf...
# 1968  da has received a tier-1 suspension based on c...
# 1969  cx account id: a2iuqmkda6o4cm\r\nrelevant cont...
#
#                                              Infraction  \
# 0                                                ailabl
# 1     er didn't mention what were the instructions a...
# 2     da reputation \u2013 behavioral \u2013 incorre...
# 3                                                ailabl
# 4     empted delivery after business hours. not a ti...
# ...                                                 ...
# 1965  as no evidence that driver opened the package ...
# 1966  da reputation - behavioral - insulting, unprof...
# 1967  appeals / dsp da / property damage - infractio...
# 1968  \r\nbody: \r\nhello plan b advantage, inc dba ...
# 1969  \r\n\r\nhello george cassell logistics, \r\n\r...
#
#                                      Additional_Details  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Additional Details:  Da marked as Unable to ac...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1965                                                NaN
# 1966  Additional Details: Customer complained that t...
# 1967  Additional Details: Driver opened storm door a...
# 1968  Additional Details: The DA was captured on cam...
# 1969  Additional Details: DA was captured on video b...
#
#                       Infraction1      Infraction2 First_Status
# 0                             NaN              NaN           NS
# 1                             NaN              NaN           NS
# 2                  incorrect scan   incorrect scan         True
# 3                  incorrect scan              NaN           NS
# 4                             NaN              NaN           NS
# ...                           ...              ...          ...
# 1965                          NaN              NaN           NS
# 1966  behavior towards a customer              NaN           NS
# 1967              property damage  property damage         True
# 1968                          NaN              NaN           NS
# 1969              property damage  property damage         True
#
# [1970 rows x 10 columns]

# %% [markdown]
# # Dumping packages inside lobby front entrance

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('dumping packages inside lobby/front entrance')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()


df['Second_Status']=(df['Additional_Details'].str.contains('drop|leaving|stash|left|deliver|dumped|leave|abandon|sent'))&(df['Additional_Details'].str.contains('package|item|box| '))&(df['Additional_Details'].str.contains('unsafe|outside|at|between|in|by|behind|of'))&(df['Additional_Details'].str.contains('fence|stairwell on the first floor|apartment front door|apartment door|mailbox|mailboxes|leasing|front in the steps|lobby|entrance|building|bldg|front door of the apartment|front of elevator|front door of apartment|the door|store|gate|public hall|building|main door|steps|mailroom'))


df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Dumping packages inside lobby.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 29    308491548  Delivery Station (Station Code, City, State): ...
# 87    308316644  Delivery Station (Station Code, City, State): ...
# 113   308444774  Delivery Station (Station Code, City, State): ...
# 119   308306967  ****Station submitted TTs will need to have da...
# 133   308301275  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6639  308294331  Delivery Station (Station Code, City, State): ...
# 6644  308399966  Delivery Station (Station Code, City, State): ...
# 6660  308494316  Delivery Station (Station Code, City, State): ...
# 6856  308321785  Delivery Station (Station Code, City, State): ...
# 6897  308447101  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 29    t2 - behavioral - dumping packages inside lobb...  TBA000217065000
# 87    t2 - behavioral - dumping packages inside lobb...  TBA000610210000
# 113   t2 - behavioral - dumping packages inside lobb...  TBA000807404000
# 119   t2 - behavioral - dumping packages inside lobb...              NaN
# 133   t2 - behavioral - dumping packages inside lobb...  TBA000956503000
# ...                                                 ...              ...
# 6639  t2 - behavioral - dumping packages inside lobb...  TBA997230246000
# 6644  t2 - behavioral - dumping packages inside lobb...  TBA997249461000
# 6660  t2 - behavioral - dumping packages inside lobb...  TBA997376696000
# 6856  t2 - behavioral - dumping packages inside lobb...  TBA999044645000
# 6897  t2 - behavioral - dumping packages inside lobb...  TBA999430657000
#
#                                                    Data  \
# 29    contact id:a7o31e9rlvr2\r\n\r\n \r\n\r\nattach...
# 87    contact id: akj9jujvmkjk7\r\n\r\nattached pod ...
# 113   contact id: a2qzuchjhp2tf2\r\n\r\nduplicate ti...
# 119   hi jennifer,\r\n\r\nplease add the tbas relate...
# 133   contact id: auxy7csdmz60v\r\n\r\nduplicate tic...
# ...                                                 ...
# 6639  contact id: a8gdsitdg3p1s\r\n\r\nduplicate tt-...
# 6644  customer stated that the driver left the packa...
# 6660  contact id: a23fiws7189sty\r\n\r\nattached pod...
# 6856  contact id:a22t1k994wnlcs\r\n\r\nduplicate tic...
# 6897  as per contact id: i just happened to check on...
#
#                                              Infraction  \
# 29    da reputation - behavioral \u2013 dumping pack...
# 87    da reputation - behavioral \u2013 dumping pack...
# 113   da reputation - behavioral \u2013 dumping pack...
# 119   \r\ntier 2 da reputation - behavioral \u2013 d...
# 133   da reputation - behavioral \u2013 dumping pack...
# ...                                                 ...
# 6639  @jarstd.com\r\n\r\nsent below mail to dsp:\r\n...
# 6644  da reputation - behavioral \u2013 dumping pack...
# 6660  da reputation - behavioral \u2013 dumping pack...
# 6856  da reputation - behavioral \u2013 dumping pack...
# 6897  da reputation - behavioral \u2013 dumping pack...
#
#                                      Additional_Details   Infraction1  \
# 29    additional details:driver left the package in ...  inside lobby
# 87    additional details: packages repeatedly left o...  inside lobby
# 113   additional details: property management report...  inside lobby
# 119   additional details: driver dumped packages by ...  inside lobby
# 133   additional details: customer complains that th...  inside lobby
# ...                                                 ...           ...
# 6639  additional details: the driver dumped all the ...  inside lobby
# 6644  additional details:customer stated that the dr...  inside lobby
# 6660  additional details: customer is complaining th...  inside lobby
# 6856  additional details: customer stated that the d...  inside lobby
# 6897  additional details: i just happened to check o...  inside lobby
#
#        Infraction2 First_Status  Second_Status
# 29    inside lobby         True           True
# 87    inside lobby         True           True
# 113   inside lobby         True           True
# 119   inside lobby         True           True
# 133   inside lobby         True          False
# ...            ...          ...            ...
# 6639  inside lobby         True          False
# 6644  inside lobby         True          False
# 6660  inside lobby         True           True
# 6856  inside lobby         True           True
# 6897  inside lobby         True           True
#
# [126 rows x 11 columns]

# %% [markdown]
# # Dumping packages outside locker

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('dumping packages outside locker')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()


df['Second_Status']=df['Additional_Details'].str.contains('left the packages in the mail room instead of delivering the package in the locker|dumped all these packages in the luxer room|left by the door inside the luxer room|left the package lean up against the lockers|into the locker room without being secured in a locker|outside the package room instead of|dumped the packages without scanning them in the luxer lockers|left in front of the locker|left the packages out of the locker system|left the packages unsecured on the parcel room|left the package in the mail-room|packages are supposed to go into the hub lockers|dumped these packages at the amazon hub|dumped all packages on his route for this address in the locker room on the ground unattended|left the package in the mail room without putting them in the locker|did not use the luxor locker|locker room floor|dump packages in the lobby|left outside of  locker|outside at the locker|instead of locker|outside of the hub|outside the hub|outside of locker|outside the locker|left on the mailroom floor|next to the locker|out side the locker|outside a locker|outside of the locker|left outside of the parcel pending locker|outside of the Luxer room|Not delivering to the locker|outside the hub locker|on top of the locker|outside of the HUB|outside locker|leave packages out of the HUB|on floor of locker|outside the Amazon Hub|outside the Hub|outside of the Delivery Locker|on the floor in parcel locker room|locker room unattended|unattended in the mail room')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Dumping packages outside locker.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 122   308399077  Delivery Station (Station Code, City, State): ...
# 243   308441956  Delivery Station (Station Code, City, State): ...
# 413   308499594  Delivery Station (Station Code, City, State): ...
# 653   308428277  Delivery Station (Station Code, City, State): ...
# 662   308443628  Delivery Station (Station Code, City, State): ...
# 682   308759075  Delivery Station (Station Code, City, State): ...
# 835   308595199  Delivery Station (Station Code, City, State): ...
# 1136  307868914  ****Station submitted TTs will need to have da...
# 1227  308632636  Delivery Station (Station Code, City, State): ...
# 1228  308737293  Delivery Station (Station Code, City, State): ...
# 1726  308723939  Delivery Station (Station Code, City, State): ...
# 1904  308619111  Delivery Station (Station Code, City, State): ...
# 1988  308768732  Delivery Station (Station Code, City, State): ...
# 2184  308743271  Delivery Station (Station Code, City, State): ...
# 2189  308854018  Delivery Station (Station Code, City, State): ...
# 2212  308883968  Delivery Station (Station Code, City, State): ...
# 2244  308761851  Delivery Station (Station Code, City, State): ...
# 2658  308745436  Delivery Station (Station Code, City, State): ...
# 3853  307911228  Delivery Station: DAT3     DSP: BamExpress, LL...
# 4489  308407590  Delivery Station (Station Code, City, State): ...
# 5261  308276113  Delivery Station (Station Code, City, State): ...
# 5593  308488898  Delivery Station (Station Code, City, State): ...
# 6302  308423386  Delivery Station (Station Code, City, State): ...
# 6431  308277554  Delivery Station (Station Code, City, State): ...
# 6437  308313132  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 122   t2 - behavioral - dumping packages outside locker  TBA000875793000
# 243   t2 - behavioral - dumping packages outside locker  TBA001847828000
# 413   t2 - behavioral - dumping packages outside locker  TBA003540432000
# 653   t2 - behavioral - dumping packages outside locker  TBA005352217000
# 662   t2 - behavioral - dumping packages outside locker  TBA005415239000
# 682   t2 - behavioral - dumping packages outside locker  TBA005533787000
# 835   t2 - behavioral - dumping packages outside locker  TBA006812826000
# 1136  t2 - behavioral - dumping packages outside locker              TBA
# 1227  t2 - behavioral - dumping packages outside locker  TBA009837945000
# 1228  t2 - behavioral - dumping packages outside locker              NaN
# 1726  t2 - behavioral - dumping packages outside locker  TBA013795914000
# 1904  t2 - behavioral - dumping packages outside locker  TBA015253844000
# 1988  t2 - behavioral - dumping packages outside locker  TBA015942908000
# 2184  t2 - behavioral - dumping packages outside locker  TBA017739610000
# 2189  t2 - behavioral - dumping packages outside locker  TBA017773952000
# 2212  t2 - behavioral - dumping packages outside locker  TBA018064608000
# 2244  t2 - behavioral - dumping packages outside locker  TBA018322720000
# 2658  t2 - behavioral - dumping packages outside locker  TBA021863724000
# 3853  t2 - behavioral - dumping packages outside locker  TBA961193171000
# 4489  t2 - behavioral - dumping packages outside locker  TBA979612672000
# 5261  t2 - behavioral - dumping packages outside locker  TBA986730218000
# 5593  t2 - behavioral - dumping packages outside locker  TBA989065652000
# 6302  t2 - behavioral - dumping packages outside locker  TBA994694040000
# 6431  t2 - behavioral - dumping packages outside locker  TBA995648761000
# 6437  t2 - behavioral - dumping packages outside locker  TBA995726380000
#
#                                                    Data  \
# 122   contact id:axjnyveeiu5h0\r\n\r\nduplicate tick...
# 243   contact id: a3oljwpeeahdl8\r\n\r\nattached pod...
# 413   tier 2:da reputation - behavioral - dumping pa...
# 653   contact id:alwl71vh1rbv7\r\n\r\nduplicate tick...
# 662   contact id:a24gbltaqsghid\r\n\r\nduplicate tic...
# 682   contact id: a9ktyuhkrideo\r\n\r\nattached pod ...
# 835   contact id:a31jnjgihexwmx\r\n\r\n \r\n\r\natta...
# 1136  tba961239471000\r\nunable to read other tbas s...
# 1227  contact id: aro2x061olmps\r\n\r\nduplicate tic...
# 1228  contact id: a1twuvd9biitb\r\n\r\nduplicate tt-...
# 1726  contact id: a1600h19tkh5b2\r\n\r\nattached pod...
# 1904  additional notes added.\r\n\r\ncontact id: a21...
# 1988  delivered not received\t\r\n\r\ncontact id: a1...
# 2184  driver left packages unprotected outside the h...
# 2189  contact id: a2ayoaj7l05jsl\r\n\r\nduplicate ti...
# 2212  contact id: a2qktyt1oesr61\r\n\r\nattached pod...
# 2244  contact id:a2zl57emuuj0gh\r\n\r\nduplicate tic...
# 2658  contact id:a3pt4kuxq4a0jv\r\n\r\nduplicate tic...
# 3853  listened to customer's call. this complex has ...
# 4489  contact id:a2d7nfhg6nu76b\r\n\r\nduplicate tic...
# 5261  contact id: ao0r5tcdjpgvd\r\n\r\nattached pod ...
# 5593  contact id: a48b8m31m8a0\r\n\r\nduplicate tick...
# 6302  contact id: a19tih8sybqlha\r\n\r\nattached pod...
# 6431  contact id:a2s3lxhemu1aoy\r\n\r\nattached pod ...
# 6437  contact id: a3itaw1bltjwce\r\n\r\nduplicate ti...
#
#                                              Infraction  \
# 122   tier 2 da reputation - behavioral - dumping pa...
# 243   da reputation - behavioral - dumping package(s...
# 413   da reputation - behavioral - dumping package(s...
# 653   da reputation - behavioral - dumping package(s...
# 662   da reputation - da reputation \u2013 behaviora...
# 682   da reputation - behavioral - dumping package(s...
# 835   da reputation - behavioral - dumping package(s...
# 1136  da reputation - behavioral - dumping package(s...
# 1227  da reputation - behavioral - dumping package(s...
# 1228  da reputation - behavioral - dumping package(s...
# 1726  da reputation - behavioral - dumping package(s...
# 1904  da reputation - behavioral - dumping package(s...
# 1988  da reputation - behavioral - dumping package(s...
# 2184  da reputation - behavioral - dumping package(s...
# 2189  da reputation - behavioral - dumping package(s...
# 2212  da reputation - behavioral - dumping package(s...
# 2244  da reputation - behavioral - dumping package(s...
# 2658  da reputation - behavioral - dumping package(s...
# 3853  da reputation - behavioral - dumping package(s...
# 4489  tier 2 da reputation - behavioral - dumping pa...
# 5261  da reputation - behavioral - dumping package(s...
# 5593  tier 2 da reputation - behavioral - dumping pa...
# 6302  da reputation - behavioral - dumping package(s...
# 6431  da reputation - behavioral - dumping package(s...
# 6437  da reputation - behavioral - dumping package(s...
#
#                                      Additional_Details Infraction1  \
# 122   additional details:customer complains that dri...      locker
# 243   additional details: customer complained that t...      locker
# 413   additional details:driver left the package in ...      locker
# 653   additional details: driver delivered package t...      locker
# 662   additional details:packages left at the proper...      locker
# 682   additional details: driver left the packages o...      locker
# 835   additional details:driver left the package out...      locker
# 1136  additional details: property manager complains...      locker
# 1227  additional details: the package is suppose to ...      locker
# 1228  additional details: the unit has lockers locat...      locker
# 1726  additional details: driver dumped multiple pac...      locker
# 1904  additional details: property manager complaint...      locker
# 1988  additional details: abandoned packages in mail...      locker
# 2184  additional details: driver left packages unpro...      locker
# 2189  additional details: the driver left these pack...      locker
# 2212  additional details: packages reported for bein...      locker
# 2244  additional details:package dumped outside lock...      locker
# 2658  additional details:customer mentioned that dri...      locker
# 3853  additional details:customer says that driver a...      locker
# 4489  additional details:the property manager says t...      locker
# 5261  additional details: these packages were report...      locker
# 5593  additional details: property manager states th...      locker
# 6302  additional details: packages were dumped outsi...      locker
# 6431  additional details:package reported being dump...      locker
# 6437  additional details:  driver dumped  package in...      locker
#
#            Infraction2 First_Status  Second_Status
# 122             locker         True           True
# 243             locker         True           True
# 413             locker         True          False
# 653             locker         True          False
# 662   mailroom/leasing           NS          False
# 682             locker         True           True
# 835             locker         True          False
# 1136            locker         True           True
# 1227            locker         True           True
# 1228            locker         True          False
# 1726            locker         True          False
# 1904            locker         True           True
# 1988            locker         True           True
# 2184            locker         True           True
# 2189            locker         True           True
# 2212            locker         True           True
# 2244            locker         True           True
# 2658            locker         True           True
# 3853            locker         True          False
# 4489            locker         True           True
# 5261            locker         True          False
# 5593            locker         True          False
# 6302            locker         True           True
# 6431            locker         True          False
# 6437            locker         True           True

# %% [markdown]
# # in_or_on_a_USPS_mail_box

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('delivering in or on a usps mail box')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()


df['Second_Status']=df['Additional_Details'].str.contains('left the package in the usps mailroom|in the united state postal service|under his mailbox|inside usps mailbox|top of the usps mailbox|left the package at the mailbox|in the united state postal service|delivered it on top of mailbox|packages were found in the usps mail box|delivered to usp|found it on my mailbox|inside of usps mailbox|in usps mailbox|top of the community mail boxes|to usps mail box|in usps mail box|to a us mailbox|delivered on mailbox|left in a mail slot|in my mail box|in the usps mailbox|in our mailbox|to the usps mailbox|atop the communal mailboxes|inside mailbox|in usps mail box|in the usps mailbox|at the usps mailbox|in usps mailbox|in the customer mailbox|in the USPS mailbox|on the mailbox|in mailbox|inside a usps mail box|inside the mailbox|in the usps mail box|top of the mail box|in the mailbox|to postal mailbox|to the mailbox|to usps mailbox|inside the usps mailbox|it in my mailbox|top of the street mail box|on the usps mail box|on usps mail box|inside the mail box|on top of the usps mail box|left in a mail box|delivered to the mailbox|to customer''s mailbox|to mail box|to mailbox|in the united state postal service (usps) mail box|in united state postal service (usps) mail box|to the united state postal service (usps) mail box|to the united state postal service mail box|to the usps mailbox|top of the mailbox|in mailbox|in the post office|in the mail box|into my mail box|to usps reserved mailbox|to the usps mail box')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Delivering in or on a USPS mail box.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
# C:\Users\majidmm\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#         ShortId                                            details  \
# 939   308599217  Delivery Station (Station Code, City, State): ...
# 1226  308724073  Delivery Station (Station Code, City, State): ...
# 1280  308638501  Delivery Station (Station Code, City, State): ...
# 2430  308768795  Delivery Station (Station Code, City, State): ...
# 3070  308853392  Delivery Station (Station Code, City, State): ...
# 3526  308283952  Delivery Station (Station Code, City, State): ...
# 3574  308271461  Copy and paste the Amazon Flex delivery partne...
# 3587  308548493  Copy and paste the Amazon Flex delivery partne...
# 3588  308548036  Copy and paste the Amazon Flex delivery partne...
# 3623  308890691  Delivery Station (Station Code, City, State): ...
# 3641  308603646  Delivery Station (Station Code, City, State): ...
# 4214  308108557  Delivery Station (Station Code, City, State): ...
# 4753  308277109  Delivery Station (Station Code, City, State): ...
# 5171  308111460  Delivery Station (Station Code, City, State): ...
# 5359  308331042  Delivery Station (Station Code, City, State): ...
# 5736  308305414  Delivery Station (Station Code, City, State): ...
# 6194  308295302  Delivery Station (Station Code, City, State): ...
# 6450  308410057  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 939   t2 - package mishandling - delivering in or on...  TBA007857891000
# 1226  t2 - package mishandling - delivering in or on...  TBA009814671000
# 1280  t2 - package mishandling - delivering in or on...  TBA010356092000
# 2430  t2 - package mishandling - delivering in or on...  TBA020013448000
# 3070  t2 - package mishandling - delivering in or on...  TBA026417031000
# 3526  t2 - package mishandling - delivering in or on...  TBA779961151000
# 3574  t2 - package mishandling - delivering in or on...  TBA892656534000
# 3587  t2 - package mishandling - delivering in or on...  TBA899195299000
# 3588  t2 - package mishandling - delivering in or on...  TBA899340615000
# 3623  t2 - package mishandling - delivering in or on...  TBA922346697000
# 3641  t2 - package mishandling - delivering in or on...  TBA933474601000
# 4214  t2 - package mishandling - delivering in or on...  TBA974393835000
# 4753  t2 - package mishandling - delivering in or on...  TBA982588117000
# 5171  t2 - package mishandling - delivering in or on...  TBA986008453000
# 5359  t2 - package mishandling - delivering in or on...  TBA987370594000
# 5736  t2 - package mishandling - delivering in or on...  TBA990051521000
# 6194  t2 - package mishandling - delivering in or on...  TBA993880353000
# 6450  t2 - package mishandling - delivering in or on...  TBA995801201000
#
#                                                    Data  \
# 939   contact id: a2hrzk485mtst0\r\n\r\nattached pod...
# 1226  contact id: atnw9bw966t6j\r\n \r\nattached pod...
# 1280  contact id: awn3aomuko958\r\n\r\nattached pod ...
# 2430  **customer stated,driver left the package in t...
# 3070  contact id: a26o5bz4zp86h1\r\n\r\nduplicate ti...
# 3526  contact id: a2eiz8qqsfbm0s\r\n\r\nduplicate ti...
# 3574  da transferring correct queue,did you consult ...
# 3587  driver is a dsp-da,did you consult the availab...
# 3588  the driver is dsp-da\r\n\r\nflipping to the co...
# 3623  contact id: a2ba9a40ecbgrr\r\n \r\nduplicate t...
# 3641  contact id:a30hk5tntpiy2n\r\n\r\nduplicate tic...
# 4214  contact id:alskffez9wvj7\r\n\r\nduplicate tick...
# 4753  contact id: a1s8yzuko49ei0\r\n\r\nattached pod...
# 5171  as per contact id : avvpofnv40qyt, customer st...
# 5359  tier 2:da reputation - package mishandling - d...
# 5736  contact id:a1etgrccxqavv6\r\n\r\nduplicate tic...
# 6194  contact id:a12uh0s4too6c7\r\n\r\nduplicate tic...
# 6450  reviewed the contact id: a1x950h59hzicy, custo...
#
#                                              Infraction  \
# 939   da reputation - package mishandling - deliveri...
# 1226  da reputation - package mishandling - deliveri...
# 1280  da reputation - package mishandling - deliveri...
# 2430  da reputation - package mishandling - deliveri...
# 3070  da reputation - package mishandling - deliveri...
# 3526  da reputation - package mishandling - deliveri...
# 3574  da reputation - package mishandling - deliveri...
# 3587  da reputation - package mishandling - deliveri...
# 3588  da reputation - package mishandling - deliveri...
# 3623  da reputation - package mishandling - deliveri...
# 3641  da reputation - package mishandling - deliveri...
# 4214  tier 2 da reputation - package mishandling - d...
# 4753  da reputation - package mishandling - deliveri...
# 5171  tier 2 da reputation - package mishandling - d...
# 5359  da reputation - package mishandling - deliveri...
# 5736  da reputation - package mishandling - deliveri...
# 6194  tier 2 da reputation - package mishandling - d...
# 6450  da reputation - package mishandling - deliveri...
#
#                                      Additional_Details Infraction1  \
# 939   additional details: usps wrote to support abou...    mail box
# 1226  additional details: driver left the package in...    mail box
# 1280                                                NaN    mail box
# 2430  additional details:  customer stated,driver le...    mail box
# 3070  additional details:  customer called to inquir...    mail box
# 3526  additional details:package found in mail box, ...    mail box
# 3574  additional details:the picture submitted by th...    mail box
# 3587  additional details: driver delivered the packa...    mail box
# 3588  additional details: the picture submitted by t...    mail box
# 3623  additional details:  post master contacted ama...    mail box
# 3641  additional details:the driver did not attempt ...    mail box
# 4214  additional details:driver left the package ins...    mail box
# 4753  additional details: customer is complaining on...    mail box
# 5171  additional details: customer states , item was...    mail box
# 5359  additional details:driver delivered all the pa...    mail box
# 5736  additional details: customer mentioned that th...    mail box
# 6194  additional details:left package in mailbox, fo...    mail box
# 6450  additional details:  customer complains that t...    mail box
#
#      Infraction2 First_Status Second_Status
# 939     mail box         True         False
# 1226    mail box         True          True
# 1280    mail box         True           NaN
# 2430    mail box         True          True
# 3070    mail box         True         False
# 3526    mail box         True         False
# 3574    mail box         True          True
# 3587    mail box         True         False
# 3588    mail box         True          True
# 3623    mail box         True         False
# 3641    mail box         True         False
# 4214    mail box         True          True
# 4753    mail box         True          True
# 5171    mail box         True          True
# 5359    mail box         True          True
# 5736    mail box         True         False
# 6194    mail box         True          True
# 6450    mail box         True          True

# %% [markdown]
# # Left in Lawn

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('left in lawn')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

df['Second_Status']=df['Additional_Details'].str.contains('should not place the packages in the rain|under the tree|under the mailbox|outside his gate|front of mailbox|in the alley|by the mail box|next to the mailbox|left in the plants|walk way|near mailbox|under the mailbox|left the package in the garden|in the tree|in leaves|on planter|lawn|pond|sidewalk|grass|walkway|yard|side walk|water|bush|flower bed|left package at gate|left it in the front gate|river bed|on the ground|snow')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left_in_lawn.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)

df
# Out:
#         ShortId                                            details  \
# 391   308531212  Delivery Station (Station Code, City, State): ...
# 687   308433970  Delivery Station (Station Code, City, State): ...
# 806   308484631  Delivery Station (Station Code, City, State): ...
# 975   308437547  Delivery Station (Station Code, City, State): ...
# 1675  308634385  Delivery Station (Station Code, City, State): ...
# 1742  308716123  Delivery Station (Station Code, City, State): ...
# 1820  308629540  Delivery Station (Station Code, City, State): ...
# 2116  308764328  Delivery Station (Station Code, City, State): ...
# 2117  308637873  Delivery Station (Station Code, City, State): ...
# 2253  308747589  Delivery Station (Station Code, City, State): ...
# 2463  308758931  Delivery Station (Station Code, City, State): ...
# 2652  308754598  Delivery Station (Station Code, City, State): ...
# 3345  308900650  Delivery Station (Station Code, City, State): ...
# 3431  308908785  Delivery Station (Station Code, City, State): ...
# 3486  308968284  Delivery Station (Station Code, City, State): ...
# 3774  308740074  Delivery Station: DDT1     DSP : AAE      Date...
# 3785  308353712  Delivery Station (Station Code, City, State): ...
# 3801  307751424  Delivery Station (Station Code, City, State): ...
# 3930  307809922  Delivery Station (Station Code, City, State): ...
# 3965  307767378  Delivery Station (Station Code, City, State): ...
# 4186  308068018  Delivery Station (Station Code, City, State): ...
# 4218  308127707  Delivery Station (Station Code, City, State): ...
# 4321  308095230  Delivery Station (Station Code, City, State): ...
# 4504  308337624  Delivery Station (Station Code, City, State): ...
# 4560  308056828  Delivery Station (Station Code, City, State): ...
# 4606  308121693  Delivery Station (Station Code, City, State): ...
# 5010  308125963  Delivery Station (Station Code, City, State): ...
# 5168  308148575  Delivery Station (Station Code, City, State): ...
# 5823  308317020  Delivery Station (Station Code, City, State): ...
# 6002  308304956  Delivery Station (Station Code, City, State): ...
# 6055  308394143  Delivery Station (Station Code, City, State): ...
# 6263  308290529  Delivery Station (Station Code, City, State): ...
# 6380  308295259  Delivery Station (Station Code, City, State): ...
# 6832  308500999  Delivery Station (Station Code, City, State): ...
# 6979  308356483  Delivery Station (Station Code, City, State): ...
#
#                                    root_cause              tid  \
# 391   t2 - package mishandling - left in lawn  TBA003327065000
# 687   t2 - package mishandling - left in lawn  TBA005577694000
# 806   t2 - package mishandling - left in lawn  TBA006628219000
# 975   t2 - package mishandling - left in lawn  TBA008075945000
# 1675  t2 - package mishandling - left in lawn  TBA013440535000
# 1742  t2 - package mishandling - left in lawn  TBA013954835000
# 1820  t2 - package mishandling - left in lawn  TBA014408601000
# 2116  t2 - package mishandling - left in lawn  TBA016997557000
# 2117  t2 - package mishandling - left in lawn  TBA017000503000
# 2253  t2 - package mishandling - left in lawn  TBA018429512000
# 2463  t2 - package mishandling - left in lawn  TBA020300159000
# 2652  t2 - package mishandling - left in lawn  TBA021825099000
# 3345  t2 - package mishandling - left in lawn  TBA029264418000
# 3431  t2 - package mishandling - left in lawn  TBA030462342000
# 3486  t2 - package mishandling - left in lawn  TBA033028430000
# 3774  t2 - package mishandling - left in lawn  TBA956990063000
# 3785  t2 - package mishandling - left in lawn  TBA957845605000
# 3801  t2 - package mishandling - left in lawn  TBA959270362000
# 3930  t2 - package mishandling - left in lawn  TBA964888087000
# 3965  t2 - package mishandling - left in lawn  TBA966710652000
# 4186  t2 - package mishandling - left in lawn  TBA973706734000
# 4218  t2 - package mishandling - left in lawn  TBA974516482000
# 4321  t2 - package mishandling - left in lawn  TBA977068056000
# 4504  t2 - package mishandling - left in lawn  TBA979808412000
# 4560  t2 - package mishandling - left in lawn  TBA980754497000
# 4606  t2 - package mishandling - left in lawn  TBA981307731000
# 5010  t2 - package mishandling - left in lawn  TBA984780574000
# 5168  t2 - package mishandling - left in lawn  TBA985995453000
# 5823  t2 - package mishandling - left in lawn  TBA990982767000
# 6002  t2 - package mishandling - left in lawn  TBA992424973000
# 6055  t2 - package mishandling - left in lawn  TBA992830305000
# 6263  t2 - package mishandling - left in lawn  TBA994424235000
# 6380  t2 - package mishandling - left in lawn  TBA995259028000
# 6832  t2 - package mishandling - left in lawn  TBA998905740000
# 6979  t2 - package mishandling - left in lawn  TBA999980964000
#
#                                                    Data  \
# 391   contact id:a2m45etq7h3wzc\r\n\r\nduplicate tic...
# 687   contact id: a6ao62ni8aej4\r\n\r\nattached pod ...
# 806   contact id:a1cy79pyuqx7in\r\n\r\nduplicate tic...
# 975   contact id: a3i9cqe866gzdl\r\n\r\nduplicate ti...
# 1675  contact id: a1orio4s9doki\r\n\r\nattached pod ...
# 1742  contact id: a37itdlit5wfkj\r\n\r\nattached pod...
# 1820  contact id: a2ti67diaave0w\r\n\r\nduplicate ti...
# 2116  contact id:a2vfi203jezenw\r\n\r\nduplicate tic...
# 2117  contact id: a29esyo3h51pnj\r\n\r\nattached pod...
# 2253  contact id: a25c06dptos5bn\r\n\r\nduplicate ti...
# 2463  contact id: a29pbnjh4u1pao\r\n\r\nattached pod...
# 2652  **as per call recordings customer stated,drive...
# 3345  contact id: a1f4chc369ywu\r\n\r\nduplicate tic...
# 3431                                  no data available
# 3486                                  no data available
# 3774                                  no data available
# 3785  contact id: a10co5k376cjy6\r\n\r\nduplicate ti...
# 3801  contact id: a2iaac0pyx7gsk\r\n\r\nduplicate ti...
# 3930  contact id:ahj3x1u14se6j\r\n\r\nduplicate tick...
# 3965  contact id: a8ih7x9cn4wcb\r\n\r\nattached pod ...
# 4186  contact id:a150a3xxzh71jn\r\n\r\n \r\n\r\natta...
# 4218  contact id:a3pjfz5x5xx3tm\r\n\r\nattached pod ...
# 4321  contact id: a1kwhiq7uh1pi7\r\n\r\nattached pod...
# 4504  contact id:a1sa15z9i8y3x5\r\n\r\nduplicate tic...
# 4560  contact id:acg90fv8vjeok\r\n\r\nduplicate tick...
# 4606  the driver left one of my packages under the m...
# 5010  contact id: afa2fsj1pv0wr\r\n\r\nduplicate tic...
# 5168  hello sdla courier service inc.,\r\n\r\nyou ar...
# 5823  did you consult the available (tm/rs) on the f...
# 6002  as per pod the package was left on lawn\r\ncon...
# 6055  contact id:aw0avwequ0ygh\r\n\r\nattached pod (...
# 6263  did you consult the available (tm/rs) on the f...
# 6380  contact id: a18prugraz6fss\r\n\r\nduplicate ti...
# 6832  contact id: a2ssho16ibzsw2\r\n\r\nattached pod...
# 6979  tier 2:da reputation - package mishandling - p...
#
#                                              Infraction  \
# 391   tier 2 da reputation - package mishandling - p...
# 687   da reputation - package mishandling - package(...
# 806   da reputation - package mishandling - package(...
# 975   da reputation - package mishandling - package(...
# 1675  da reputation - package mishandling - package(...
# 1742  da reputation - package mishandling - package(...
# 1820  tier 2 da reputation - package mishandling - p...
# 2116  da reputation - package mishandling - package(...
# 2117  da reputation - package mishandling - package(...
# 2253  da reputation - package mishandling - package(...
# 2463  da reputation - package mishandling - package(...
# 2652  da reputation - package mishandling - package(...
# 3345  da reputation - package mishandling - package(...
# 3431                                             ailabl
# 3486                                             ailabl
# 3774                                             ailabl
# 3785  tier 2 da reputation - package mishandling - p...
# 3801  da reputation - package mishandling - package(...
# 3930  \u2013 christopher schmidt\r\n \t\r\nhello ves...
# 3965  da reputation - package mishandling - package(...
# 4186  da reputation - package mishandling - package(...
# 4218  da reputation - package mishandling - package(...
# 4321  da reputation - package mishandling - package(...
# 4504  da reputation - package mishandling - package(...
# 4560  da reputation - package mishandling - package(...
# 4606  da reputation - package mishandling - package(...
# 5010  tier 2 da reputation - package mishandling - p...
# 5168  tier 2 da reputation - package mishandling - p...
# 5823  da reputation - package mishandling - package(...
# 6002  da reputation - package mishandling - package(...
# 6055  da reputation - package mishandling - package(...
# 6263  da reputation - package mishandling - package(...
# 6380  tier 2 da reputation - package mishandling - p...
# 6832  da reputation - package mishandling - package(...
# 6979  da reputation - package mishandling - package(...
#
#                                      Additional_Details Infraction1  \
# 391   additional details:customer stated that the dr...        lawn
# 687   additional details: the driver left the order ...        lawn
# 806   additional details:customer is saying that the...        lawn
# 975   additional details: da left the package in the...        lawn
# 1675  additional details: customer says that the dri...        lawn
# 1742                                                NaN        lawn
# 1820  additional details: driver tossed the package ...        lawn
# 2116  additional details:customer says that he drive...        lawn
# 2117  additional details: driver did not deliver pkg...        lawn
# 2253  additional details: customer complains that th...        lawn
# 2463  additional details: the customer contacted sup...        lawn
# 2652  additional details:  customer stated,driver di...        lawn
# 3345  additional details: driver left the customer p...        lawn
# 3431                                                NaN        lawn
# 3486                                                NaN        lawn
# 3774                                                NaN        lawn
# 3785  additional details:  customer states -my packa...        lawn
# 3801  additional details: customer complained driver...        lawn
# 3930  additional details:  package was scanned as de...        lawn
# 3965  additional details: driver left the package on...        lawn
# 4186  additional details:driver left the package in ...        lawn
# 4218  additional details:driver didn't follow instru...        lawn
# 4321  additional details: customer is complaining on...        lawn
# 4504  additional details:deliveries continue to be l...        lawn
# 4560  additional details: customer says that the dri...        lawn
# 4606  additional details:the driver left one of my p...        lawn
# 5010  additional details: driver left the package in...        lawn
# 5168  additional details:  customer escalated the is...        lawn
# 5823  additional details: driver left the package in...        lawn
# 6002  additional details:the package was left on law...        lawn
# 6055  additional details:not following instructions ...        lawn
# 6263  additional details: the driver delivered the i...        lawn
# 6380  additional details:customer stated that the dr...        lawn
# 6832  additional details: customer states package wa...        lawn
# 6979  additional details:the package was on the grou...        lawn
#
#      Infraction2 First_Status Second_Status
# 391         lawn         True          True
# 687         lawn         True          True
# 806         lawn         True          True
# 975         lawn         True          True
# 1675        lawn         True          True
# 1742        lawn         True           NaN
# 1820        lawn         True          True
# 2116        lawn         True          True
# 2117        lawn         True          True
# 2253        lawn         True          True
# 2463        lawn         True          True
# 2652        lawn         True          True
# 3345        lawn         True          True
# 3431         NaN           NS           NaN
# 3486         NaN           NS           NaN
# 3774         NaN           NS           NaN
# 3785        lawn         True          True
# 3801         NaN           NS          True
# 3930        lawn         True         False
# 3965        lawn         True          True
# 4186        lawn         True          True
# 4218        lawn         True         False
# 4321        lawn         True          True
# 4504        lawn         True          True
# 4560        lawn         True          True
# 4606        lawn         True          True
# 5010        lawn         True         False
# 5168        lawn         True          True
# 5823        lawn         True          True
# 6002        lawn         True          True
# 6055        lawn         True          True
# 6263        lawn         True         False
# 6380        lawn         True          True
# 6832        lawn         True         False
# 6979        lawn         True          True

# %% [markdown]
# # Left in road-curb

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('package mishandling - left in road/curb')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list=('pkg out in the street','left the packages near the road','outside of the gate','left them near road','left the package on sidewalk','left the package at the gate','left in the alley','near the road','left the package at gate','by the road','next to a telephone pole','by the mailbox','side the road','on the side walk','public sidewalk','by sidewalk','left out in the street','side of the street','next to the street','side of the road','beside the road','walkway','Package outside the Gate','at the main street','at the street','by the gate near the street','by the rain','by the street','curb','curb of the street','exposed to rain','from the street',
    'in the rain','left in the street','left on the ground in front of my house near the street','left the package almost in the street','left the package at street','left the package down the street','left the package in the street','middle of a busy street','middle of the street','of the rain',
    'on the curb in street','on the ground near the street','on the main street','on the road','on the sidewalk','on the street','outside a busy street','outside the gate','package to the street','raining')


df['attribute'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df['Second_Status']=df['Additional_Details'].str.contains('pkg out in the street|left the packages near the road|outside of the gate|left them near road|left the package on sidewalk|left the package at the gate|left in the alley|near the road|left the package at gate|by the road|next to a telephone pole|by the mailbox|side the road|on the side walk|public sidewalk|by sidewalk|left out in the street|side of the street|next to the street|side of the road|beside the road|walkway|curb|in the rain|on the road|exposed to rain|of the rain|raining|by the rain|outside a busy street|on the street|middle of the street|at the street|left the package down the street  |left the package almost in the street|Package outside the Gate| by the street|on the main street | on the curb in street  |package to the street|on the sidewalk|at the main street  |outside the gate|from the street|left on the ground in front of my house near the street|by the street|curb of the street|left the package in the street|on the ground near the street|by the gate near the street|left the package at street|middle of a busy street|left in the street')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left_in_road_curb.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 44    308293787  Delivery Station (Station Code, City, State): ...
# 88    308326362  Delivery Station (Station Code, City, State): ...
# 139   308324204  Delivery Station (Station Code, City, State): ...
# 259   308524207  Delivery Station (Station Code, City, State): ...
# 264   308334468  Delivery Station (Station Code, City, State): ...
# 276   308766517  Delivery Station (Station Code, City, State): ...
# 564   308432759  Delivery Station (Station Code, City, State): ...
# 772   308438191  Delivery Station (Station Code, City, State): ...
# 828   308607358  Delivery Station (Station Code, City, State): ...
# 1274  308635777  Delivery Station (Station Code, City, State): ...
# 1558  308631664  Delivery Station (Station Code, City, State): ...
# 1561  424252245  Delivery Station (Station Code, City, State): ...
# 1569  308640636  Delivery Station (Station Code, City, State): ...
# 1681  308621809  Delivery Station (Station Code, City, State): ...
# 2008  308759768  Delivery Station (Station Code, City, State): ...
# 2048  308748818  Delivery Station (Station Code, City, State): ...
# 2208  308758947  Delivery Station (Station Code, City, State): ...
# 2358  308725587  Delivery Station (Station Code, City, State): ...
# 2384  308756970  Delivery Station (Station Code, City, State): ...
# 3274  308881064  Delivery Station (Station Code, City, State): ...
# 3601  307745964  Delivery Station: DBL1     DSP : SHEF      Dat...
# 3770  307662373  Delivery Station (Station Code, City, State): ...
# 3981  308104274  Delivery Station (Station Code, City, State): ...
# 3993  308288592  Delivery Station (Station Code, City, State): ...
# 4052  307938789  Delivery Station (Station Code, City, State): ...
# 4056  307912850  Delivery Station (Station Code, City, State): ...
# 4145  308292709  Delivery Station (Station Code, City, State): ...
# 4198  307911318  Delivery Station (Station Code, City, State): ...
# 4383  308055535  Delivery Station (Station Code, City, State): ...
# 4472  308124946  Delivery Station (Station Code, City, State): ...
# 4522  308043185  Delivery Station (Station Code, City, State): ...
# 4532  308424582  Delivery Station (Station Code, City, State): ...
# 4860  308105044  Delivery Station (Station Code, City, State): ...
# 4867  308122734  Delivery Station (Station Code, City, State): ...
# 4985  308114999  Delivery Station (Station Code, City, State): ...
# 5196  308200474  Delivery Station (Station Code, City, State): ...
# 5290  308121839  Delivery Station (Station Code, City, State): ...
# 5776  308408846  Delivery Station (Station Code, City, State): ...
# 6018  308891089  Delivery Station (Station Code, City, State): ...
# 6152  308188635  Delivery Station (Station Code, City, State): ...
# 6207  308501665  Delivery Station (Station Code, City, State): ...
# 6515  308329325  Delivery Station (Station Code, City, State): ...
# 6816  308302393  Delivery Station (Station Code, City, State): ...
# 6824  308297864  Delivery Station (Station Code, City, State): ...
# 6828  308402875  Delivery Station (Station Code, City, State): ...
# 6880  308327221  Delivery Station (Station Code, City, State): ...
#
#                                         root_cause              tid  \
# 44    t2 - package mishandling - left in road/curb  TBA000298229000
# 88    t2 - package mishandling - left in road/curb  TBA000610526000
# 139   t2 - package mishandling - left in road/curb  TBA001040524000
# 259   t2 - package mishandling - left in road/curb  TBA002003822000
# 264   t2 - package mishandling - left in road/curb  TBA002041116000
# 276   t2 - package mishandling - left in road/curb  TBA002117977000
# 564   t2 - package mishandling - left in road/curb  TBA004726453000
# 772   t2 - package mishandling - left in road/curb  TBA006397972000
# 828   t2 - package mishandling - left in road/curb  TBA006778252000
# 1274  t2 - package mishandling - left in road/curb  TBA010297143000
# 1558  t2 - package mishandling - left in road/curb  TBA012556038000
# 1561  t2 - package mishandling - left in road/curb  TBA012593423000
# 1569  t2 - package mishandling - left in road/curb  TBA012645781000
# 1681  t2 - package mishandling - left in road/curb  TBA013476789000
# 2008  t2 - package mishandling - left in road/curb  TBA016066103000
# 2048  t2 - package mishandling - left in road/curb  TBA016399505000
# 2208  t2 - package mishandling - left in road/curb  TBA018007187000
# 2358  t2 - package mishandling - left in road/curb  TBA019359580000
# 2384  t2 - package mishandling - left in road/curb  TBA019551733000
# 3274  t2 - package mishandling - left in road/curb  TBA028359706000
# 3601  t2 - package mishandling - left in road/curb  TBA905387446000
# 3770  t2 - package mishandling - left in road/curb  TBA956708556000
# 3981  t2 - package mishandling - left in road/curb  TBA967120878000
# 3993  t2 - package mishandling - left in road/curb  TBA967809674000
# 4052  t2 - package mishandling - left in road/curb  TBA969502448000
# 4056  t2 - package mishandling - left in road/curb  TBA969675302000
# 4145  t2 - package mishandling - left in road/curb  TBA972589417000
# 4198  t2 - package mishandling - left in road/curb  TBA974037759000
# 4383  t2 - package mishandling - left in road/curb  TBA978004993000
# 4472  t2 - package mishandling - left in road/curb  TBA979348154000
# 4522  t2 - package mishandling - left in road/curb  TBA980160027000
# 4532  t2 - package mishandling - left in road/curb  TBA980326974000
# 4860  t2 - package mishandling - left in road/curb  TBA983536344000
# 4867  t2 - package mishandling - left in road/curb  TBA983606560000
# 4985  t2 - package mishandling - left in road/curb  TBA984573870000
# 5196  t2 - package mishandling - left in road/curb  TBA986233661000
# 5290  t2 - package mishandling - left in road/curb  TBA986925940000
# 5776  t2 - package mishandling - left in road/curb  TBA990467646000
# 6018  t2 - package mishandling - left in road/curb  TBA992533061000
# 6152  t2 - package mishandling - left in road/curb  TBA993554992000
# 6207  t2 - package mishandling - left in road/curb  TBA993950106000
# 6515  t2 - package mishandling - left in road/curb  TBA996320141000
# 6816  t2 - package mishandling - left in road/curb  TBA998718747000
# 6824  t2 - package mishandling - left in road/curb  TBA998817972000
# 6828  t2 - package mishandling - left in road/curb  TBA998870846000
# 6880  t2 - package mishandling - left in road/curb  TBA999320246000
#
#                                                    Data  \
# 44    contact id: a2gwm249jie6pj\r\n\r\nduplicate tt...
# 88    contact id:a2ptf7hjlzcwhm\r\n\r\nattached pod ...
# 139   contact id: a3767g3drdn3qa\r\n\r\nattached pod...
# 259   contact id: a2lw9lii9n3rqw\r\n\r\nattached pod...
# 264   contact id: a13hxx7ymimuw7\r\n\r\nduplicate ti...
# 276   as per the contact information a2lw598bg8d7zv,...
# 564   contact id: a330olw10puqdt\r\n\r\nattached pod...
# 772   contact id:ayz72lhoisn00\r\n\r\nduplicate tick...
# 828   contact id:  ac7by5uj4pri0\r\n\r\nduplicate ti...
# 1274  contact id: aib52uf6bsxqt\r\n\r\nattached pod ...
# 1558  contact id: a10829nsa01r5x\r\n\r\nattached pod...
# 1561  contact id: a3gabn57i6u97c\r\n\r\nattached pod...
# 1569  contact id: a9fu30u3ew2s7\r\n\r\nattached pod ...
# 1681  contact id: a15ngyztfomhrq\r\n\r\nduplicate ti...
# 2008  contact id: a3i5klk85ldsix\r\n\r\nduplicate ti...
# 2048  contact id: aqj73ks1meazj\r\n\r\nattached pod ...
# 2208  as per call record: customer reports da left t...
# 2358  contact id: a3in1gxdpcb7j5\r\n\r\nduplicate ti...
# 2384  contact id:a28627smp9x4s1\r\n\r\nduplicate tic...
# 3274  contact id:aeses90jb03f1\r\n\r\nattached pod (...
# 3601  did you consult the available (tm/rs) on the f...
# 3770  reviewed contact a1jiqmmw602fmg customer state...
# 3981  contact id:a1m72tlp6tc10b\r\n\r\nduplicate tic...
# 3993  contact id:a2m41jy1r78mu5\r\n\r\nattached pod ...
# 4052  contact id:axbtptieon06k\r\n\r\nduplicate tick...
# 4056  contact id: a196uvvekv4ff7\r\n\r\nduplicate ti...
# 4145  contact id:a2kc76qjm2wken\r\n\r\nduplicate tic...
# 4198  contact id: a9mkcxe9cnc1s\r\n\r\nduplicate tic...
# 4383  contact id:ajaeowepzkdpj\r\n\r\nduplicate tick...
# 4472  contact id: avyjmh58c20za\r\n\r\nduplicate tt-...
# 4522  contact id:a1kztrj6lufso5\r\n\r\nduplicate tic...
# 4532  contact id: a23zmwpljud242\r\n\r\nattached pod...
# 4860  contact id:azfcczr8d6bwp\r\n\r\nduplicate tick...
# 4867  contact id:a19k9bfrpbiehx\r\n\r\n \r\n\r\natta...
# 4985  contact id: a2ndyqupwelv5g\r\n\r\nattached pod...
# 5196  contact id:a321g0a85hvsdj\r\n\r\nduplicate tic...
# 5290  contact id: a31txfe4fpeohy\r\n\r\nduplicate ti...
# 5776  item was left out front of a business on a mai...
# 6018  contact id:a24a5uywdgy1c5\r\n\r\nattached pod ...
# 6152  not sure whether the mail box is usps. anyway ...
# 6207  contact id:ae2q1un61gd4l\r\n\r\nduplicate tick...
# 6515  contact id: a1xdsor4s7o947\r\n\r\nattached pod...
# 6816  contact id:a9b3awo3ohsg6\r\n\r\nduplicate tick...
# 6824  contact id:a1j2f82xczxrvu\r\n\r\nduplicate tic...
# 6828  contact id: aq8ru45qeupd5\r\n\r\nattached pod ...
# 6880  contact id: a195w75nlj7zmx\r\n\r\nattached pod...
#
#                                              Infraction  \
# 44    da reputation - package mishandling - package(...
# 88    da reputation - package mishandling - package(...
# 139   da reputation - package mishandling - package(...
# 259   da reputation - package mishandling - package(...
# 264   da reputation - package mishandling - package(...
# 276   da reputation - package mishandling - package(...
# 564   da reputation - package mishandling - package(...
# 772   da reputation - package mishandling - package(...
# 828   da reputation - package mishandling - package(...
# 1274  da reputation - package mishandling - package(...
# 1558  da reputation - package mishandling - package(...
# 1561  da reputation - package mishandling - package(...
# 1569  da reputation - package mishandling - package(...
# 1681  da reputation - package mishandling - package(...
# 2008  da reputation - package mishandling - package(...
# 2048  da reputation - package mishandling - package(...
# 2208  da reputation - package mishandling - package(...
# 2358  da reputation - package mishandling - package(...
# 2384  tier 2 da reputation - package mishandling - p...
# 3274  da reputation - package mishandling - package(...
# 3601  da reputation - package mishandling - package(...
# 3770  da reputation - package mishandling - package(...
# 3981  da reputation - package mishandling - package(...
# 3993  da reputation - package mishandling - package(...
# 4052  da reputation - package mishandling - package(...
# 4056  tier 2 da reputation - package mishandling - p...
# 4145  da reputation - package mishandling - package(...
# 4198  da reputation - package mishandling - package(...
# 4383  da reputation - package mishandling - package(...
# 4472  da reputation - package mishandling - package(...
# 4522  da reputation - package mishandling - package(...
# 4532  da reputation - package mishandling - package(...
# 4860  da reputation - package mishandling - package(...
# 4867  da reputation - package mishandling - package(...
# 4985  da reputation - package mishandling - package(...
# 5196  tier 2 da reputation - package mishandling - p...
# 5290  da reputation - package mishandling - package(...
# 5776  da reputation - package mishandling - package(...
# 6018  da reputation - package mishandling - package(...
# 6152  da reputation - package mishandling - package(...
# 6207  da reputation - package mishandling - package(...
# 6515  da reputation - package mishandling - package(...
# 6816  da reputation - package mishandling - package(...
# 6824  tier 2 da reputation - package mishandling - p...
# 6828  da reputation - package mishandling - package(...
# 6880  da reputation - package mishandling - package(...
#
#                                      Additional_Details   Infraction1  \
# 44    additional details: the package was left by th...  left in road
# 88    additional details:cx feed back: embarrassing ...  left in road
# 139   additional details: driver left package on the...  left in road
# 259   additional details: a resident found the follo...  left in road
# 264   additional details: the driver left the packag...  left in road
# 276   additional details: customer is complaining th...  left in road
# 564   additional details: as per customer driver lef...  left in road
# 772   additional details:customer is saying that the...  left in road
# 828   additional details: customer that the driver d...  left in road
# 1274  additional details: driver delivered the packa...  left in road
# 1558  additional details: customer is mad and furiou...  left in road
# 1561  additional details: driver left the package in...  left in road
# 1569  additional details:  customer says that driver...  left in road
# 1681  additional details: customer is calling to rep...  left in road
# 2008  additional details: driver tagged this package...  left in road
# 2048  additional details: customer stated that \the ...  left in road
# 2208  additional details: customer reports da left t...  left in road
# 2358  additional details: delivery person did not le...  left in road
# 2384  additional details:the customer says the drive...  left in road
# 3274  additional details:driver left package on side...  left in road
# 3601  additional details: das are not supposed to le...  left in road
# 3770  additional details: customer complained driver...  left in road
# 3981  additional details:customer complain that the ...  left in road
# 3993  additional details:the package was left in the...  left in road
# 4052  additional details: customer reported that pac...  left in road
# 4056  additional details: package was left at a back...  left in road
# 4145  additional details: the driver left by the str...  left in road
# 4198  additional details: customer has complained th...  left in road
# 4383  additional details:although it said package wa...  left in road
# 4472  additional details: the driver left the packag...  left in road
# 4522  additional details:the customer states that th...  left in road
# 4532  additional details: driver left the package ou...  left in road
# 4860  additional details: customer complaining that ...  left in road
# 4867  additional details:driver left the package on ...  left in road
# 4985  additional details: the driver delivered the p...  left in road
# 5196  additional details:customer stated that the dr...  left in road
# 5290  additional details: customer has complained th...  left in road
# 5776  additional details:item was left out front of ...  left in road
# 6018  additional details:the driver tossed the packa...  left in road
# 6152  additional details: customer complains that th...  left in road
# 6207  additional details:da delivered the package at...  left in road
# 6515  additional details: customer instructed to del...  left in road
# 6816  additional details:the driver left the package...  left in road
# 6824  additional details: the driver left the packag...  left in road
# 6828  additional details: customer  have issues with...  left in road
# 6880  additional details: driver left the packages o...  left in road
#
#      Infraction2 First_Status                       attribute  Second_Status
# 44           NaN           NS                             NaN          False
# 88           NaN           NS                             NaN          False
# 139          NaN           NS                 on the sidewalk           True
# 259          NaN           NS                             NaN          False
# 264          NaN           NS                outside the gate           True
# 276          NaN           NS                             NaN          False
# 564          NaN           NS                             NaN          False
# 772          NaN           NS            middle of the street           True
# 828          NaN           NS                            curb           True
# 1274         NaN           NS                             NaN          False
# 1558         NaN           NS             outside of the gate           True
# 1561         NaN           NS                             NaN          False
# 1569         NaN           NS                            curb           True
# 1681         NaN           NS                             NaN          False
# 2008         NaN           NS                             NaN          False
# 2048         NaN           NS                   on the street           True
# 2208         NaN           NS                         walkway           True
# 2358         NaN           NS                             NaN          False
# 2384         NaN           NS                   on the street           True
# 3274         NaN           NS                             NaN          False
# 3601         NaN           NS                             NaN          False
# 3770         NaN           NS  left the package in the street           True
# 3981         NaN           NS                   on the street           True
# 3993         NaN           NS                         walkway           True
# 4052         NaN           NS                  by the mailbox           True
# 4056         NaN           NS                             NaN          False
# 4145         NaN           NS                   by the street           True
# 4198         NaN           NS   on the ground near the street           True
# 4383         NaN           NS                   by the street           True
# 4472         NaN           NS                             NaN          False
# 4522         NaN           NS              side of the street           True
# 4532         NaN           NS                   on the street           True
# 4860         NaN           NS                             NaN          False
# 4867         NaN           NS                 on the sidewalk           True
# 4985        lawn           NS              next to the street           True
# 5196         NaN           NS                     on the road           True
# 5290         NaN           NS                   near the road           True
# 5776         NaN           NS                             NaN          False
# 6018         NaN           NS                             NaN          False
# 6152         NaN           NS                             NaN          False
# 6207         NaN           NS                             NaN          False
# 6515         NaN           NS                     on the road           True
# 6816         NaN           NS                             NaN          False
# 6824         NaN           NS                             NaN          False
# 6828         NaN           NS                             NaN          False
# 6880         NaN           NS                     on the road           True

# %% [markdown]
# # Left on near garbage or recycling

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('left on/near garbage or recycling')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list_1=('left','dump','put','deliver')

word_list_2=('dumpster','garbage','trash','recycling bin')


df['attribute_1'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list_1)),expand=False).str.lower()
df['attribute_2'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list_2)),expand=False).str.lower()

df['Second_Status']=(df['Additional_Details'].str.contains('left|dump|put|deliver'))&(df['Additional_Details'].str.contains('trash|dumpster|garbage|recycling bin'))

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_near garbage or recycling.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 105   308497264  Delivery Station (Station Code, City, State): ...
# 131   308326538  Delivery Station (Station Code, City, State): ...
# 350   308451131  Delivery Station (Station Code, City, State): ...
# 355   308406429  Delivery Station (Station Code, City, State): ...
# 382   308496750  Delivery Station (Station Code, City, State): ...
# 928   308632026  Delivery Station (Station Code, City, State): ...
# 1197  308756116  Delivery Station (Station Code, City, State): ...
# 1378  308863119  Delivery Station (Station Code, City, State): ...
# 1977  308870497  Delivery Station (Station Code, City, State): ...
# 2174  308623027  Delivery Station (Station Code, City, State): ...
# 2180  308756835  Delivery Station (Station Code, City, State): ...
# 2195  308739997  Delivery Station (Station Code, City, State): ...
# 2475  308873184  Delivery Station (Station Code, City, State): ...
# 2568  308801962  Delivery Station (Station Code, City, State): ...
# 3102  308892819  Delivery Station (Station Code, City, State): ...
# 3235  308923753  Delivery Station (Station Code, City, State): ...
# 3457  308894854  Delivery Station (Station Code, City, State): ...
# 3691  307516897  Delivery Station (Station Code, City, State): ...
# 3701  307786248  Delivery Station (Station Code, City, State): ...
# 3971  308042535  Delivery Station (Station Code, City, State): ...
# 4262  308047843  Delivery Station (Station Code, City, State): ...
# 4566  308188513  Delivery Station (Station Code, City, State): ...
# 4638  308131334  Delivery Station (Station Code, City, State): ...
# 5105  308124992  Delivery Station (Station Code, City, State): ...
# 5273  308189038  Delivery Station (Station Code, City, State): ...
# 5274  308130588  Delivery Station (Station Code, City, State): ...
# 5316  308112415  Delivery Station (Station Code, City, State): ...
# 6184  308597737  Delivery Station (Station Code, City, State): ...
# 6505  308388895  Delivery Station (Station Code, City, State): ...
# 6833  308594133  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 105   t2 - package mishandling - left on/near garbag...  TBA000738285000
# 131   t2 - package mishandling - left on/near garbag...  TBA000939064000
# 350   t2 - package mishandling - left on/near garbag...  TBA002920995000
# 355   t2 - package mishandling - left on/near garbag...  TBA002983070000
# 382   t2 - package mishandling - left on/near garbag...  TBA003258724000
# 928   t2 - package mishandling - left on/near garbag...  TBA007803436000
# 1197  t2 - package mishandling - left on/near garbag...  TBA009501070000
# 1378  t2 - package mishandling - left on/near garbag...  TBA011203263000
# 1977  t2 - package mishandling - left on/near garbag...  TBA015818474000
# 2174  t2 - package mishandling - left on/near garbag...  TBA017594200000
# 2180  t2 - package mishandling - left on/near garbag...  TBA017698132000
# 2195  t2 - package mishandling - left on/near garbag...  TBA017867865000
# 2475  t2 - package mishandling - left on/near garbag...  TBA020474717000
# 2568  t2 - package mishandling - left on/near garbag...  TBA021258492000
# 3102  t2 - package mishandling - left on/near garbag...  TBA026815046000
# 3235  t2 - package mishandling - left on/near garbag...  TBA027885827000
# 3457  t2 - package mishandling - left on/near garbag...  TBA030815005000
# 3691  t2 - package mishandling - left on/near garbag...  TBA945774929000
# 3701  t2 - package mishandling - left on/near garbag...  TBA947154910000
# 3971  t2 - package mishandling - left on/near garbag...  TBA966868902000
# 4262  t2 - package mishandling - left on/near garbag...  TBA975580859000
# 4566  t2 - package mishandling - left on/near garbag...  TBA980839675000
# 4638  t2 - package mishandling - left on/near garbag...  TBA981576698000
# 5105  t2 - package mishandling - left on/near garbag...  TBA985525453000
# 5273  t2 - package mishandling - left on/near garbag...  TBA986825763000
# 5274  t2 - package mishandling - left on/near garbag...  TBA986830670000
# 5316  t2 - package mishandling - left on/near garbag...  TBA987105987000
# 6184  t2 - package mishandling - left on/near garbag...  TBA993813776000
# 6505  t2 - package mishandling - left on/near garbag...  TBA996245315000
# 6833  t2 - package mishandling - left on/near garbag...  TBA998918655000
#
#                                                    Data  \
# 105   contact id: ab7z0tpbqrk5j\r\n\r\nattached pod ...
# 131   contact id: a3dci775w36h2u\r\n\r\nattached pod...
# 350   contact id: ax68bitol0lms\r\n\r\nattached pod ...
# 355   contact id: a1hzddnyt10gis\r\n\r\nduplicate ti...
# 382   contact id:a3kmix5fomrdgg\r\n\r\nduplicate tic...
# 928   contact id: amkar2ncdfxn4\r\n\r\nduplicate tic...
# 1197  contact id: a60mjxz2hu9kx\r\n\r\nattached pod ...
# 1378  contact id: anvqzjzw022l\r\n\r\nduplicate tick...
# 1977  customer says that the package was delivered s...
# 2174  contact id: a2pk38p0vhxtb1\r\n\r\nattached pod...
# 2180  contact id:a3mcz0t3dayx7n\r\n\r\nduplicate tic...
# 2195  contact id: ax7z0hds04bg0\r\n\r\nduplicate tic...
# 2475  contact id:a1fq93e9h7dt3\r\n\r\nduplicate tick...
# 2568  contact id: a12ly8rntva0qn\r\n\r\nattached pod...
# 3102  contact id:a1y1khlwmh77w3\r\n\r\nduplicate tic...
# 3235                                  no data available
# 3457  contact id: a17fczfdpzbbgz\r\n\r\nattached pod...
# 3691                                  no data available
# 3701  contact id: a1kzyycgbx4fpm\r\n\r\nduplicate ti...
# 3971                                  no data available
# 4262  contact id:a2m4l9kvlcf5oa\r\n\r\nduplicate tic...
# 4566  contact id: axdscpdmpila2\r\n\r\nattached pod ...
# 4638  contact id:a1nc6p3mg1ltoc\r\n\r\nduplicate tic...
# 5105  contact id: a1jom25ui8aixw\r\n\r\nduplicate ti...
# 5273  contact id: a1s1p5wsrgxitq\r\n \r\nduplicate t...
# 5274  contact id:a1nzwh6hmzpp8r\r\n\r\nduplicate tic...
# 5316  contact id:a2nz9aes0w4pwv\r\n\r\nduplicate tic...
# 6184  contact id:a1bm3a0a913mes\r\n\r\nduplicate tic...
# 6505  contact id:aaglclgat10h4\r\n\r\nduplicate tick...
# 6833  contact id: awu9glcqxp5a7\r\n\r\nattached pod ...
#
#                                              Infraction  \
# 105   da reputation - package mishandling - package(...
# 131   da reputation - package mishandling - package(...
# 350   da reputation - package mishandling - package(...
# 355   tier 2 da reputation - package mishandling - p...
# 382   da reputation - package mishandling - package(...
# 928   da reputation - package mishandling - package(...
# 1197  da reputation - package mishandling - package(...
# 1378  da reputation - package mishandling - package(...
# 1977  da reputation - package mishandling - package(...
# 2174  da reputation - package mishandling - package(...
# 2180  da reputation - package mishandling - package(...
# 2195  da reputation - package mishandling - package(...
# 2475  da reputation - package mishandling - package(...
# 2568  da reputation - package mishandling - package(...
# 3102  da reputation - package mishandling - package(...
# 3235                                             ailabl
# 3457  da reputation - package mishandling - package(...
# 3691                                             ailabl
# 3701  tier 2 da reputation - package mishandling - p...
# 3971                                             ailabl
# 4262  da reputation - package mishandling - package(...
# 4566  da reputation - package mishandling - package(...
# 4638  tier 2 da reputation - package mishandling - p...
# 5105  da reputation - package mishandling - package(...
# 5273  da reputation - package mishandling - package(...
# 5274  da reputation - package mishandling - package(...
# 5316  tier 2 da reputation - package mishandling - p...
# 6184  tier 2 da reputation - package mishandling - p...
# 6505  da reputation - package mishandling - package(...
# 6833  da reputation - package mishandling - package(...
#
#                                      Additional_Details      Infraction1  \
# 105   additional details: package surround by my sno...  on/near garbage
# 131   additional details: driver left the package ne...  on/near garbage
# 350   additional details: driver leave the package i...  on/near garbage
# 355   additional details: driver left my packages in...  on/near garbage
# 382   additional details:package was left near garba...  on/near garbage
# 928   additional details: customer leaves in the 3rd...  on/near garbage
# 1197  additional details: package was scan as delive...  on/near garbage
# 1378  additional details:  delivery was awful. throw...  on/near garbage
# 1977  additional details:customer says that the pack...  on/near garbage
# 2174  additional details: delivery associate left th...  on/near garbage
# 2180  additional details:the customer stated that th...  on/near garbage
# 2195  additional details: the customer state the dri...  on/near garbage
# 2475  additional details:customer says that  deliver...  on/near garbage
# 2568  additional details: customer said that driver ...  on/near garbage
# 3102  additional details:customer is complaining tha...  on/near garbage
# 3235                                                NaN  on/near garbage
# 3457  additional details: driver left the package on...  on/near garbage
# 3691                                                NaN  on/near garbage
# 3701  additional details: package was left out with ...  on/near garbage
# 3971                                                NaN  on/near garbage
# 4262  additional details:customer says that the driv...  on/near garbage
# 4566  additional details: driver left customers pack...  on/near garbage
# 4638  additional details:customer stated that the dr...  on/near garbage
# 5105  additional details: da left the package near t...  on/near garbage
# 5273  additional details: customer called stating th...  on/near garbage
# 5274  additional details:da delivered the packages o...  on/near garbage
# 5316  additional details:customer complaining -\my o...  on/near garbage
# 6184  additional details:customer stated that he was...  on/near garbage
# 6505  additional details:package was placed between ...  on/near garbage
# 6833  additional details: the customer is complainin...  on/near garbage
#
#           Infraction2 First_Status attribute_1 attribute_2  Second_Status
# 105   on/near garbage         True         NaN       trash          False
# 131   on/near garbage         True        left     garbage           True
# 350   on/near garbage         True         NaN       trash          False
# 355   on/near garbage         True        left       trash           True
# 382   on/near garbage         True        left     garbage           True
# 928   on/near garbage         True        left       trash           True
# 1197  on/near garbage         True     deliver       trash           True
# 1378  on/near garbage         True     deliver     garbage           True
# 1977  on/near garbage         True     deliver       trash           True
# 2174  on/near garbage         True     deliver       trash           True
# 2180  on/near garbage         True        left    dumpster           True
# 2195  on/near garbage         True     deliver       trash           True
# 2475  on/near garbage         True     deliver       trash           True
# 2568  on/near garbage         True        left       trash           True
# 3102  on/near garbage         True        left     garbage           True
# 3235              NaN           NS         NaN         NaN          False
# 3457  on/near garbage         True        left       trash           True
# 3691              NaN           NS         NaN         NaN          False
# 3701  on/near garbage         True        left       trash           True
# 3971              NaN           NS         NaN         NaN          False
# 4262  on/near garbage         True        left     garbage           True
# 4566  on/near garbage         True        left     garbage           True
# 4638  on/near garbage         True        left         NaN          False
# 5105  on/near garbage         True        left       trash           True
# 5273  on/near garbage         True        left         NaN          False
# 5274  on/near garbage         True     deliver     garbage           True
# 5316  on/near garbage         True     deliver       trash           True
# 6184  on/near garbage         True        left     garbage           True
# 6505  on/near garbage         True         NaN     garbage          False
# 6833  on/near garbage         True         NaN       trash          False

# %% [markdown]
# # Package Mishandling - Throwing

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('package mishandling - throwing/tossing')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list=('chunked','flip','kick','threw','throw','toss')

df['attribute'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list)),expand=False).str.lower()


df['Second_Status']=df['Additional_Details'].str.contains('chunked|kick|toss|throw|threw|flip')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Package Mishandling - Throwing.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 20    308455464  Delivery Station (Station Code, City, State): ...
# 22    308331832  Delivery Station (Station Code, City, State): ...
# 31    308336630  Delivery Station (Station Code, City, State): ...
# 64    308492104  Delivery Station (Station Code, City, State): ...
# 89    308492160  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6708  308329525  Delivery Station (Station Code, City, State): ...
# 6801  308301738  Delivery Station (Station Code, City, State): ...
# 6876  308573146  Delivery Station (Station Code, City, State): ...
# 6890  308331872  Delivery Station: DTO1    Contact ID: AOE5LQX8...
# 6894  308306393  Delivery Station (Station Code, City, State): ...
#
#                                        root_cause              tid  \
# 20    t2 - package mishandling - throwing/tossing  TBA000144188000
# 22    t2 - package mishandling - throwing/tossing  TBA000158966000
# 31    t2 - package mishandling - throwing/tossing  TBA000225218000
# 64    t2 - package mishandling - throwing/tossing  TBA000454421000
# 89    t2 - package mishandling - throwing/tossing  TBA000619008000
# ...                                           ...              ...
# 6708  t2 - package mishandling - throwing/tossing  TBA997801574000
# 6801  t2 - package mishandling - throwing/tossing  TBA998595832000
# 6876  t2 - package mishandling - throwing/tossing  TBA999279375000
# 6890  t2 - package mishandling - throwing/tossing              NaN
# 6894  t2 - package mishandling - throwing/tossing  TBA999397049000
#
#                                                    Data  \
# 20    contact id:a2s64pg6vi658h\r\n\r\nduplicate tic...
# 22    **customer has seen driver tossing the package...
# 31    contact id:a1xexqr4c1nu6x\r\n\r\nattached pod ...
# 64    contact id: aac2iezf9paeh\r\n\r\nduplicate tic...
# 89    contact id: a2vezpli17oku4\r\n\r\nduplicate ti...
# ...                                                 ...
# 6708  contact id:a34tgdjtl1izyi\r\n\r\nduplicate tic...
# 6801  contact id:a17tljqy1xoz1r\r\n\r\nduplicate tic...
# 6876  contact id: akp0k42d0ya1a\r\n\r\nduplicate tic...
# 6890  contact id: a2xijyuj5ke41h\r\n\r\nduplicate ti...
# 6894  contact id:a7232qd73ph2a\r\n\r\nduplicate tick...
#
#                                              Infraction  \
# 20    da reputation - package mishandling - throwing...
# 22    da reputation - package mishandling - throwing...
# 31    da reputation - package mishandling - throwing...
# 64    da reputation - package mishandling - throwing...
# 89    da reputation - package mishandling - throwing...
# ...                                                 ...
# 6708  da reputation - package mishandling - throwing...
# 6801  tier 2 da reputation - package mishandling - t...
# 6876  da reputation - package mishandling - throwing...
# 6890  tier 2- da reputation - package mishandling - ...
# 6894  tier 2 da reputation - package mishandling - t...
#
#                                      Additional_Details Infraction1  \
# 20    additional details:customer is complaining tha...    throwing
# 22    additional details:  customer has seen driver ...    throwing
# 31    additional details:customer has a camera at ho...    throwing
# 64    additional details: customer reported that the...    throwing
# 89    additional details: customer saw the driver th...    throwing
# ...                                                 ...         ...
# 6708  additional details:the driver threw the packag...    throwing
# 6801  additional details:the customer says the drive...    throwing
# 6876  additional details:  package was tossed into t...    throwing
# 6890  additional details:  customer states that pack...    throwing
# 6894  additional details:customer stated \he stood a...    throwing
#
#      Infraction2 First_Status attribute Second_Status
# 20      throwing         True      toss          True
# 22      throwing         True      toss          True
# 31      throwing         True     throw          True
# 64      throwing         True     threw          True
# 89      throwing         True     throw          True
# ...          ...          ...       ...           ...
# 6708    throwing         True     threw          True
# 6801    throwing         True     threw          True
# 6876    throwing         True      toss          True
# 6890    throwing         True     throw          True
# 6894    throwing         True     threw          True
#
# [222 rows x 12 columns]

# %% [markdown]
# # Package Mishandling Left in driveway

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('left in driveway')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()


df['Second_Status']=(df['Additional_Details'].str.contains('leave|kept|put|drop|leaving|stash|left|deliver|dumped|leave|abandon|sent'))&(df['Additional_Details'].str.contains('package|item|box| '))&(df['Additional_Details'].str.contains('against|under|unsafe|outside|at|middle|between|in|by|behind|of|on'))&(df['Additional_Details'].str.contains('car|dirt|windshield|roof of the truck|drive way|car tyre|two vehicles|garage|driveway|top of customer''s tire|under car|under car''s tyre|under customers tyre|behind the car|on car tyre|under customer''s tire|under the car|under car''s tire|parking lot|on customer''s husband''s car|under the car''s tyre|on the car trunk|left in a vulnerable state|outside the gate|on car|on top of a car|under customers truck|hood of the truck|truck tire|top of a car'))


df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left in driveway.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 147   308493663  Delivery Station (Station Code, City, State): ...
# 157   308420902  Delivery Station (Station Code, City, State): ...
# 255   308422220  Delivery Station (Station Code, City, State): ...
# 349   308620193  Delivery Station (Station Code, City, State): ...
# 354   308449541  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6355  308309014  Delivery Station (Station Code, City, State): ...
# 6381  308291136  Delivery Station (Station Code, City, State): ...
# 6632  308399877  Delivery Station (Station Code, City, State): ...
# 6680  308619482  Delivery Station (Station Code, City, State): ...
# 6803  308338005  Delivery Station (Station Code, City, State): ...
#
#                                        root_cause              tid  \
# 147   t2 - package mishandling - left in driveway  TBA001087839000
# 157   t2 - package mishandling - left in driveway  TBA001155235000
# 255   t2 - package mishandling - left in driveway  TBA001979189000
# 349   t2 - package mishandling - left in driveway  TBA002908190000
# 354   t2 - package mishandling - left in driveway  TBA002974798000
# ...                                           ...              ...
# 6355  t2 - package mishandling - left in driveway  TBA995054690000
# 6381  t2 - package mishandling - left in driveway  TBA995284108000
# 6632  t2 - package mishandling - left in driveway  TBA997173208000
# 6680  t2 - package mishandling - left in driveway  TBA997568803000
# 6803  t2 - package mishandling - left in driveway  TBA998632088000
#
#                                                    Data  \
# 147   contact id: a121vz0dbsstga\r\n\r\nattached pod...
# 157   as per contact id:  i want to know why my pack...
# 255   note : package was left at the driveway alerti...
# 349   contact id: a12j543wqys4hk\r\n\r\nattached pod...
# 354   contact id: a3udl3hcjhujl3\r\n\r\nduplicate ti...
# ...                                                 ...
# 6355  contact id:aaj59kkw9vhav\r\n\r\nattached pod (...
# 6381  contact id: a2wp2ws9osm6lh\r\n\r\nduplicate ti...
# 6632  contact id:a3sa2vabbh81pi\r\n\r\nattached pod ...
# 6680  contact id: a3e60zflgb8qt2\r\n\r\nduplicate ti...
# 6803  contact id: a38utqh0175mhg\r\n\r\nduplicate ti...
#
#                                              Infraction  \
# 147   da reputation - package mishandling - package(...
# 157   da reputation - package mishandling - package(...
# 255   da reputation - package mishandling - package(...
# 349   da reputation - package mishandling - package(...
# 354   da reputation - package mishandling - package(...
# ...                                                 ...
# 6355  da reputation - package mishandling - package(...
# 6381  da reputation - package mishandling - package(...
# 6632  da reputation - package mishandling - package(...
# 6680  tier 2 da reputation - package mishandling - p...
# 6803  da reputation - package mishandling - package(...
#
#                                      Additional_Details       Infraction1  \
# 147   additional details: customer is complaining on...  left in driveway
# 157   additional details: i want to know why my pack...  left in driveway
# 255   additional details: package was left at the dr...  left in driveway
# 349   additional details: driver left the package at...  left in driveway
# 354   additional details: driver left the packages o...  left in driveway
# ...                                                 ...               ...
# 6355  additional details: driver left the package ne...  left in driveway
# 6381  additional details: the driver dropped her box...  left in driveway
# 6632  additional details:driver is delivering to the...  left in driveway
# 6680  additional details: driver dumped her package ...  left in driveway
# 6803  additional details:the packages were left at t...  left in driveway
#
#            Infraction2 First_Status  Second_Status
# 147   left in driveway         True           True
# 157   left in driveway         True           True
# 255   left in driveway         True           True
# 349   left in driveway         True           True
# 354   left in driveway         True           True
# ...                ...          ...            ...
# 6355  left in driveway         True           True
# 6381  left in driveway         True           True
# 6632  left in driveway         True           True
# 6680  left in driveway         True           True
# 6803  left in driveway         True           True
#
# [74 rows x 11 columns]

# %% [markdown]
# # property_damage

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('property damage')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list=('damage','destroy','rut','hit','tear','tire','pulled off','stain','tore','leak','knock','dent','damaging','ditch','tracks','ruin','mess','mud','break','broke','stuck','drove all over','driver drove','driven into','scratch','grass','hole','torn','ran over','drove over')


df['attribute'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df['Second_Status']=df['Additional_Details'].str.contains('banged|ripped|crush|damage|destroy|rut|hit|tear|tire|pulled off|stain|tore|leak|knock|dent|damaging|ditch|tracks|ruin|mess|mud|break|broke|stuck|drove all over|driver drove|driven into|scratch|grass|hole|torn|ran over|drove over')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_property_damage.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)

df
# Out:
#         ShortId                                            details  \
# 30    308579958  Who reported the incident?: Customer / Witness...
# 43    308320503  Who reported the incident?: Customer / Witness...
# 62    308444996  Delivery Station (Station Code, City, State): ...
# 84    308451463  Who reported the incident?: Customer / Witness...
# 85    308322346  Who reported the incident?: Customer / Witness...
# ...         ...                                                ...
# 6861  308901631  Who reported the incident?: Customer / Witness...
# 6870  308425773  Who reported the incident?: Customer / Witness...
# 6891  308397391  Who reported the incident?: Customer / Witness...
# 6911  308301830  Who reported the incident?: Customer / Witness...
# 6941  308333448  Who reported the incident?: Customer / Witness...
#
#                                           root_cause              tid  \
# 30    t2 - unsafe driving behavior - property damage  TBA000220533000
# 43    t2 - unsafe driving behavior - property damage  TBA000291753000
# 62    t2 - unsafe driving behavior - property damage  TBA000439007000
# 84    t2 - unsafe driving behavior - property damage  TBA000600216000
# 85    t2 - unsafe driving behavior - property damage  TBA000608560000
# ...                                              ...              ...
# 6861  t2 - unsafe driving behavior - property damage  TBA999105201000
# 6870  t2 - unsafe driving behavior - property damage  TBA999209944000
# 6891  t2 - unsafe driving behavior - property damage  TBA999384529000
# 6911  t2 - unsafe driving behavior - property damage  TBA999539354000
# 6941  t2 - unsafe driving behavior - property damage              NaN
#
#                                                    Data  \
# 30    contact id:a1eccsi2suhajv\r\n\r\nduplicate tic...
# 43    contact id: a31qn68mk7s3ms\r\n\r\nattached pod...
# 62    contact id:a1635rub7axffo\r\n\r\nduplicate tic...
# 84    contact id:a20ywsm07630tp\r\n\r\nduplicate tic...
# 85    contact id: a3ffugt23wca00\r\n\r\nduplicate ti...
# ...                                                 ...
# 6861                                  no data available
# 6870  contact id: a303fgxsfkac0k\r\n\r\nduplicate ti...
# 6891  contact id:a1exw1cxohsa0h\r\n\r\n \r\n\r\natta...
# 6911  contact id:a3mxcuuhr1n7uy\r\n\r\nduplicate tic...
# 6941  contact id: a3r1w41kwd9l6s\r\n\r\nattached pod...
#
#                                              Infraction  \
# 30    da reputation - unsafe driving behavior - prop...
# 43    da reputation - unsafe driving behavior - prop...
# 62    da reputation - unsafe driving behavior - prop...
# 84    da reputation - unsafe driving behavior - prop...
# 85    da reputation - unsafe driving behavior - prop...
# ...                                                 ...
# 6861                                             ailabl
# 6870  tier 2 - da reputation - unsafe driving behavi...
# 6891  da reputation - unsafe driving behavior - prop...
# 6911  tier 2 da reputation - unsafe driving behavior...
# 6941  da reputation - unsafe driving behavior - prop...
#
#                                      Additional_Details      Infraction1  \
# 30    additional details:customer complains the driv...  property damage
# 43    additional details: the driver backed up in an...  property damage
# 62    additional details:customer is saying that the...  property damage
# 84    additional details:the driver did not utilise ...  property damage
# 85    additional details: driver got stuck in custom...  property damage
# ...                                                 ...              ...
# 6861                                                NaN  property damage
# 6870  additional details: the driver got stuck on th...  property damage
# 6891  additional details:driver spun the vehicle on ...  property damage
# 6911  additional details:the customer says the drive...  property damage
# 6941  additional details: the driver was backing up ...  property damage
#
#           Infraction2 First_Status     attribute Second_Status
# 30    property damage         True      ran over          True
# 43    property damage         True           NaN         False
# 62    property damage         True  driver drove          True
# 84    property damage         True         stuck          True
# 85    property damage         True         stuck          True
# ...               ...          ...           ...           ...
# 6861              NaN           NS           NaN           NaN
# 6870  property damage         True         stuck          True
# 6891  property damage         True           NaN         False
# 6911  property damage         True  driver drove          True
# 6941  property damage         True          dent          True
#
# [272 rows x 12 columns]

# %% [markdown]
# # Scanned business closed

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('scanned business closed')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()



df['Second_Status']=df['Additional_Details'].str.contains('when the school was open|address is the post office and it was not closed but driver incorrectly scanned as business closed|business closed for an apartment|business was not closed when driver attempted the delivery|driver scanned as business closed when the business open|business and the front door was open|business is very open|business was closed but it was open|business closed while it''s opened at the time of delivery|business closed when it was open|waiting for this order|business is still open|business is open|business was open|business is not closed|there are people|building is open|business hours have been updated')

# df['Scan_Status']=df['Reason'].str.contains('BUSINESS_CLOSED')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Scanned business closed.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId                                            details  \
# 533   308459893  Delivery Station (Station Code, City, State): ...
# 1999  308777052  Delivery Station (Station Code, City, State): ...
# 2187  308779621  Delivery Station (Station Code, City, State): ...
# 2276  308923954  Delivery Station (Station Code, City, State): ...
# 2856  308922355  Delivery Station (Station Code, City, State): ...
# 2877  308911973  Delivery Station (Station Code, City, State): ...
# 3007  308908937  Delivery Station (Station Code, City, State): ...
# 3084  308908687  Delivery Station (Station Code, City, State): ...
# 3155  308915522  Delivery Station (Station Code, City, State): ...
# 3725  307577893  ****Station submitted TTs will need to have da...
# 3891  307906193  Delivery Station (Station Code, City, State): ...
# 4035  308029249  Delivery Station (Station Code, City, State): ...
# 4063  308276424  Delivery Station (Station Code, City, State): ...
# 4140  307917056  Delivery Station (Station Code, City, State): ...
# 4161  308046681  Delivery Station (Station Code, City, State): ...
# 4244  308338234  Delivery Station (Station Code, City, State): ...
# 4388  308094539  Delivery Station (Station Code, City, State): ...
# 5854  308339437  Delivery Station (Station Code, City, State): ...
# 5960  308181358  Delivery Station (Station Code, City, State): ...
# 6211  308304848  Delivery Station (Station Code, City, State): ...
# 6621  308325437  Delivery Station (Station Code, City, State): ...
# 6653  308305636  Delivery Station (Station Code, City, State): ...
# 6716  308406537  Copy and paste the Amazon Flex delivery partne...
# 6767  308343390  Delivery Station (Station Code, City, State): ...
# 6912  308293596  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 533   t2 - behavioral - scanned business closed (bc)...  TBA004434307000
# 1999  t2 - behavioral - scanned business closed (bc)...  TBA016007601000
# 2187  t2 - behavioral - scanned business closed (bc)...  TBA017758615000
# 2276  t2 - behavioral - scanned business closed (bc)...  TBA018699897000
# 2856  t2 - behavioral - scanned business closed (bc)...  TBA023713623000
# 2877  t2 - behavioral - scanned business closed (bc)...  TBA023897223000
# 3007  t2 - behavioral - scanned business closed (bc)...  TBA025630832000
# 3084  t2 - behavioral - scanned business closed (bc)...  TBA026525053000
# 3155  t2 - behavioral - scanned business closed (bc)...  TBA027249334000
# 3725  t2 - behavioral - scanned business closed (bc)...  TBA951247007000
# 3891  t2 - behavioral - scanned business closed (bc)...  TBA962931105000
# 4035  t2 - behavioral - scanned business closed (bc)...  TBA969106035000
# 4063  t2 - behavioral - scanned business closed (bc)...  TBA969904391000
# 4140  t2 - behavioral - scanned business closed (bc)...  TBA972436858000
# 4161  t2 - behavioral - scanned business closed (bc)...  TBA973134472000
# 4244  t2 - behavioral - scanned business closed (bc)...  TBA975123005000
# 4388  t2 - behavioral - scanned business closed (bc)...  TBA978089284000
# 5854  t2 - behavioral - scanned business closed (bc)...  TBA991263778000
# 5960  t2 - behavioral - scanned business closed (bc)...  TBA992131573000
# 6211  t2 - behavioral - scanned business closed (bc)...  TBA993971523000
# 6621  t2 - behavioral - scanned business closed (bc)...  TBA997092834000
# 6653  t2 - behavioral - scanned business closed (bc)...  TBA997296274000
# 6716  t2 - behavioral - scanned business closed (bc)...  TBA997868085000
# 6767  t2 - behavioral - scanned business closed (bc)...  TBA998249187000
# 6912  t2 - behavioral - scanned business closed (bc)...  TBA999546223000
#
#                                                    Data  \
# 533   contact id: a2rn7pjir127cy\r\n\r\nduplicate ti...
# 1999  contact id:a1u8qzryjjwxi0\r\n\r\nduplicate tic...
# 2187  contact id:a3bnws8955kaok\r\n\r\nduplicate tic...
# 2276                                  no data available
# 2856                                  no data available
# 2877                                  no data available
# 3007                                  no data available
# 3084  contact id: a1172pavuhvvjl\r\n\r\nattached pod...
# 3155                                  no data available
# 3725  packages marked bc at 9:19pm, i see that the a...
# 3891  contact id : a1221jtkttdqco\r\n\r\nattached po...
# 4035                                  no data available
# 4063  contact id:a2065uihzjbbxg\r\n\r\n\r\nduplicate...
# 4140  contact id:arjwjiqzav04u\r\n\r\nduplicate tick...
# 4161  contact id:a1ho7jg59qkf0i\r\n\r\n \r\n\r\natta...
# 4244  driver scanned \xb4business closed\xb4,when bu...
# 4388  contact id:a2twwphhd9d6un\r\n\r\n \r\n\r\natta...
# 5854  tier 2:da reputation - behavioral - scanned bu...
# 5960  driver marked as business closed customer stat...
# 6211  **checked with scan co-ordinates and customer'...
# 6621  contact id:a37bke5abfmoga\r\n\r\nduplicate tic...
# 6653  contact id: ao012nyu4f762\r\n\r\nduplicate tic...
# 6716  driver found as dsp da in am console, hence fl...
# 6767  contact id: a38b2ubs2dn04x\r\n\r\nattached pod...
# 6912  notes: was unable to send the e-mail to the pr...
#
#                                              Infraction  \
# 533   da reputation - behavioral - scanned business ...
# 1999  da reputation - behavioral - scanned business ...
# 2187  da reputation - behavioral - scanned business ...
# 2276                                             ailabl
# 2856                                             ailabl
# 2877                                             ailabl
# 3007                                             ailabl
# 3084  da reputation - behavioral - scanned business ...
# 3155                                             ailabl
# 3725  da reputation - behavioral - scanned business ...
# 3891  da reputation - behavioral - scanned business ...
# 4035                                             ailabl
# 4063  da reputation - behavioral - scanned business ...
# 4140  da reputation - behavioral - scanned business ...
# 4161  da reputation - behavioral - scanned business ...
# 4244  da reputation - behavioral - scanned business ...
# 4388  da reputation - behavioral - scanned business ...
# 5854  da reputation - behavioral - scanned business ...
# 5960  da reputation - behavioral - scanned business ...
# 6211  da reputation - behavioral - scanned business ...
# 6621  da reputation - behavioral - scanned business ...
# 6653  da reputation - behavioral - scanned business ...
# 6716  da reputation - behavioral - scanned business ...
# 6767  da reputation - behavioral - scanned business ...
# 6912  tier 2 da reputation - behavioral - scanned bu...
#
#                                      Additional_Details      Infraction1  \
# 533   additional details: driver marked the package ...  business closed
# 1999  additional details:the driver marked business ...  business closed
# 2187  additional details:customer states business wa...  business closed
# 2276                                                NaN  business closed
# 2856                                                NaN  business closed
# 2877                                                NaN  business closed
# 3007                                                NaN  business closed
# 3084  additional details: customer says that the bus...  business closed
# 3155                                                NaN  business closed
# 3725  additional details: residential packages false...  business closed
# 3891                                                NaN  business closed
# 4035                                                NaN  business closed
# 4063  additional details: driver didn't make to deli...  business closed
# 4140  additional details:cx watched driver arrive an...  business closed
# 4161  additional details:driver scanned the package ...  business closed
# 4244  additional details:driver scanned \xb4business...  business closed
# 4388  additional details:driver scanned business clo...  business closed
# 5854  additional details: package was marked as deli...  business closed
# 5960  additional details:driver marked as business c...  business closed
# 6211  additional details: customer stated driver inc...  business closed
# 6621  additional details:da marked as business close...  business closed
# 6653  additional details: customer complains that th...  business closed
# 6716  additional details:the customer said that he b...  business closed
# 6767  additional details: business address does not ...  business closed
# 6912  additional details:customer complains that dri...  business closed
#
#           Infraction2 First_Status Second_Status
# 533   business closed         True          True
# 1999  business closed         True          True
# 2187  business closed         True          True
# 2276              NaN           NS           NaN
# 2856              NaN           NS           NaN
# 2877              NaN           NS           NaN
# 3007              NaN           NS           NaN
# 3084  business closed         True         False
# 3155              NaN           NS           NaN
# 3725  business closed         True         False
# 3891  business closed         True           NaN
# 4035              NaN           NS           NaN
# 4063  business closed         True         False
# 4140  business closed         True         False
# 4161  business closed         True          True
# 4244  business closed         True          True
# 4388  business closed         True          True
# 5854  business closed         True         False
# 5960  business closed         True          True
# 6211  business closed         True          True
# 6621  business closed         True          True
# 6653  business closed         True         False
# 6716  business closed         True          True
# 6767  business closed         True         False
# 6912  business closed         True          True

# %% [markdown]
# # Scanned unable to access

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('scanned unable to access')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()



df['Second_Status']=df['Additional_Details'].str.contains('does not require any code|nothing to block access to the home|residential address|residential properties|falsely marked packages uta|customer provide driver with code driver scan customer package as unable to access|customer mentioned there is no dog, fence, gate nor construction going|no access code in the address|no access needed|there is no access code|there are no access codes|address is residential|never attempted to deliver|access is not needed|no access code required|no access code needed|effort was not made|unlocked door|no access barrier|notes has access code|provided instruction|not need any access code|door is always open|no access required|no access problem|no access code that is needed|no access code is required|residential home|no access code to front door')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Scanned unable to access.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId                                            details  \
# 193   308577966  Delivery Station (Station Code, City, State): ...
# 306   308858402  Delivery Station (Station Code, City, State): ...
# 579   308425153  Delivery Station (Station Code, City, State): ...
# 1109  308616131  Delivery Station (Station Code, City, State): ...
# 1353  308645110  Delivery Station (Station Code, City, State): ...
# 1360  308633027  Delivery Station (Station Code, City, State): ...
# 1615  308613917  Delivery Station (Station Code, City, State): ...
# 2383  308756464  Delivery Station (Station Code, City, State): ...
# 2519  308768767  Copy and paste the Amazon Flex delivery partne...
# 2530  308766742  Delivery Station (Station Code, City, State): ...
# 2553  308775128  Delivery Station (Station Code, City, State): ...
# 4164  307936741  Delivery Station (Station Code, City, State): ...
# 4759  308131805  Delivery Station (Station Code, City, State): ...
# 4830  308174044  Delivery Station (Station Code, City, State): ...
# 4847  308115731  Delivery Station (Station Code, City, State): ...
# 5115  308121805  Delivery Station (Station Code, City, State): ...
# 5424  308440382  Delivery Station (Station Code, City, State): ...
# 6789  308326226  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 193   t2 - behavioral - scanned unable to access (ut...  TBA001559230000
# 306   t2 - behavioral - scanned unable to access (ut...  TBA002460034000
# 579   t2 - behavioral - scanned unable to access (ut...  TBA004898912000
# 1109  t2 - behavioral - scanned unable to access (ut...  TBA008858283000
# 1353  t2 - behavioral - scanned unable to access (ut...  TBA011035978000
# 1360  t2 - behavioral - scanned unable to access (ut...  TBA011076643000
# 1615  t2 - behavioral - scanned unable to access (ut...  TBA013037138000
# 2383  t2 - behavioral - scanned unable to access (ut...  TBA019551131000
# 2519  t2 - behavioral - scanned unable to access (ut...  TBA020924449000
# 2530  t2 - behavioral - scanned unable to access (ut...  TBA020999815000
# 2553  t2 - behavioral - scanned unable to access (ut...  TBA021204802000
# 4164  t2 - behavioral - scanned unable to access (ut...  TBA973199146000
# 4759  t2 - behavioral - scanned unable to access (ut...  TBA982608504000
# 4830  t2 - behavioral - scanned unable to access (ut...  TBA983231387000
# 4847  t2 - behavioral - scanned unable to access (ut...  TBA983413516000
# 5115  t2 - behavioral - scanned unable to access (ut...  TBA985655452000
# 5424  t2 - behavioral - scanned unable to access (ut...  TBA987819826000
# 6789  t2 - behavioral - scanned unable to access (ut...  TBA998478792000
#
#                                                    Data  \
# 193   contact id: a1zmg79vqwyghc\r\n\r\nduplicate ti...
# 306   contact id:  a37h7ajmmqwgfx\r\n\r\nattached po...
# 579   contact id:a2kusb612pokq2\r\n\r\nduplicate tic...
# 1109  note:- driver marked the package as uta at the...
# 1353  contact id: ao6o3trrxph3\r\n\r\nduplicate tick...
# 1360  contact id: a30vl4c6s0h3dj\r\n\r\nduplicate ti...
# 1615  **customer stated there is no access required ...
# 2383  contact id:a2owv58kro2mtq\r\n\r\nduplicate tic...
# 2519  dspda. hence flipping for better assistance.,c...
# 2530  contact id:a3id1in5200emj\r\n\r\n \r\n\r\natta...
# 2553  contact id: a2vmj4be466aoq\r\n\r\nduplicate ti...
# 4164  contact id: a3qibk1w4kher8\r\n\r\nattached pod...
# 4759  contact id:a3vpzxkl2q1pyx\r\n\r\nduplicate tic...
# 4830  contact id: a32b7013yw6cd3\r\n\r\nattached pod...
# 4847  contact id: a2jn1fk44hvday\r\n\r\nduplicate ti...
# 5115  contact id: a2hya77dwl111y\r\n\r\nduplicate ti...
# 5424  contact id: a3d5gtnjwawz23\r\n\r\nattached pod...
# 6789  contact id:a2p8da90jjw3ci\r\n\r\nduplicate tic...
#
#                                              Infraction  \
# 193   da reputation \u2013 behavioral \u2013 scanned...
# 306   da reputation \u2013 behavioral \u2013 scanned...
# 579   da reputation \u2013 behavioral \u2013 scanned...
# 1109  da reputation \u2013 behavioral \u2013 scanned...
# 1353  tier 2 da reputation \u2013 behavioral \u2013 ...
# 1360  da reputation \u2013 behavioral \u2013 scanned...
# 1615  da reputation \u2013 behavioral \u2013 scanned...
# 2383  da reputation \u2013 behavioral \u2013 scanned...
# 2519  da reputation \u2013 behavioral \u2013 scanned...
# 2530  da reputation \u2013 behavioural \u2013 scanne...
# 2553  da reputation \u2013 behavioral \u2013 scanned...
# 4164  da reputation \u2013 behavioral \u2013 scanned...
# 4759  tier 2 da reputation \u2013 behavioral \u2013 ...
# 4830  da reputation \u2013 behavioral \u2013 scanned...
# 4847  tier 2 da reputation \u2013 behavioral \u2013 ...
# 5115  da reputation \u2013 behavioral \u2013 scanned...
# 5424  da reputation \u2013 behavioral \u2013 scanned...
# 6789  da reputation \u2013 behavioral \u2013 scanned...
#
#                                      Additional_Details       Infraction1  \
# 193   additional details: driver marked uta at custo...  unable to access
# 306   additional details: customer is complaining on...  unable to access
# 579   additional details: customer complaining that ...  unable to access
# 1109  additional details: \r\ncustomer stated that t...  unable to access
# 1353  additional details: driver marked the scan as ...  unable to access
# 1360  additional details:driver scanned as unable to...  unable to access
# 1615  additional details:  customer stated there is ...  unable to access
# 2383  additional details:this driver marked the pack...  unable to access
# 2519  additional details: customer reported that thi...  unable to access
# 2530  additional details:driver scanned the package ...  unable to access
# 2553  additional details:  the customer called in be...  unable to access
# 4164  additional details:  driver scanned as deliver...  unable to access
# 4759  additional details:customer complains that dri...  unable to access
# 4830  additional details: no access code needed, but...  unable to access
# 4847  additional details: driver marked the scan as ...  unable to access
# 5115  additional details: customer has complained th...  unable to access
# 5424  additional details: customer reported that the...  unable to access
# 6789  additional details: customer complains that th...  unable to access
#
#            Infraction2 First_Status  Second_Status
# 193   unable to access         True           True
# 306   unable to access         True           True
# 579   unable to access         True           True
# 1109  unable to access         True           True
# 1353  unable to access         True           True
# 1360  unable to access         True           True
# 1615  unable to access         True           True
# 2383  unable to access         True          False
# 2519  unable to access         True           True
# 2530  unable to access         True           True
# 2553  unable to access         True          False
# 4164  unable to access         True           True
# 4759  unable to access         True           True
# 4830  unable to access         True           True
# 4847  unable to access         True           True
# 5115  unable to access         True          False
# 5424  unable to access         True          False
# 6789  unable to access         True           True

# %% [markdown]
# # unattended in mailroom

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('behavioral - left packages unattended in mailroom/leasing')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list_1=('abandon','dump','outside','unattended','left')

word_list_2=('leasing','lobby','mail box','mail room','mail-room','mailbox','mailroom','parcel room')

df['attribute_1'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list_1)), 
                        expand=False).str.lower()

df['attribute_2'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list_2)), 
                        expand=False).str.lower()

df['Second_Status']=(df['Additional_Details'].str.contains('deliver|left|unattended|dump|outside|abandon|leave|top'))&(df['Additional_Details'].str.contains('office|leasing|mailroom|mail room|mailbox|mail box|parcel room|mail-room|lobby'))

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_unattended_in_mailroom.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 268   308432263  Delivery Station (Station Code, City, State): ...
# 467   308603966  Delivery Station (Station Code, City, State): ...
# 1432  308587722  Delivery Station (Station Code, City, State): ...
# 1586  308781827  Delivery Station (Station Code, City, State): ...
# 1598  308622846  Delivery Station (Station Code, City, State): ...
# 1650  424254506  Delivery Station (Station Code, City, State): ...
# 1868  308738194  Delivery Station (Station Code, City, State): ...
# 2223  308779023  Delivery Station (Station Code, City, State): ...
# 2247  308764858  Delivery Station (Station Code, City, State): ...
# 2326  308767182  Delivery Station (Station Code, City, State): ...
# 3489  308956992  Delivery Station (Station Code, City, State): ...
# 3749  308405466  Delivery Station (Station Code, City, State): ...
# 3827  308038977  Delivery Station (Station Code, City, State): ...
# 3945  308285469  Delivery Station (Station Code, City, State): ...
# 4171  307907641  Delivery Station (Station Code, City, State): ...
# 4291  308200063  Delivery Station (Station Code, City, State): ...
# 4537  308121458  Delivery Station (Station Code, City, State): ...
# 5081  308110695  Delivery Station (Station Code, City, State): ...
# 5547  308277034  Delivery Station (Station Code, City, State): ...
# 6053  308268105  Delivery Station (Station Code, City, State): ...
# 6306  308413594  Delivery Station (Station Code, City, State): ...
# 6668  308886455  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 268   t2 - behavioral - left packages unattended in ...  TBA002061139000
# 467   t2 - behavioral - left packages unattended in ...  TBA003944664000
# 1432  t2 - behavioral - left packages unattended in ...  TBA011611532000
# 1586  t2 - behavioral - left packages unattended in ...  TBA012847857000
# 1598  t2 - behavioral - left packages unattended in ...  TBA012964244000
# 1650  t2 - behavioral - left packages unattended in ...  TBA013294885000
# 1868  t2 - behavioral - left packages unattended in ...  TBA014779085000
# 2223  t2 - behavioral - left packages unattended in ...  TBA018168535000
# 2247  t2 - behavioral - left packages unattended in ...  TBA018359550000
# 2326  t2 - behavioral - left packages unattended in ...  TBA019063288000
# 3489  t2 - behavioral - left packages unattended in ...  TBA033150643000
# 3749  t2 - behavioral - left packages unattended in ...  TBA954132371000
# 3827  t2 - behavioral - left packages unattended in ...  TBA960223959000
# 3945  t2 - behavioral - left packages unattended in ...  TBA965744507000
# 4171  t2 - behavioral - left packages unattended in ...  TBA973389371000
# 4291  t2 - behavioral - left packages unattended in ...  TBA976196498000
# 4537  t2 - behavioral - left packages unattended in ...  TBA980419891000
# 5081  t2 - behavioral - left packages unattended in ...  TBA985340568000
# 5547  t2 - behavioral - left packages unattended in ...  TBA988742351000
# 6053  t2 - behavioral - left packages unattended in ...  TBA992788206000
# 6306  t2 - behavioral - left packages unattended in ...  TBA994739316000
# 6668  t2 - behavioral - left packages unattended in ...  TBA997452319000
#
#                                                    Data  \
# 268   as per contact id;a3o0e3v1kvffgw ,driver left ...
# 467   contact id:a2hyr8p3pvjpoy\r\n\r\nduplicate tic...
# 1432  contact id:a2qyqpwzmbsidp\r\n\r\n \r\n\r\natta...
# 1586  contact id: a25scfunejaosy\r\n\r\nduplicate ti...
# 1598  contact id: a3rbnezyfksiz6\r\n\r\nduplicate ti...
# 1650  contact id: a1tgp5w1ofjajq\r\n\r\nattached pod...
# 1868  tba020234994000\r\ntba015412580000\r\ntba01477...
# 2223  contact id: a1tny4ni53sq78\r\n\r\nattached pod...
# 2247  **customer stated,driver left the package in t...
# 2326  contact id: a1c89x8eby14b8\r\n\r\nattached pod...
# 3489                                  no data available
# 3749  contact id: a3uirxci03opkx\r\n\r\nattached pod...
# 3827  contact id:a3m5la5lv3jhn2\r\n\r\nduplicate tic...
# 3945  contact id: a1rog01hymk9wg\r\n\r\nattached pod...
# 4171  reviewed contact a169yvht972asj customer state...
# 4291  contact id: a2hrqkmw51uvn3\r\n\r\nduplicate ti...
# 4537  contact id:awggaqe563r48\r\n\r\nduplicate tick...
# 5081  contact id:  acv8xnxck2pqz\r\n\r\nattached pod...
# 5547  reviewed the contact id: a19p1m2cdsjj9m, prope...
# 6053  contact id: a32addula80kzd\r\n\r\nduplicate ti...
# 6306  contact id: a3id5fp2v3vzoi\r\n\r\nduplicate ti...
# 6668  contact id: a34c5vzi5bsvz8\r\n\r\nattached pod...
#
#                                              Infraction  \
# 268   tier 2 da reputation - da reputation \u2013 be...
# 467   tier 2 da reputation - da reputation \u2013 be...
# 1432  da reputation - da reputation \u2013 behaviora...
# 1586  da reputation - da reputation \u2013 behaviora...
# 1598  da reputation \u2013 behavioral \u2013 leaving...
# 1650  da reputation - da reputation \u2013 behaviora...
# 1868  tier 2 da reputation - da reputation \u2013 be...
# 2223  da reputation - da reputation \u2013 behaviora...
# 2247  da reputation - da reputation \u2013 behaviora...
# 2326  da reputation - da reputation \u2013 behaviora...
# 3489                                             ailabl
# 3749  da reputation - da reputation \u2013 behaviora...
# 3827  tier 2 da reputation - da reputation \u2013 be...
# 3945  da reputation - da reputation \u2013 behaviora...
# 4171  da reputation \u2013 behavioral \u2013 leaving...
# 4291  da reputation - da reputation \u2013 behaviora...
# 4537  tier 2 da reputation - da reputation \u2013 be...
# 5081  tier 2 da reputation - da reputation \u2013 be...
# 5547  da reputation - da reputation \u2013 behaviora...
# 6053  da reputation - da reputation \u2013 behaviora...
# 6306  da reputation - da reputation \u2013 behaviora...
# 6668  da reputation - da reputation \u2013 behaviora...
#
#                                      Additional_Details       Infraction1  \
# 268   additional details:driver left packages unatte...  mailroom/leasing
# 467   additional details:customer stated that the dr...  mailroom/leasing
# 1432  additional details:driver left the package at ...  mailroom/leasing
# 1586  additional details: driver left the customer p...  mailroom/leasing
# 1598  additional details: driver left packages unatt...  mailroom/leasing
# 1650  additional details: complaint on driver from p...  mailroom/leasing
# 1868  additional details:the property manager stated...  mailroom/leasing
# 2223  additional details: property manager says that...  mailroom/leasing
# 2247  additional details:  customer stated,driver le...  mailroom/leasing
# 2326  additional details: driver left the package un...  mailroom/leasing
# 3489                                                NaN  mailroom/leasing
# 3749  additional details:  property manager says tha...  mailroom/leasing
# 3827  additional details:the property manager stated...  mailroom/leasing
# 3945  additional details: driver dumped packages una...  mailroom/leasing
# 4171  additional details: customer complained driver...  mailroom/leasing
# 4291  additional details: customer reached out compl...  mailroom/leasing
# 4537  additional details:customer complains that dri...  mailroom/leasing
# 5081  additional details:: customer wants to make a ...  mailroom/leasing
# 5547  additional details:  property manager complain...  mailroom/leasing
# 6053  additional details: customer complains that th...  mailroom/leasing
# 6306  additional details: customer states that packa...  mailroom/leasing
# 6668  additional details: the delivery driver left 3...  mailroom/leasing
#
#            Infraction2 First_Status attribute_1 attribute_2  Second_Status
# 268   mailroom/leasing         True        left    mailroom           True
# 467   mailroom/leasing         True        left   mail room           True
# 1432  mailroom/leasing         True        left   mail room           True
# 1586  mailroom/leasing         True        left   mail room           True
# 1598  mailroom/leasing         True        left    mailroom           True
# 1650               NaN           NS         NaN   mail room          False
# 1868  mailroom/leasing         True        left       lobby           True
# 2223  mailroom/leasing         True        left     leasing           True
# 2247  mailroom/leasing         True        left   mail room           True
# 2326  mailroom/leasing         True        left   mail room           True
# 3489               NaN           NS         NaN         NaN          False
# 3749  mailroom/leasing         True         NaN         NaN          False
# 3827  mailroom/leasing         True         NaN   mail room          False
# 3945  mailroom/leasing         True        dump   mail room           True
# 4171  mailroom/leasing         True        left    mailroom           True
# 4291  mailroom/leasing         True        left   mail room           True
# 4537  mailroom/leasing         True  unattended    mailroom           True
# 5081  mailroom/leasing         True        left     mailbox           True
# 5547  mailroom/leasing         True        left         NaN          False
# 6053  mailroom/leasing         True        left         NaN          False
# 6306  mailroom/leasing         True        dump         NaN           True
# 6668  mailroom/leasing         True        left     leasing           True

# %% [markdown]
# # Unauthorized entry of entryway garage

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('behavioral - unauthorized entry of entryway/garage/foyer')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list=('entered home|past the locked entry door','driver entered the house','driver enter her back yard','driver opened my basement door','staring through the windows','driver entered the customer''s house','driver hopped over the customer''s fence','driver entered into the side gate','entered customer back yard','driver opened the front door','entered customer''s garage','driver was found in in his open garage','enter his house','enter the back gate','enter the customer''s house','enter the customers house','entered customer''s garage','entered the gate','entered through a side door','entered through the backyard','entered to leave the package',
    'entering into the house','into the customers house','jumped over the fence','looking around','open her door','open the customer front door','open the customer''s back door','open the customer''s door','open the door','open the front door',
    'opened front door','opened the door of customer','opening the door','over the gate','pass the no passing zone','trespass','walk around','wander','without customer''s permission','without her permission')


df['attribute'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list)),expand=False).str.lower()


df['Second_Status']=df['Additional_Details'].str.contains('permission|opened his back door|opened customer''s garage|trying to enter|spying|pull the customer door|jump the fence|walked into|inside the house|left fence open|entered his garage|came in her house|all the way around my house to the back|straight into the door|came inside the house|attempted to open|came into my garage|entered home|driver entered her home|past the locked entry door|driver entered the house|driver enter her back yard|driver opened my basement door|staring through the windows|driver entered the customer''s house|driver hopped over the customer''s fence|driver entered into the side gate|driver opened the front door|entered customer back yard|entered customer''s garage|enter his house|open the door|jumped over the fence|enter the back gate|trespass|walk around|without customer''s permission|entering into the house|over the gate|opening the door|driver was found in in his open garage|entered the gate|entered through the backyard|open her door|open the front door|open the customer''s door|entered through a side door|opened front door|into the customers house|open the customer''s back door|without her permission|enter the customer''s house|looking around|open the customer front door|pass the no passing zone|opened the door of customer|entered to leave the package|enter the customers house|wander')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unauthorized entry of entryway garage foyer.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 61    308329404  Delivery Station (Station Code, City, State): ...
# 266   308331473  Delivery Station (Station Code, City, State): ...
# 599   308599381  Delivery Station (Station Code, City, State): ...
# 689   308499855  Delivery Station (Station Code, City, State): ...
# 777   308498137  Delivery Station (Station Code, City, State): ...
# 1069  307657007  Delivery Station: DVC1    DSP: Unknown    Cont...
# 1296  308601241  Delivery Station (Station Code, City, State): ...
# 1896  308767299  Delivery Station (Station Code, City, State): ...
# 1960  308633137  Delivery Station (Station Code, City, State): ...
# 2435  308734163  Delivery Station (Station Code, City, State): ...
# 2532  308785428  Delivery Station (Station Code, City, State): ...
# 2915  308902924  Delivery Station (Station Code, City, State): ...
# 2948  308874697  Delivery Station (Station Code, City, State): ...
# 3092  308880133  Delivery Station (Station Code, City, State): ...
# 3510  308179261  Delivery Station (Station Code, City, State): ...
# 3826  307773968  Delivery Station (Station Code, City, State): ...
# 3832  308880155  Delivery Station: DXU1      Contact ID: A2MYSH...
# 3970  308192500  Delivery Station (Station Code, City, State): ...
# 4125  308124186  Delivery Station (Station Code, City, State): ...
# 4149  308106541  Delivery Station (Station Code, City, State): ...
# 4157  307924410  Delivery Station (Station Code, City, State): ...
# 4431  308104558  Delivery Station (Station Code, City, State): ...
# 4896  308298946  Delivery Station (Station Code, City, State): ...
# 5008  308217337  Delivery Station (Station Code, City, State): ...
# 5543  308197235  Delivery Station (Station Code, City, State): ...
# 5889  308182255  Delivery Station (Station Code, City, State): ...
# 6059  308263781  Delivery Station (Station Code, City, State): ...
# 6303  308400274  Delivery Station (Station Code, City, State): ...
# 6387  308302131  Delivery Station (Station Code, City, State): ...
# 6422  308341630  Delivery Station (Station Code, City, State): ...
# 6490  308339159  Delivery Station (Station Code, City, State): ...
# 6562  308329299  Delivery Station (Station Code, City, State): ...
# 6624  308307087  Delivery Station (Station Code, City, State): ...
# 6736  308436159  Delivery Station: DTO1    Contact ID: A6LX0X5J...
# 6765  308462533  Delivery Station: DWG1      Contact ID: AD808F...
# 6946  308416993  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 61    t2 - behavioral - unauthorized entry of entryw...  TBA000433962000
# 266   t2 - behavioral - unauthorized entry of entryw...  TBA002049509000
# 599   t2 - behavioral - unauthorized entry of entryw...  TBA004999539000
# 689   t2 - behavioral - unauthorized entry of entryw...  TBA005593795000
# 777   t2 - behavioral - unauthorized entry of entryw...  TBA006429476000
# 1069  t2 - behavioral - unauthorized entry of entryw...              NaN
# 1296  t2 - behavioral - unauthorized entry of entryw...  TBA010569319000
# 1896  t2 - behavioral - unauthorized entry of entryw...  TBA015158472000
# 1960  t2 - behavioral - unauthorized entry of entryw...  TBA015696651000
# 2435  t2 - behavioral - unauthorized entry of entryw...  TBA020078349000
# 2532  t2 - behavioral - unauthorized entry of entryw...  TBA021017239000
# 2915  t2 - behavioral - unauthorized entry of entryw...  TBA024361977000
# 2948  t2 - behavioral - unauthorized entry of entryw...  TBA024692757000
# 3092  t2 - behavioral - unauthorized entry of entryw...  TBA026693316000
# 3510  t2 - behavioral - unauthorized entry of entryw...  TBA644985705000
# 3826  t2 - behavioral - unauthorized entry of entryw...  TBA960207487000
# 3832  t2 - behavioral - unauthorized entry of entryw...              NaN
# 3970  t2 - behavioral - unauthorized entry of entryw...  TBA966819865000
# 4125  t2 - behavioral - unauthorized entry of entryw...  TBA971981113000
# 4149  t2 - behavioral - unauthorized entry of entryw...  TBA972789032000
# 4157  t2 - behavioral - unauthorized entry of entryw...  TBA973069297000
# 4431  t2 - behavioral - unauthorized entry of entryw...  TBA978680774000
# 4896  t2 - behavioral - unauthorized entry of entryw...  TBA983858038000
# 5008  t2 - behavioral - unauthorized entry of entryw...  TBA984771568000
# 5543  t2 - behavioral - unauthorized entry of entryw...  TBA988712987000
# 5889  t2 - behavioral - unauthorized entry of entryw...  TBA991568276000
# 6059  t2 - behavioral - unauthorized entry of entryw...  TBA992878566000
# 6303  t2 - behavioral - unauthorized entry of entryw...  TBA994733866000
# 6387  t2 - behavioral - unauthorized entry of entryw...  TBA995361936000
# 6422  t2 - behavioral - unauthorized entry of entryw...  TBA995564317000
# 6490  t2 - behavioral - unauthorized entry of entryw...  TBA996126709000
# 6562  t2 - behavioral - unauthorized entry of entryw...  TBA996703324000
# 6624  t2 - behavioral - unauthorized entry of entryw...  TBA997108339000
# 6736  t2 - behavioral - unauthorized entry of entryw...              NaN
# 6765  t2 - behavioral - unauthorized entry of entryw...              NaN
# 6946  t2 - behavioral - unauthorized entry of entryw...  TBA999776376000
#
#                                                    Data  \
# 61    t1 issue, unauthorized entry. hence flipping t...
# 266   da jumped over gate to deliver package.,contac...
# 599   additional details from contact:just wanted to...
# 689   video added to \related items\ tab.,tier 2:da ...
# 777   tier 2:da reputation - behavioral - actual or ...
# 1069  * this ticket will automatically be set to ass...
# 1296  contact id:a2gppmqix2i7em\r\n\r\nduplicate tic...
# 1896  contact id:awlhtuxebofbu\r\n\r\nduplicate tick...
# 1960  contact id: aby09mzvgfu6f\r\n\r\nduplicate tic...
# 2435  additional details: driver looked into custome...
# 2532  contact id: a3h1x0heypm89l\r\n\r\nduplicate ti...
# 2915  contact id: a1ijsxrposjkbd\r\n\r\nduplicate ti...
# 2948                                  no data available
# 3092  contact id: acj4kolpdacbu\r\n\r\nduplicate tic...
# 3510  while delivery tba644985705000 dsp da used ano...
# 3826  did you consult the available (tm/rs) on the f...
# 3832  contact id: auulao4k1ll95\r\n\r\nduplicate tic...
# 3970  contact id: a2se73yjv37t40\r\n\r\nduplicate ti...
# 4125  contact id: a3n1l98j4gyj85\r\n\r\nduplicate ti...
# 4149  contact id:anv0liclpr0fv\r\n\r\nduplicate tick...
# 4157  contact id: a1j706gy2oa7hs\r\n\r\nattached pod...
# 4431  contact id: a1tk9hltngolld\r\n\r\nattached pod...
# 4896  contact id: akb3l1qup5y7o\r\n\r\nduplicate tic...
# 5008  contact id:a20fedt7gjzn1v\r\n\r\nduplicate tic...
# 5543  contact id: a3s0t3w69d1xs8\r\n\r\nduplicate ti...
# 5889  contact id: a25tnk4uvhsor3\r\n\r\nattached pod...
# 6059  contact id: a1nhuegm7nt209\r\n\r\nattached pod...
# 6303  contact id:a3dr2tjywevzml\r\n\r\nduplicate tic...
# 6387  contact id:agvo0gn19szl9\r\n\r\nduplicate tick...
# 6422  contact id: a6w6htg2j3ngw\r\n\r\nduplicate tic...
# 6490  contact id: al0t39yr9g2da\r\n\r\nduplicate tic...
# 6562  customer reports the driver came through my fe...
# 6624  contact id:asu007ycib80b\r\n\r\nduplicate tick...
# 6736  contact id: a15sb7snqidtmc\r\n\r\nduplicate ti...
# 6765  contact id: a1ygnhz57fycw3\r\n\r\nduplicate ti...
# 6946  contact id:a3ay68gnbuhwaf\r\n\r\nduplicate tic...
#
#                                              Infraction  \
# 61    da reputation - behavioral - actual or attempt...
# 266   da reputation - behavioral - actual or attempt...
# 599   da reputation - behavioral - actual or attempt...
# 689   da reputation - package mishandling - throwing...
# 777   da reputation - behavioral - actual or attempt...
# 1069  da reputation - behavioral - actual or attempt...
# 1296  da reputation - behavioral - actual or attempt...
# 1896  tier 2 da reputation - behavioral - actual or ...
# 1960  da reputation - behavioral - actual or attempt...
# 2435                                                NaN
# 2532  da reputation - behavioral - actual or attempt...
# 2915  tier 2 da reputation - behavioral - actual or ...
# 2948                                             ailabl
# 3092  da reputation - behavioral - actual or attempt...
# 3510  da reputation - behavioral - actual or attempt...
# 3826  da reputation - behavioral - actual or attempt...
# 3832  da reputation - behavioral - actual or attempt...
# 3970  da reputation - behavioral - actual or attempt...
# 4125  da reputation - behavioral - actual or attempt...
# 4149  da reputation - behavioral - actual or attempt...
# 4157  da reputation - behavioral - actual or attempt...
# 4431  tier 2 da reputation - behavioral - actual or ...
# 4896  da reputation - behavioral - actual or attempt...
# 5008  da reputation - behavioral - actual or attempt...
# 5543  da reputation - behavioral - actual or attempt...
# 5889  tier 2 da reputation - behavioral - actual or ...
# 6059  da reputation - behavioral - actual or attempt...
# 6303  da reputation - behavioral - actual or attempt...
# 6387  tier 2 da reputation - behavioral - actual or ...
# 6422  da reputation - behavioral - actual or attempt...
# 6490  da reputation - behavioral - actual or attempt...
# 6562  da reputation - behavioral - actual or attempt...
# 6624  da reputation - behavioral - actual or attempt...
# 6736  da reputation - behavioral - actual or attempt...
# 6765  da reputation - behavioral - actual or attempt...
# 6946  tier 2 da reputation - behavioral - actual or ...
#
#                                      Additional_Details         Infraction1  \
# 61    additional details:instead of living the packa...  unauthorized entry
# 266   additional details:driver  jumped over gate to...  unauthorized entry
# 599   additional details:just wanted to let you guys...  unauthorized entry
# 689   additional details:not only have we never had ...  unauthorized entry
# 777   additional details:my delivery driver went ins...  unauthorized entry
# 1069  additional details: customer complaints that t...  unauthorized entry
# 1296  additional details:customer complaint about th...  unauthorized entry
# 1896  additional details:the customer says the drive...  unauthorized entry
# 1960  additional details: customer said that the dri...  unauthorized entry
# 2435  additional details: driver looked into custome...  unauthorized entry
# 2532  additional details: customer says the driver j...  unauthorized entry
# 2915  additional details:  dropped the package on th...  unauthorized entry
# 2948                                                NaN  unauthorized entry
# 3092  additional details: customer complained driver...  unauthorized entry
# 3510  additional details: customer complains that th...  unauthorized entry
# 3826  additional details:customer contacted upset sh...  unauthorized entry
# 3832  additional details: customer complained driver...  unauthorized entry
# 3970  additional details: driver jumped over the loc...  unauthorized entry
# 4125  additional details: driver enter the backyard,...  unauthorized entry
# 4149  additional details: customer complained that t...  unauthorized entry
# 4157  additional details: the driver opened the fron...  unauthorized entry
# 4431  additional details:customer says the driver tr...  unauthorized entry
# 4896  additional details: customer complains that th...  unauthorized entry
# 5008  additional details: customer complains that th...  unauthorized entry
# 5543  additional details: customer wants to make a c...  unauthorized entry
# 5889  additional details: the customer called in sta...  unauthorized entry
# 6059  additional details: the customer states that t...  unauthorized entry
# 6303  additional details:customer says that the deli...  unauthorized entry
# 6387  additional details: driver tried to open custo...  unauthorized entry
# 6422  additional details:package has to be left on t...  unauthorized entry
# 6490  additional details: customer  upset and afraid...  unauthorized entry
# 6562  additional details:customer reports the driver...  unauthorized entry
# 6624  additional details: driver trying to open her ...  unauthorized entry
# 6736  additional details: the driver tried to open t...  unauthorized entry
# 6765  additional details: during the time that this ...  unauthorized entry
# 6946  additional details:the customer says the drive...  unauthorized entry
#
#              Infraction2 First_Status                     attribute  \
# 61    unauthorized entry         True                           NaN
# 266   unauthorized entry         True                           NaN
# 599   unauthorized entry         True                           NaN
# 689             throwing           NS                           NaN
# 777   unauthorized entry         True                           NaN
# 1069  unauthorized entry         True                           NaN
# 1296  unauthorized entry         True                           NaN
# 1896  unauthorized entry         True                           NaN
# 1960  unauthorized entry         True                           NaN
# 2435                 NaN           NS                           NaN
# 2532  unauthorized entry         True                 over the gate
# 2915  unauthorized entry         True              opening the door
# 2948                 NaN           NS                           NaN
# 3092  unauthorized entry         True  driver opened the front door
# 3510  unauthorized entry         True                           NaN
# 3826  unauthorized entry         True                           NaN
# 3832  unauthorized entry         True                           NaN
# 3970  unauthorized entry         True                           NaN
# 4125  unauthorized entry         True                           NaN
# 4149  unauthorized entry         True                           NaN
# 4157  unauthorized entry         True  driver opened the front door
# 4431  unauthorized entry         True                      trespass
# 4896  unauthorized entry         True                           NaN
# 5008  unauthorized entry         True                           NaN
# 5543  unauthorized entry         True                           NaN
# 5889  unauthorized entry         True                      trespass
# 6059  unauthorized entry         True                           NaN
# 6303  unauthorized entry         True                           NaN
# 6387  unauthorized entry         True                           NaN
# 6422  unauthorized entry         True                           NaN
# 6490  unauthorized entry         True                           NaN
# 6562  unauthorized entry         True                           NaN
# 6624  unauthorized entry         True                 open her door
# 6736  unauthorized entry         True                 open the door
# 6765  unauthorized entry         True                           NaN
# 6946  unauthorized entry         True                           NaN
#
#      Second_Status
# 61            True
# 266          False
# 599          False
# 689          False
# 777          False
# 1069         False
# 1296         False
# 1896          True
# 1960          True
# 2435         False
# 2532          True
# 2915          True
# 2948           NaN
# 3092          True
# 3510         False
# 3826         False
# 3832          True
# 3970         False
# 4125         False
# 4149         False
# 4157          True
# 4431          True
# 4896         False
# 5008         False
# 5543         False
# 5889          True
# 6059          True
# 6303         False
# 6387         False
# 6422         False
# 6490         False
# 6562         False
# 6624          True
# 6736          True
# 6765          True
# 6946         False

# %% [markdown]
# # Unprofessional behavior towards a customer

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('unprofessional behavior towards a customer')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()


df['Second_Status']=df['Additional_Details'].str.contains('preaching religion|he did not feel like delivering the packages door to door|arguing|told the customer to go to him|nasty|argument|driver shout|obscene language|banged the customer door|driver flipped customer off|receive the package from his car|beg|inappropriate|accuse|harass|aggressive|shook the door|slam|pee|driver took a picture of his father|driver not getting out of the truck|don''t order|deal with it|asked for food and money|uncomfortable|argue|bad tone|verbal altercation|rant|not polite|abuse|bad word|offensive|offensive verbal exchange|cussing|improper words|driver behaved improperly|disrespect|bad language|profane language|yell|attitude|unprofessional|remark|rude|curse|middle finger|abusive|scream|cursing|profanity|banging|abusing|threatened|intimidating|disrespectful|foul language|honking the horn constantly|i will not deliver the package to you next time|mis-gender')


df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unprofessional behavior towards a customer.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 24    308320215  Delivery Station (Station Code, City, State): ...
# 104   308293318  Delivery Station (Station Code, City, State): ...
# 177   308332457  Delivery Station (Station Code, City, State): ...
# 523   308405426  Delivery Station (Station Code, City, State): ...
# 524   308725254  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6392  308321484  Delivery Station (Station Code, City, State): ...
# 6438  308405214  Delivery Station (Station Code, City, State): ...
# 6677  308297616  Delivery Station (Station Code, City, State): ...
# 6840  308277890  Delivery Station (Station Code, City, State): ...
# 6873  308593607  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 24    t2 - behavioral - unprofessional behavior towa...  TBA000194898000
# 104   t2 - behavioral - unprofessional behavior towa...  TBA000717306000
# 177   t2 - behavioral - unprofessional behavior towa...  TBA001349071000
# 523   t2 - behavioral - unprofessional behavior towa...  TBA004372333000
# 524   t2 - behavioral - unprofessional behavior towa...  TBA004373089000
# ...                                                 ...              ...
# 6392  t2 - behavioral - unprofessional behavior towa...  TBA995389213000
# 6438  t2 - behavioral - unprofessional behavior towa...  TBA995727073000
# 6677  t2 - behavioral - unprofessional behavior towa...  TBA997561155000
# 6840  t2 - behavioral - unprofessional behavior towa...  TBA998971647000
# 6873  t2 - behavioral - unprofessional behavior towa...  TBA999244364000
#
#                                                    Data  \
# 24    contact id: a33bhyql99j2x\r\n\r\nduplicate tic...
# 104   customer is concerned that driver might have t...
# 177   contact id:a3n20eninukkux\r\n\r\nduplicate tic...
# 523   contact id: a29bw8otm6i8a8\r\n\r\nduplicate ti...
# 524   caller stated that the driver was yelling at t...
# ...                                                 ...
# 6392  contact id:adocipbbvzj0i\r\n\r\nduplicate tick...
# 6438  customer drove 2 houses down where dp was dp c...
# 6677  contact id: a3hkzles1vi30e\r\n\r\nattached pod...
# 6840  contact id:ao9y5hr7myv5s\r\n\r\nattached pod (...
# 6873  contact id:a2zidjo60deipe\r\n\r\nduplicate tic...
#
#                                              Infraction  \
# 24    da reputation - behavioural - insulting, unpro...
# 104                                                 NaN
# 177   da reputation - behavioral - insulting, unprof...
# 523   tier 2 da reputation - behavioral - insulting,...
# 524   da reputation - behavioral - insulting, unprof...
# ...                                                 ...
# 6392  da reputation - behavioral - insulting, unprof...
# 6438  tier 2 da reputation - behavioral - insulting,...
# 6677  da reputation - behavioral - insulting, unprof...
# 6840  da reputation - behavioral - insulting, unprof...
# 6873  da reputation - behavioral - insulting, unprof...
#
#                                      Additional_Details  \
# 24    additional details: customer stated that the d...
# 104   additional details:  customer said \driver blo...
# 177   additional details: customer says that the dri...
# 523   additional details: to gain access you have to...
# 524   additional details:caller stated that the driv...
# ...                                                 ...
# 6392  additional details:driver verbally harassed th...
# 6438  additional details: the customer says driver c...
# 6677  additional details:  the driver didn't follow ...
# 6840  additional details:upon arrival to security dr...
# 6873  additional details:driver came up to the custo...
#
#                       Infraction1 Infraction2 First_Status Second_Status
# 24    behavior towards a customer         NaN           NS          True
# 104   behavior towards a customer         NaN           NS          True
# 177   behavior towards a customer         NaN           NS          True
# 523   behavior towards a customer         NaN           NS          True
# 524   behavior towards a customer         NaN           NS          True
# ...                           ...         ...          ...           ...
# 6392  behavior towards a customer         NaN           NS          True
# 6438  behavior towards a customer         NaN           NS         False
# 6677  behavior towards a customer         NaN           NS          True
# 6840  behavior towards a customer         NaN           NS          True
# 6873  behavior towards a customer         NaN           NS          True
#
# [81 rows x 11 columns]

# %% [markdown]
# # Unsafe driving behavior

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')
df=df[df['root_cause'].str.contains('unsafe driving behavior')==True]
df=df[df['root_cause'].str.contains('unsafe driving behavior - property damage')==False]
df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

word_list=('wrong direction','drove on her lawn','drove on the yard','360 degrees turn','grass','drove on to the customer''s yard','mud','block','drove on their backyard','over 35 MPH','fly','smash','shatter','drove over','mess','cutting off traffic','drove over the customers lawn','spin','tire track','through her lawn','wrong side','drove by his front lawn','pace that was unsafe','360 in the parking','pulling in customers lawn','driving through the grass','drove on the customer lawn','rut','ran into','displace','damage','reckless','wrong way','destroy','60miles/hour','drove off our driveway sinking into our yard','fast','hit','knock','mark','speed','rush','drover over','drove off our driveway')


df['attribute'] = df.Additional_Details.str.extract('({})'.format('|'.join(word_list)),expand=False).str.lower()

df['Second_Status']=df['Additional_Details'].str.contains('slow down|wrong direction|drove on her lawn|drove on the yard|360 degrees turn|grass|drove on to the customer''s yard|mud|block|drove on their backyard|over 35 MPH|fly|smash|shatter|drove over|mess|cutting off traffic|drove over the customers lawn|spin|tire track|through her lawn|wrong side|drove by his front lawn|pace that was unsafe|360 in the parking|pulling in customers lawn|driving through the grass|drove on the customer lawn|rut|ran into|displace|damage|reckless|wrong way|destroy|60miles/hour|drove off our driveway sinking into our yard|speed|mark|hit|fast|knock|rush|drove off our driveway')

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unsafe driving behavior.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 63    308428154  Delivery Station (Station Code, City, State): ...
# 251   308298330  Delivery Station (Station Code, City, State): ...
# 305   308837677  Delivery Station (Station Code, City, State): ...
# 423   308443044  Delivery Station (Station Code, City, State): ...
# 483   308753238  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6860  308263990  Delivery Station (Station Code, City, State): ...
# 6867  308306119  Delivery Station (Station Code, City, State): ...
# 6871  308316949  Delivery Station (Station Code, City, State): ...
# 6898  308397945  Delivery Station (Station Code, City, State): ...
# 6932  308569484  Delivery Station (Station Code, City, State): ...
#
#                         root_cause              tid  \
# 63    t2 - unsafe driving behavior  TBA000444122000
# 251   t2 - unsafe driving behavior              NaN
# 305   t2 - unsafe driving behavior  TBA002436329000
# 423   t2 - unsafe driving behavior  TBA003614770000
# 483   t2 - unsafe driving behavior  TBA004069582000
# ...                            ...              ...
# 6860  t2 - unsafe driving behavior  TBA999082387000
# 6867  t2 - unsafe driving behavior  TBA999195704000
# 6871  t2 - unsafe driving behavior  TBA999218647000
# 6898  t2 - unsafe driving behavior  TBA999433978000
# 6932  t2 - unsafe driving behavior  TBA999684049000
#
#                                                    Data  \
# 63    as per investigation found that the driver is ...
# 251   did you consult the available (tm/rs) on the f...
# 305   contact id:a1xjev2z0t4hh0\r\n\r\nduplicate tic...
# 423   contact id: a1e0pd7tpglr76\r\n\r\nattached pod...
# 483   contact id:a2fsnbi3et3ru9\r\n\r\nduplicate tic...
# ...                                                 ...
# 6860  contact id: azp5bqjvntrsf\r\n\r\nduplicate tic...
# 6867  as per call record: customer reports da drivin...
# 6871  contact id: a18ja1vsx4dji9\r\n\r\nattached pod...
# 6898  contact id: a3izelk45d3xi1\r\n\r\nattached pod...
# 6932  contact id: a23n1bq6b359ln\r\n\r\nduplicate ti...
#
#                                              Infraction  \
# 63     da reputation \u2013 unsafe driving behavior\r\n
# 251   is classified as tier 2 - reckless driving, re...
# 305    da reputation \u2013 unsafe driving behavior\r\n
# 423    da reputation \u2013 unsafe driving behavior\r\n
# 483    da reputation \u2013 unsafe driving behavior\r\n
# ...                                                 ...
# 6860   da reputation \u2013 unsafe driving behavior\r\n
# 6867   da reputation \u2013 unsafe driving behavior\r\n
# 6871   da reputation \u2013 unsafe driving behavior\r\n
# 6898   da reputation \u2013 unsafe driving behavior\r\n
# 6932   da reputation \u2013 unsafe driving behavior\r\n
#
#                                      Additional_Details Infraction1  \
# 63    additional details: customer said that the dri...         NaN
# 251   additional details:driver was speeding through...         NaN
# 305   additional details:customer states that driver...         NaN
# 423   additional details: customer complained that t...         NaN
# 483   additional details:the driver is speeding over...         NaN
# ...                                                 ...         ...
# 6860  additional details: : driver pulled into one w...         NaN
# 6867  additional details: customer reports da drivin...         NaN
# 6871  additional details: customer says that the dri...         NaN
# 6898  additional details: the driver drove on her la...         NaN
# 6932  additional details: driver backed up into cust...         NaN
#
#      Infraction2 First_Status          attribute Second_Status
# 63           NaN           NS               fast          True
# 251          NaN           NS              speed          True
# 305          NaN           NS                NaN         False
# 423          NaN           NS             damage          True
# 483          NaN           NS              speed          True
# ...          ...          ...                ...           ...
# 6860         NaN           NS    wrong direction          True
# 6867         NaN           NS               fast          True
# 6871         NaN           NS             damage          True
# 6898         NaN           NS  drove on her lawn          True
# 6932         NaN           NS             damage          True
#
# [85 rows x 12 columns]

# %% [markdown]
# # Incorrectly scanned delivered to receiver

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('behavioral - incorrectly scanned delivered to receiver')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

# df['Status_1']=df['Additional_Details'].str.contains('no one was at home|customer didn''t sign for their package|item was not handed|package was never handed|customer was not in the address|no one was there to receive|package wasn''t handed|not deliver to receiver|not delivered to any receiver|delivered to receiver when it was not|left the packages outside|was never handed to her|is not at home|no one home|no one at the time of delivery|not handed directly to anyone|was left un attended|wasn''t handed to her|did not hand over the package to the customer|customer is not at home|was not left with the customer|left outside|customer was not home')


df['Second_Status']=(df['Additional_Details'].str.contains('package was never delivered|elevator|did not hand the package to the customer|no one was at home|customer didn''t sign for their package|item was not handed|package was never handed|customer was not in the address|no one was there to receive|package wasn''t handed|not deliver to receiver|not delivered to any receiver|delivered to receiver when it was not|left the packages outside|was never handed to her|is not at home|no one home|no one at the time of delivery|not handed directly to anyone|was left un attended|wasn''t handed to her|did not hand over the package to the customer|customer is not at home|was not left with the customer|left outside|customer was not home|did not hand over to the customer|has not happened|side walk|nobody was home|vending machine|no on was home|under the car|driver way|lawn|amazon hub|garbage|snow|outside|inaccurate delivery scan|alley|hallway|not true|parking lot|trash can|garage|planter bed|location|locker|yard|pile of snow|address|customers home|mail room|office|leasing|business area|mail box|bush|road|grass|porch|lock box|stair|unattended|building|gate|street|ground|driveway|desk|sidewalk|customer''s business|door|apartment|mailbox|floor|lobby|steps|front porch|bush|waste management|curb'))

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\comp_data.csv',encoding='ISO-8859-1')
df1.dropna(axis = 0, how = 'all', inplace = True) 

df2=df.merge(df1,left_on='tid',right_on='Tracking Id',how='left')


df2.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Incorrectly scanned delivered to receiver.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df2
# Out:
#        ShortId                                            details  \
# 0    308316671  Delivery Station (Station Code, City, State): ...
# 1    308338768  Delivery Station (Station Code, City, State): ...
# 2    308301845  Delivery Station (Station Code, City, State): ...
# 3    308301771  Delivery Station (Station Code, City, State): ...
# 4    308427075  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 398  308448904  Delivery Station (Station Code, City, State): ...
# 399  308399810  Delivery Station (Station Code, City, State): ...
# 400  308578824  Delivery Station (Station Code, City, State): ...
# 401  308320188  Delivery Station (Station Code, City, State): ...
# 402  308468989  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 0    t2 - behavioral - incorrectly scanned delivere...  TBA000010023000
# 1    t2 - behavioral - incorrectly scanned delivere...  TBA000038910000
# 2    t2 - behavioral - incorrectly scanned delivere...  TBA000212515000
# 3    t2 - behavioral - incorrectly scanned delivere...  TBA000280110000
# 4    t2 - behavioral - incorrectly scanned delivere...  TBA000546907000
# ..                                                 ...              ...
# 398  t2 - behavioral - incorrectly scanned delivere...  TBA999512066000
# 399  t2 - behavioral - incorrectly scanned delivere...  TBA999668209000
# 400  t2 - behavioral - incorrectly scanned delivere...  TBA999829828000
# 401  t2 - behavioral - incorrectly scanned delivere...  TBA999855566000
# 402  t2 - behavioral - incorrectly scanned delivere...  TBA999871301000
#
#                                                   Data  \
# 0    contact id:a1d4d7cvjw35x0\r\n\r\n\r\nattached ...
# 1    contact id: a8ic8s3n79sx5\r\n\r\nattached pod ...
# 2    contact id: a2dr4t32d1l3s0\r\n\r\nduplicate tt...
# 3    contact id: a12273edigr9fk\r\n\r\nattached pod...
# 4    contact id: a32ws4nhu4sufk\r\n\r\nattached pod...
# ..                                                 ...
# 398  contact id:a37662sbx52cin\r\n\r\n\r\n\r\nda de...
# 399  contact id:a2bjqofjvg62yc\r\n\r\nduplicate tic...
# 400  reviewed contact a2rwq1e12mmfu customer states...
# 401  contact id: axq3yued6idd2\r\n\r\nduplicate tic...
# 402  contact id:aqx0szavy0z2x\r\n\r\nduplicate tick...
#
#                                             Infraction  \
# 0    da reputation - behavioral - scanned delivered...
# 1    da reputation - behavioral - scanned delivered...
# 2    da reputation - behavioral - scanned delivered...
# 3    da reputation - behavioral - scanned delivered...
# 4    da reputation - behavioral - scanned delivered...
# ..                                                 ...
# 398  da reputation - behavioral - scanned delivered...
# 399  da reputation - behavioral - scanned delivered...
# 400  da reputation - behavioral - scanned delivered...
# 401  da reputation - behavioral - scanned delivered...
# 402  da reputation - behavioral - scanned delivered...
#
#                                     Additional_Details            Infraction1  \
# 0    additional details:customer complaints that th...  delivered to receiver
# 1    additional details: driver left the package ou...  delivered to receiver
# 2    additional details: the driver did not follow ...  delivered to receiver
# 3    additional details: customer  state dthat her ...  delivered to receiver
# 4    additional details: the customer has specific ...  delivered to receiver
# ..                                                 ...                    ...
# 398  additional details:the driver dropped the pack...  delivered to receiver
# 399  additional details:customer stated that the dr...  delivered to receiver
# 400  additional details: customer complained driver...  delivered to receiver
# 401  additional details: driver left the package un...  delivered to receiver
# 402  additional details:customer is saying that the...  delivered to receiver
#
#                Infraction2 First_Status  ...  Code TBA Deposit Code  \
# 0    delivered to receiver         True  ...  DLA9              NaN
# 1    delivered to receiver         True  ...  DHO1              NaN
# 2    delivered to receiver         True  ...  DDT2              NaN
# 3    delivered to receiver         True  ...  DEW8              NaN
# 4    delivered to receiver         True  ...  DCH1              NaN
# ..                     ...          ...  ...   ...              ...
# 398  delivered to receiver         True  ...  DOR1              NaN
# 399  delivered to receiver         True  ...  DRI1              NaN
# 400  delivered to receiver         True  ...  DBK1              NaN
# 401  delivered to receiver         True  ...  DSD2              NaN
# 402  delivered to receiver         True  ...  DDC3              NaN
#
#     Amazon Deposit Code Route Sequence sort_zone          packaging  \
# 0                   NaN          115.0   D-31.4D  No Packaging Need
# 1                   NaN           69.0   B-11.2A  No Packaging Need
# 2                   NaN           39.0    G-5.4G  No Packaging Need
# 3                   NaN           49.0    B-8.4A  No Packaging Need
# 4                   NaN           17.0   J-31.3C  No Packaging Need
# ..                  ...            ...       ...                ...
# 398                 NaN          158.0   A-34.1A  No Packaging Need
# 399                 NaN          155.0   G-15.3A  No Packaging Need
# 400                 NaN           61.0   B-26.3D  No Packaging Need
# 401                 NaN           90.0    A-3.1A  No Packaging Need
# 402                 NaN          141.0   D-48.2E  No Packaging Need
#
#      sellerName inductedCycle assignedCycle sideLineUntilTime
# 0           NaN       CYCLE_1       CYCLE_1               NaN
# 1           NaN       CYCLE_2       CYCLE_1               NaN
# 2           NaN       CYCLE_2       CYCLE_1               NaN
# 3           NaN       CYCLE_2       CYCLE_1               NaN
# 4           NaN       CYCLE_1       CYCLE_1               NaN
# ..          ...           ...           ...               ...
# 398         NaN       CYCLE_1       CYCLE_1               NaN
# 399         NaN       CYCLE_1       CYCLE_1               NaN
# 400         NaN       CYCLE_1       CYCLE_1               NaN
# 401         NaN       CYCLE_1       CYCLE_1               NaN
# 402         NaN       CYCLE_1       CYCLE_1               NaN
#
# [403 rows x 70 columns]

# %% [markdown]
# # Incorrect Scan

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('behavioral - incorrect scan')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

df['Second_Status']=df['Additional_Details'].str.contains('and scanned the packages as|and left the package by the gate|instead it was delivered|and marked them as|which is incorrect|was not followed|but left at|scan incorrectly|incorrectly scan the package|but they left in|but left the package|incorrectly scanned|but left package at|but the packages were left|but left package at|instead of leaving it|instead marked scan as|but the packages were left|and marked package as|tried delivering the package to an incorrect address|however, package was delivered|did not deliver|scanned the package on the wrong location|when it was delivered|but left package|not at|did not leave the package|from far location|marked it incorrectly|it was actually delivered|away from customer|far away|outside the property|business closed before reaching|inaccurate|packages as business closed that were residential addresses|scanned it as|marked incorrectly|marked as|as scanned|marked it as|but the package was left|scanned as|which is not true|marked the scan as|marked the package as|scanned the package as')



df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Behavioral - Incorrect Scan.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId                                            details  \
# 13    308449849  Delivery Station (Station Code, City, State): ...
# 17    308298567  Delivery Station (Station Code, City, State): ...
# 18    308444949  Delivery Station (Station Code, City, State): ...
# 23    308324247  Delivery Station (Station Code, City, State): ...
# 27    308316763  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6900  308771563  Delivery Station (Station Code, City, State): ...
# 6913  308321720  Delivery Station (Station Code, City, State): ...
# 6918  308411308  Delivery Station (Station Code, City, State): ...
# 6926  308488313  Delivery Station (Station Code, City, State): ...
# 6945  308321102  Delivery Station (Station Code, City, State): ...
#
#                             root_cause              tid  \
# 13    t2 - behavioral - incorrect scan  TBA000086720000
# 17    t2 - behavioral - incorrect scan  TBA000111206000
# 18    t2 - behavioral - incorrect scan  TBA000130129000
# 23    t2 - behavioral - incorrect scan  TBA000161748000
# 27    t2 - behavioral - incorrect scan  TBA000211386000
# ...                                ...              ...
# 6900  t2 - behavioral - incorrect scan  TBA999466165000
# 6913  t2 - behavioral - incorrect scan  TBA999561279000
# 6918  t2 - behavioral - incorrect scan  TBA999600927000
# 6926  t2 - behavioral - incorrect scan  TBA999637661000
# 6945  t2 - behavioral - incorrect scan  TBA999772378000
#
#                                                    Data  \
# 13    contact id: a1xx6r3ys3tvx7\r\n\r\nduplicate ti...
# 17    contact id: agjmhlhjwkl8y\r\n\r\nattached pod ...
# 18    contact id:a1h6d6wm0v8m63\r\n\r\nduplicate tic...
# 23    contact id: a42g5ag6l96iq\r\n\r\nattached pod ...
# 27    contact id:aynh9nh1ys6hk\r\n\r\nduplicate tick...
# ...                                                 ...
# 6900  contact id:a3byqsolo9dgtf\r\n\r\n\r\n\r\nattac...
# 6913  driver delivered the package in the driveway a...
# 6918  issue is not an infraction.delivered to front ...
# 6926  contact id: a32tod3se2e9oi\r\n\r\nduplicate ti...
# 6945  contact id:a396sw6ibutrgz\r\n\r\nduplicate tic...
#
#                                              Infraction  \
# 13    da reputation \u2013 behavioral \u2013 incorre...
# 17    da reputation \u2013 behavioral \u2013 incorre...
# 18    da reputation \u2013 behavioral \u2013 incorre...
# 23    da reputation \u2013 behavioral \u2013 incorre...
# 27    da reputation \u2013 behavioral \u2013 incorre...
# ...                                                 ...
# 6900  da reputation \u2013 behavioral \u2013 incorre...
# 6913  da reputation \u2013 behavioral \u2013 incorre...
# 6918  da reputation \u2013 behavioral \u2013 incorre...
# 6926  da reputation \u2013 behavioral \u2013 incorre...
# 6945  da reputation \u2013 behavioral \u2013 incorre...
#
#                                      Additional_Details     Infraction1  \
# 13    additional details: customer has complained th...  incorrect scan
# 17    additional details: this driver left the packa...  incorrect scan
# 18    additional details:the driver left the package...  incorrect scan
# 23    additional details: customer instructed to giv...  incorrect scan
# 27    additional details:customer is saying that the...  incorrect scan
# ...                                                 ...             ...
# 6900  additional details:the driver left the package...  incorrect scan
# 6913  additional details:driver delivered the packag...  incorrect scan
# 6918  additional details: package marked as deliver ...  incorrect scan
# 6926  additional details: customer has complained th...  incorrect scan
# 6945  additional details:customer is saying that the...  incorrect scan
#
#          Infraction2 First_Status Second_Status
# 13    incorrect scan         True          True
# 17    incorrect scan         True         False
# 18    incorrect scan         True          True
# 23    incorrect scan         True         False
# 27    incorrect scan         True          True
# ...              ...          ...           ...
# 6900  incorrect scan         True          True
# 6913  incorrect scan         True          True
# 6918  incorrect scan         True          True
# 6926  incorrect scan         True          True
# 6945  incorrect scan         True          True
#
# [443 rows x 11 columns]

# %% [markdown]
# # Collated Files except not a tier, duplicate, nfdi

# %%
df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Delivering in or on a USPS mail box.csv')
df2=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Dumping packages inside lobby.csv')
df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Dumping packages outside locker.csv')
df4=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left in driveway.csv')
df5=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left_in_lawn.csv')
df6=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_near garbage or recycling.csv')
df7=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Package Mishandling - Throwing.csv')
df8=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_property_damage.csv')
df9=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Scanned business closed.csv')
df10=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Scanned unable to access.csv')
df11=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_unattended_in_mailroom.csv')
df12=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unauthorized entry of entryway garage foyer.csv')
df13=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unprofessional behavior towards a customer.csv')
df14=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Unsafe driving behavior.csv')
df15=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Behavioral - Incorrect Scan.csv')
df16=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Incorrectly scanned delivered to receiver.csv')
df17=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_left_in_road_curb.csv')




df = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17], ignore_index=True,sort=False)
df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\Collated_end_infractions.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId              tid  \
# 0     308599217  TBA007857891000
# 1     308724073  TBA009814671000
# 2     308638501  TBA010356092000
# 3     308768795  TBA020013448000
# 4     308853392  TBA026417031000
# ...         ...              ...
# 1956  308329325  TBA996320141000
# 1957  308302393  TBA998718747000
# 1958  308297864  TBA998817972000
# 1959  308402875  TBA998870846000
# 1960  308327221  TBA999320246000
#
#                                              root_cause  \
# 0     t2 - package mishandling - delivering in or on...
# 1     t2 - package mishandling - delivering in or on...
# 2     t2 - package mishandling - delivering in or on...
# 3     t2 - package mishandling - delivering in or on...
# 4     t2 - package mishandling - delivering in or on...
# ...                                                 ...
# 1956       t2 - package mishandling - left in road/curb
# 1957       t2 - package mishandling - left in road/curb
# 1958       t2 - package mishandling - left in road/curb
# 1959       t2 - package mishandling - left in road/curb
# 1960       t2 - package mishandling - left in road/curb
#
#                                              Infraction  \
# 0     da reputation - package mishandling - deliveri...
# 1     da reputation - package mishandling - deliveri...
# 2     da reputation - package mishandling - deliveri...
# 3     da reputation - package mishandling - deliveri...
# 4     da reputation - package mishandling - deliveri...
# ...                                                 ...
# 1956  da reputation - package mishandling - package(...
# 1957  da reputation - package mishandling - package(...
# 1958  tier 2 da reputation - package mishandling - p...
# 1959  da reputation - package mishandling - package(...
# 1960  da reputation - package mishandling - package(...
#
#                                      Additional_Details First_Status  \
# 0     additional details: usps wrote to support abou...         True
# 1     additional details: driver left the package in...         True
# 2                                                   NaN         True
# 3     additional details:  customer stated,driver le...         True
# 4     additional details:  customer called to inquir...         True
# ...                                                 ...          ...
# 1956  additional details: customer instructed to del...           NS
# 1957  additional details:the driver left the package...           NS
# 1958  additional details: the driver left the packag...           NS
# 1959  additional details: customer  have issues with...           NS
# 1960  additional details: driver left the packages o...           NS
#
#      Second_Status
# 0            False
# 1             True
# 2              NaN
# 3             True
# 4            False
# ...            ...
# 1956          True
# 1957         False
# 1958         False
# 1959         False
# 1960          True
#
# [1961 rows x 7 columns]
