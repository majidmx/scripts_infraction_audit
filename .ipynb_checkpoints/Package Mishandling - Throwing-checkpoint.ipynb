# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('package mishandling - throwing/tossing')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

word_list=('driver flung','driver toss','throw it outside','driver kicked her package','throwing his package','driver throw','tossed the stuff','driver slid the package','tossed into the yard','drops the package from the height','pacakge was tossed','drive toss','kick','driver throwing','was tossed','packages were thrown','driver dropping package','driver throw','driver thew the package','driver throwed the package','driver throw','flung the customer''s order','threw','drop package','drop the box','drop the package','dropped package','dropped the package','kicking','launched the package','not handling packages carefully','package threw by','package was dropped',
    'package was just thrown','package was thrown','package was thrown over a gate','package was tossed','package were thrown','package which was tossed','packages are being thrown','packages tossed','packages were tossed','rolled the boxes',
    'shipment was thrown','slammed the pkg','slides the package','slung package','the customer package','threw a package','threw and left','threw away the package','threw customer package','threw customer''s package',
    'threw customers package','threw her package','threw his package','threw it on the road','threw it over fence','threw my package','threw my packaging','threw package','threw the customer''s package','threw the envelope package',
    'threw the package','threw their package','threw/toss','throw her package','throw his package','throw it in front of my door','throw my package','throw or toss','throw over his fence','throw package',
    'throw the package','throwing boxes','throwing her package','throwing items','throwing my package','throwing package','throwing the items','throwing the package','throwing/tossing','thrown at customer''s door',
    'thrown at my door','thrown his package','thrown into their backyard','thrown on the lawn','thrown on the porch','thrown onto my porch','thrown over a fence','thrown over the fence','thrown over the gate','thrown package',
    'thrown the item','thrown the package','thrown the valuable package','thrown to','throws the package','toss my package out','toss package','toss the customer package','toss the package','tossed across',
    'tossed and threw','tossed away the package','tossed customer package','tossed customer''s package','tossed customers package','tossed her package','tossed his package','tossed his packages','tossed into the porch','tossed it',
    'tossed on','tossed over my fence','tossed over the backyard','tossed package','tossed the customer package','tossed the customer''s package','tossed the customers package','tossed the package','tossed their package','tossing her package',
    'tossing package','tossing packages','tossing the package','was thrown','driver flung the customer''s order')

df['attribute'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list)),expand=False).str.lower()


df['Second_Status']=df['Additional_Details_Data'].str.contains('driver flung|driver toss|throw it outside|driver kicked her package|throwing his package|driver throw|tossed the stuff|driver slid the package|tossed into the yard|drops the package from the height|pacakge was tossed|drive toss|kick|driver throwing|was tossed|packages were thrown|driver dropping package|driver throw|driver thew the package|driver throwed the package|driver throw|flung the customer''s order|driver flung the customer''s order|threw|drop package|drop the package|dropped package|kicking|launched the package|package threw by|package was dropped|package was just thrown|package was thrown|package was tossed|packages tossed|packages were tossed|shipment was thrown|threw his package|threw it on the road|threw it over fence|threw my package|threw package|threw the package|throw package|throw the package|throwing items|throwing package|throwing the items|throwing the package|throwing/tossing |thrown at my door|thrown over a fence|thrown over the fence|thrown over the gate|thrown package|thrown the package|thrown to |toss package|toss the customer package|toss the package|tossed across|tossed away the package|tossed customer package|tossed customers package|tossed customer''s package|tossed his packages|tossed on |tossed over my fence|tossed package|tossed the customer package|tossed the customers package|tossed the package|tossing package|was thrown|threw/toss|threw away the package|threw a package|slides the package|dropped the package|thrown the item|tossing packages|tossing the package|threw the customer''s package|threw customers package|threw customer''s package|threw customer package|rolled the boxes|thrown at customer''s door|thrown into their backyard|throw her package|the customer package|throw his package|throw over his fence|throw or toss|tossed their package|tossed her package|drop the box|threw and left|slung package|package were thrown|package was thrown over a gate|tossed over the backyard|thrown the valuable package|packages are being thrown|tossed and threw|threw their package|thrown on the porch|tossed into the porch|thrown onto my porch|slammed the pkg|tossed his package|throwing my package|not handling packages carefully|thrown on the lawn|threw her package|threw the envelope package|throwing her package|tossed it|package which was tossed|tossing her package|throwing boxes|tossed the customer''s package|throws the package|thrown his package|threw my packaging|throw it in front of my door|throw my package|toss my package out')



df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Package Mishandling - Throwing.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 13    306030963  Delivery Station (Station Code, City, State): ...
# 36    306053870  Delivery Station (Station Code, City, State): ...
# 57    305938003  Delivery Station (Station Code, City, State): ...
# 166   306060373  Delivery Station (Station Code, City, State): ...
# 266   306029855  ****Station submitted TTs will need to have da...
# ...         ...                                                ...
# 6691  306221546  Delivery Station (Station Code, City, State): ...
# 6739  306204168  Delivery Station (Station Code, City, State): ...
# 6786  306289266  Delivery Station (Station Code, City, State): ...
# 6823  306298571  Delivery Station (Station Code, City, State): ...
# 6831  305363129  City/Site: FBN1 New York - AMZL      Contact I...
#
#                                        root_cause              tid  \
# 13    t2 - package mishandling - throwing/tossing  TBA860139855000
# ...
