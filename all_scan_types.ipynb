# %% [markdown]
# # business_closed

# %%
import pandas as pd

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()

df=df[df['root_cause'].str.contains('scanned business closed|scanned unable to access|incorrectly scanned delivered to receiver')==True]


df['Second_Status']=df['Additional_Details'].str.contains('when the school was open|address is the post office and it was not closed but driver incorrectly scanned as business closed|business closed for an apartment|business was not closed when driver attempted the delivery|driver scanned as business closed when the business open|business and the front door was open|business is very open|business was closed but it was open|business closed while it''s opened at the time of delivery|business closed when it was open|waiting for this order|business is still open|business is open|business was open|business is not closed|there are people|building is open|business hours have been updated')

# x=df.merge(comp,left_on='tid',right_on='Tracking Id')
# x['Scan_Status']=x[x['Reason'].str.contains('BUSINESS_CLOSED')==True]

# x

df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\aa.csv',index = False)


# df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Scanned business closed.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
# df

# %% [markdown]
# # unable_to_attempt_uta

# %%
# Out:
#         ShortId                                            details  \
# 193   308577966  Delivery Station (Station Code, City, State): ...
# 306   308858402  Delivery Station (Station Code, City, State): ...
# 579   308425153  Delivery Station (Station Code, City, State): ...
# 1109  308616131  Delivery Station (Station Code, City, State): ...
# 1353  308645110  Delivery Station (Station Code, City, State): ...
# 1360  308633027  Delivery Station (Station Code, City, State): ...
# 1615  308613917  Delivery Station (Station Code, City, State): ...
# 2383  308756464  Delivery Station (Station Code, City, State): ...
# 2519  308768767  Copy and paste the Amazon Flex delivery partne...
# 2530  308766742  Delivery Station (Station Code, City, State): ...
# 2553  308775128  Delivery Station (Station Code, City, State): ...
# 4164  307936741  Delivery Station (Station Code, City, State): ...
# 4759  308131805  Delivery Station (Station Code, City, State): ...
# 4830  308174044  Delivery Station (Station Code, City, State): ...
# 4847  308115731  Delivery Station (Station Code, City, State): ...
# 5115  308121805  Delivery Station (Station Code, City, State): ...
# 5424  308440382  Delivery Station (Station Code, City, State): ...
# 6789  308326226  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 193   t2 - behavioral - scanned unable to access (ut...  TBA001559230000
# 306   t2 - behavioral - scanned unable to access (ut...  TBA002460034000
# 579   t2 - behavioral - scanned unable to access (ut...  TBA004898912000
# 1109  t2 - behavioral - scanned unable to access (ut...  TBA008858283000
# 1353  t2 - behavioral - scanned unable to access (ut...  TBA011035978000
# 1360  t2 - behavioral - scanned unable to access (ut...  TBA011076643000
# 1615  t2 - behavioral - scanned unable to access (ut...  TBA013037138000
# 2383  t2 - behavioral - scanned unable to access (ut...  TBA019551131000
# 2519  t2 - behavioral - scanned unable to access (ut...  TBA020924449000
# 2530  t2 - behavioral - scanned unable to access (ut...  TBA020999815000
# 2553  t2 - behavioral - scanned unable to access (ut...  TBA021204802000
# 4164  t2 - behavioral - scanned unable to access (ut...  TBA973199146000
# 4759  t2 - behavioral - scanned unable to access (ut...  TBA982608504000
# 4830  t2 - behavioral - scanned unable to access (ut...  TBA983231387000
# 4847  t2 - behavioral - scanned unable to access (ut...  TBA983413516000
# 5115  t2 - behavioral - scanned unable to access (ut...  TBA985655452000
# 5424  t2 - behavioral - scanned unable to access (ut...  TBA987819826000
# 6789  t2 - behavioral - scanned unable to access (ut...  TBA998478792000
#
#                                                    Data  \
# 193   contact id: a1zmg79vqwyghc\r\n\r\nduplicate ti...
# 306   contact id:  a37h7ajmmqwgfx\r\n\r\nattached po...
# 579   contact id:a2kusb612pokq2\r\n\r\nduplicate tic...
# 1109  note:- driver marked the package as uta at the...
# 1353  contact id: ao6o3trrxph3\r\n\r\nduplicate tick...
# 1360  contact id: a30vl4c6s0h3dj\r\n\r\nduplicate ti...
# 1615  **customer stated there is no access required ...
# 2383  contact id:a2owv58kro2mtq\r\n\r\nduplicate tic...
# 2519  dspda. hence flipping for better assistance.,c...
# 2530  contact id:a3id1in5200emj\r\n\r\n \r\n\r\natta...
# 2553  contact id: a2vmj4be466aoq\r\n\r\nduplicate ti...
# 4164  contact id: a3qibk1w4kher8\r\n\r\nattached pod...
# 4759  contact id:a3vpzxkl2q1pyx\r\n\r\nduplicate tic...
# 4830  contact id: a32b7013yw6cd3\r\n\r\nattached pod...
# 4847  contact id: a2jn1fk44hvday\r\n\r\nduplicate ti...
# 5115  contact id: a2hya77dwl111y\r\n\r\nduplicate ti...
# 5424  contact id: a3d5gtnjwawz23\r\n\r\nattached pod...
# 6789  contact id:a2p8da90jjw3ci\r\n\r\nduplicate tic...
#
#                                              Infraction  \
# 193   da reputation \u2013 behavioral \u2013 scanned...
# 306   da reputation \u2013 behavioral \u2013 scanned...
# 579   da reputation \u2013 behavioral \u2013 scanned...
# 1109  da reputation \u2013 behavioral \u2013 scanned...
# 1353  tier 2 da reputation \u2013 behavioral \u2013 ...
# 1360  da reputation \u2013 behavioral \u2013 scanned...
# 1615  da reputation \u2013 behavioral \u2013 scanned...
# 2383  da reputation \u2013 behavioral \u2013 scanned...
# 2519  da reputation \u2013 behavioral \u2013 scanned...
# 2530  da reputation \u2013 behavioural \u2013 scanne...
# 2553  da reputation \u2013 behavioral \u2013 scanned...
# 4164  da reputation \u2013 behavioral \u2013 scanned...
# 4759  tier 2 da reputation \u2013 behavioral \u2013 ...
# 4830  da reputation \u2013 behavioral \u2013 scanned...
# 4847  tier 2 da reputation \u2013 behavioral \u2013 ...
# 5115  da reputation \u2013 behavioral \u2013 scanned...
# 5424  da reputation \u2013 behavioral \u2013 scanned...
# 6789  da reputation \u2013 behavioral \u2013 scanned...
#
#                                      Additional_Details       Infraction1  \
# 193   additional details: driver marked uta at custo...  unable to access
# 306   additional details: customer is complaining on...  unable to access
# 579   additional details: customer complaining that ...  unable to access
# 1109  additional details: \r\ncustomer stated that t...  unable to access
# 1353  additional details: driver marked the scan as ...  unable to access
# 1360  additional details:driver scanned as unable to...  unable to access
# 1615  additional details:  customer stated there is ...  unable to access
# 2383  additional details:this driver marked the pack...  unable to access
# 2519  additional details: customer reported that thi...  unable to access
# 2530  additional details:driver scanned the package ...  unable to access
# 2553  additional details:  the customer called in be...  unable to access
# 4164  additional details:  driver scanned as deliver...  unable to access
# 4759  additional details:customer complains that dri...  unable to access
# 4830  additional details: no access code needed, but...  unable to access
# 4847  additional details: driver marked the scan as ...  unable to access
# 5115  additional details: customer has complained th...  unable to access
# 5424  additional details: customer reported that the...  unable to access
# 6789  additional details: customer complains that th...  unable to access
#
#            Infraction2 First_Status  Second_Status
# 193   unable to access         True           True
# 306   unable to access         True           True
# 579   unable to access         True           True
# 1109  unable to access         True           True
# 1353  unable to access         True           True
# 1360  unable to access         True           True
# 1615  unable to access         True           True
# 2383  unable to access         True          False
# 2519  unable to access         True           True
# 2530  unable to access         True           True
# 2553  unable to access         True          False
# 4164  unable to access         True           True
# 4759  unable to access         True           True
# 4830  unable to access         True           True
# 4847  unable to access         True           True
# 5115  unable to access         True          False
# 5424  unable to access         True          False
# 6789  unable to access         True           True

# %% [markdown]
#  # Incorrectly scanned delivered to receiver

# %%
df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_infractions_first_check.csv')

df=df[df['root_cause'].str.contains('behavioral - incorrectly scanned delivered to receiver')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction']=df['Infraction'].str.lower() 
df['Additional_Details']=df['Additional_Details'].str.lower()



df['Second_Status']=(df['Additional_Details'].str.contains('package was never delivered|elevator|did not hand the package to the customer|no one was at home|customer didn''t sign for their package|item was not handed|package was never handed|customer was not in the address|no one was there to receive|package wasn''t handed|not deliver to receiver|not delivered to any receiver|delivered to receiver when it was not|left the packages outside|was never handed to her|is not at home|no one home|no one at the time of delivery|not handed directly to anyone|was left un attended|wasn''t handed to her|did not hand over the package to the customer|customer is not at home|was not left with the customer|left outside|customer was not home|did not hand over to the customer|has not happened|side walk|nobody was home|vending machine|no on was home|under the car|driver way|lawn|amazon hub|garbage|snow|outside|inaccurate delivery scan|alley|hallway|not true|parking lot|trash can|garage|planter bed|location|locker|yard|pile of snow|address|customers home|mail room|office|leasing|business area|mail box|bush|road|grass|porch|lock box|stair|unattended|building|gate|street|ground|driveway|desk|sidewalk|customer''s business|door|apartment|mailbox|floor|lobby|steps|front porch|bush|waste management|curb'))

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\INPUT_FILES\comp_data.csv',encoding='ISO-8859-1')
df1.dropna(axis = 0, how = 'all', inplace = True) 

df2=df.merge(df1,left_on='tid',right_on='Tracking Id',how='left')


df2.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\OUTPUT_FILES\verified_Incorrectly scanned delivered to receiver.csv',columns=('ShortId','tid','root_cause','Infraction','Additional_Details','First_Status','Second_Status'),index = False)
df2
# Out:
#        ShortId                                            details  \
# 0    308316671  Delivery Station (Station Code, City, State): ...
# 1    308338768  Delivery Station (Station Code, City, State): ...
# 2    308301845  Delivery Station (Station Code, City, State): ...
# 3    308301771  Delivery Station (Station Code, City, State): ...
# 4    308427075  Delivery Station (Station Code, City, State): ...
# ..         ...                                                ...
# 398  308448904  Delivery Station (Station Code, City, State): ...
# 399  308399810  Delivery Station (Station Code, City, State): ...
# 400  308578824  Delivery Station (Station Code, City, State): ...
# 401  308320188  Delivery Station (Station Code, City, State): ...
# 402  308468989  Delivery Station (Station Code, City, State): ...
#
#                                             root_cause              tid  \
# 0    t2 - behavioral - incorrectly scanned delivere...  TBA000010023000
# 1    t2 - behavioral - incorrectly scanned delivere...  TBA000038910000
# 2    t2 - behavioral - incorrectly scanned delivere...  TBA000212515000
# 3    t2 - behavioral - incorrectly scanned delivere...  TBA000280110000
# 4    t2 - behavioral - incorrectly scanned delivere...  TBA000546907000
# ..                                                 ...              ...
# 398  t2 - behavioral - incorrectly scanned delivere...  TBA999512066000
# 399  t2 - behavioral - incorrectly scanned delivere...  TBA999668209000
# 400  t2 - behavioral - incorrectly scanned delivere...  TBA999829828000
# 401  t2 - behavioral - incorrectly scanned delivere...  TBA999855566000
# 402  t2 - behavioral - incorrectly scanned delivere...  TBA999871301000
#
#                                                   Data  \
# 0    contact id:a1d4d7cvjw35x0\r\n\r\n\r\nattached ...
# 1    contact id: a8ic8s3n79sx5\r\n\r\nattached pod ...
# 2    contact id: a2dr4t32d1l3s0\r\n\r\nduplicate tt...
# 3    contact id: a12273edigr9fk\r\n\r\nattached pod...
# 4    contact id: a32ws4nhu4sufk\r\n\r\nattached pod...
# ..                                                 ...
# 398  contact id:a37662sbx52cin\r\n\r\n\r\n\r\nda de...
# 399  contact id:a2bjqofjvg62yc\r\n\r\nduplicate tic...
# 400  reviewed contact a2rwq1e12mmfu customer states...
# 401  contact id: axq3yued6idd2\r\n\r\nduplicate tic...
# 402  contact id:aqx0szavy0z2x\r\n\r\nduplicate tick...
#
#                                             Infraction  \
# 0    da reputation - behavioral - scanned delivered...
# 1    da reputation - behavioral - scanned delivered...
# 2    da reputation - behavioral - scanned delivered...
# 3    da reputation - behavioral - scanned delivered...
# 4    da reputation - behavioral - scanned delivered...
# ..                                                 ...
# 398  da reputation - behavioral - scanned delivered...
# 399  da reputation - behavioral - scanned delivered...
# 400  da reputation - behavioral - scanned delivered...
# 401  da reputation - behavioral - scanned delivered...
# 402  da reputation - behavioral - scanned delivered...
#
#                                     Additional_Details            Infraction1  \
# 0    additional details:customer complaints that th...  delivered to receiver
# 1    additional details: driver left the package ou...  delivered to receiver
# 2    additional details: the driver did not follow ...  delivered to receiver
# 3    additional details: customer  state dthat her ...  delivered to receiver
# 4    additional details: the customer has specific ...  delivered to receiver
# ..                                                 ...                    ...
# 398  additional details:the driver dropped the pack...  delivered to receiver
# 399  additional details:customer stated that the dr...  delivered to receiver
# 400  additional details: customer complained driver...  delivered to receiver
# 401  additional details: driver left the package un...  delivered to receiver
# 402  additional details:customer is saying that the...  delivered to receiver
#
#                Infraction2 First_Status  ...  Code TBA Deposit Code  \
# 0    delivered to receiver         True  ...  DLA9              NaN
# 1    delivered to receiver         True  ...  DHO1              NaN
# 2    delivered to receiver         True  ...  DDT2              NaN
# 3    delivered to receiver         True  ...  DEW8              NaN
# 4    delivered to receiver         True  ...  DCH1              NaN
# ..                     ...          ...  ...   ...              ...
# 398  delivered to receiver         True  ...  DOR1              NaN
# 399  delivered to receiver         True  ...  DRI1              NaN
# 400  delivered to receiver         True  ...  DBK1              NaN
# 401  delivered to receiver         True  ...  DSD2              NaN
# 402  delivered to receiver         True  ...  DDC3              NaN
#
#     Amazon Deposit Code Route Sequence sort_zone          packaging  \
# 0                   NaN          115.0   D-31.4D  No Packaging Need
# 1                   NaN           69.0   B-11.2A  No Packaging Need
# 2                   NaN           39.0    G-5.4G  No Packaging Need
# 3                   NaN           49.0    B-8.4A  No Packaging Need
# 4                   NaN           17.0   J-31.3C  No Packaging Need
# ..                  ...            ...       ...                ...
# 398                 NaN          158.0   A-34.1A  No Packaging Need
# 399                 NaN          155.0   G-15.3A  No Packaging Need
# 400                 NaN           61.0   B-26.3D  No Packaging Need
# 401                 NaN           90.0    A-3.1A  No Packaging Need
# 402                 NaN          141.0   D-48.2E  No Packaging Need
#
#      sellerName inductedCycle assignedCycle sideLineUntilTime
# 0           NaN       CYCLE_1       CYCLE_1               NaN
# 1           NaN       CYCLE_2       CYCLE_1               NaN
# 2           NaN       CYCLE_2       CYCLE_1               NaN
# 3           NaN       CYCLE_2       CYCLE_1               NaN
# 4           NaN       CYCLE_1       CYCLE_1               NaN
# ..          ...           ...           ...               ...
# 398         NaN       CYCLE_1       CYCLE_1               NaN
# 399         NaN       CYCLE_1       CYCLE_1               NaN
# 400         NaN       CYCLE_1       CYCLE_1               NaN
# 401         NaN       CYCLE_1       CYCLE_1               NaN
# 402         NaN       CYCLE_1       CYCLE_1               NaN
#
# [403 rows x 70 columns]
