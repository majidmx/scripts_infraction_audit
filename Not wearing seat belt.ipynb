# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('safety station - not wearing seat belt in delivery vehicle')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

word_list=('did not have seat belt','did not wear the seat belt','fasten your seat belt correctly','not properly wearing seat','not properly wearing their seat belt','not wearing his seat belt','not wearing seat belt','not wearing seatbelt','not wearing the seat belt','not wearing the seat-belt',
    'was not properly wearing their seat belt','wearing seat','with no seat-belt','with no seat-belt on','without a seat belt','without seat belt','without seat-belt','without seatbelt','without wearing a seat belt','without wearing seat belt',
    'without wearing seat-belt')


df['attribute'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df['Status']=df['attribute'].str.contains('with no seat-belt on|not wearing seat belt|without seat belt|did not have seat belt|not wearing seatbelt|without seat-belt|without wearing seat-belt|not properly wearing seat|not wearing his seat belt|not wearing the seat-belt|without seatbelt|fasten your seat belt correctly|was not properly wearing their seat belt|did not wear the seat belt|without wearing a seat belt|with no seat-belt|wearing seat|not properly wearing their seat belt|not wearing the seat belt|without wearing seat belt|without a seat belt|not wearing seatbelt')

df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_not_wearing_seatbelt.csv',index = False)


df
# Out:
#          ShortId details                                         root_cause  \
# 32    E102419960     NaN  t2 - safety station - not wearing seat belt in...
# 364   E102425451     NaN  t2 - safety station - not wearing seat belt in...
# 543   E102421430     NaN  t2 - safety station - not wearing seat belt in...
# 570   E102421436     NaN  t2 - safety station - not wearing seat belt in...
# 702   E102425831     NaN  t2 - safety station - not wearing seat belt in...
# 870   E102425455     NaN  t2 - safety station - not wearing seat belt in...
# 1095  E102422096     NaN  t2 - safety station - not wearing seat belt in...
# 1648  E102258748     NaN  t2 - safety station - not wearing seat belt in...
# 1666  E102254794     NaN  t2 - safety station - not wearing seat belt in...
# 1670  E102257541     NaN  t2 - safety station - not wearing seat belt in...
# 1693  E102256129     NaN  t2 - safety station - not wearing seat belt in...
# ...
