# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('behavioral - dumping packages inside lobby/front entrance')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()


df['Second_Status']=(df['Additional_Details_Data'].str.contains('drop|leaving|stash|left|deliver|dumped|leave|abandon|sent'))&(df['Additional_Details_Data'].str.contains('package|item|box| '))&(df['Additional_Details_Data'].str.contains('unsafe|outside|at|between|in|by|behind|of'))&(df['Additional_Details_Data'].str.contains('fence|stairwell on the first floor|apartment front door|apartment door|mailbox|mailboxes|leasing|front in the steps|lobby|entrance|building|bldg|front door of the apartment|front of elevator|front door of apartment|the door|store|gate|public hall|building|main door|steps|mailroom'))


df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Dumping packages inside lobby.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 19    305941175  Copy and paste the Amazon Flex delivery partne...
# 71    305955631  Delivery Station (Station Code, City, State): ...
# 311   306031742  Delivery Station (Station Code, City, State): ...
# 349   306059972  Delivery Station (Station Code, City, State): ...
# 363   306042157  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6697  306206025  Delivery Station (Station Code, City, State): ...
# 6727  306320608  Delivery Station (Station Code, City, State): ...
# 6734  306280824  Delivery Station (Station Code, City, State): ...
# 6785  306315319  Delivery Station (Station Code, City, State): ...
# 6790  306305152  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 19    t2 - behavioral - dumping packages inside lobb...  TBA849453462000
# ...
