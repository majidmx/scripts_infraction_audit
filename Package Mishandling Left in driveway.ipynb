# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('left in driveway')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()


df['Second_Status']=(df['Additional_Details_Data'].str.contains('leave|kept|put|drop|leaving|stash|left|deliver|dumped|leave|abandon|sent'))&(df['Additional_Details_Data'].str.contains('package|item|box| '))&(df['Additional_Details_Data'].str.contains('against|under|unsafe|outside|at|middle|between|in|by|behind|of|on'))&(df['Additional_Details_Data'].str.contains('car|dirt|windshield|roof of the truck|drive way|car tyre|two vehicles|garage|driveway|top of customer''s tire|under car|under car''s tyre|under customers tyre|behind the car|on car tyre|under customer''s tire|under the car|under car''s tire|parking lot|on customer''s husband''s car|under the car''s tyre|on the car trunk|left in a vulnerable state|outside the gate|on car|on top of a car|under customers truck|hood of the truck|truck tire|top of a car'))


df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_left in driveway.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 100   305984596  Delivery Station (Station Code, City, State): ...
# 153   305945181  Delivery Station (Station Code, City, State): ...
# 165   306050867  Delivery Station (Station Code, City, State): ...
# 252   305926383  Delivery Station (Station Code, City, State): ...
# 295   306042762  Delivery Station (Station Code, City, State): ...
# ...         ...                                                ...
# 6692  306281256  Delivery Station: DPX5     DSP : SAAM      Dat...
# 6747  306284013  Delivery Station: DSM1     DSP : ADCS      Dat...
# 6768  306284503  Delivery Station: DMC1     DSP : LARK      Dat...
# 6816  305793021  Delivery Station (Station Code, City, State): ...
# 6827  304947764  Delivery Station (Station Code, City, State): ...
#
#                                        root_cause              tid  \
# 100   t2 - package mishandling - left in driveway  TBA848684285000
# ...
