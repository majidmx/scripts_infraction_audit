# %%
 
    
    
    
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('dumping packages outside locker')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

# word_list_1=('left','dump','put','deliver')

# word_list_2=('left the package in the mail room without putting them in the locker','did not use the luxor locker','locker room floor','dump packages in the lobby','left outside of  locker','outside at the locker','instead of locker','outside of the hub','outside the hub','Not delivering to the locker','leave packages out of the HUB','left on the mailroom floor','left outside of the parcel pending locker','locker room unattended','next to the locker','on floor of locker','on the floor in parcel locker room','on top of the locker','out side the locker',
#     'outside a locker','outside locker','outside of locker','outside of the Delivery Locker','outside of the HUB','outside of the Luxer room','outside of the locker','outside the Amazon Hub','outside the Hub','outside the hub locker',
#     'outside the locker','unattended in the mail room')


# df['attribute_1'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list_1)),expand=False).str.lower()
# df['attribute_2'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list_2)),expand=False).str.lower()

# df['Status']=(df['Additional_Details_Data'].str.contains('left|dump|put|deliver'))&(df['Additional_Details_Data'].str.contains('trash|dumpster|garbage|recycling bin'))

df['Second_Status']=df['Additional_Details_Data'].str.contains('left the packages in the mail room instead of delivering the package in the locker|dumped all these packages in the luxer room|left by the door inside the luxer room|left the package lean up against the lockers|into the locker room without being secured in a locker|outside the package room instead of|dumped the packages without scanning them in the luxer lockers|left in front of the locker|left the packages out of the locker system|left the packages unsecured on the parcel room|left the package in the mail-room|packages are supposed to go into the hub lockers|dumped these packages at the amazon hub|dumped all packages on his route for this address in the locker room on the ground unattended|left the package in the mail room without putting them in the locker|did not use the luxor locker|locker room floor|dump packages in the lobby|left outside of  locker|outside at the locker|instead of locker|outside of the hub|outside the hub|outside of locker|outside the locker|left on the mailroom floor|next to the locker|out side the locker|outside a locker|outside of the locker|left outside of the parcel pending locker|outside of the Luxer room|Not delivering to the locker|outside the hub locker|on top of the locker|outside of the HUB|outside locker|leave packages out of the HUB|on floor of locker|outside the Amazon Hub|outside the Hub|outside of the Delivery Locker|on the floor in parcel locker room|locker room unattended|unattended in the mail room')



df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Dumping packages outside locker.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 448   306051265  Delivery Station (Station Code, City, State): ...
# 556   306048537  Delivery Station (Station Code, City, State): ...
# 621   305939659  Delivery Station (Station Code, City, State): ...
# 649   306009030  Delivery Station (Station Code, City, State): ...
# 864   306009247  Delivery Station (Station Code, City, State): ...
# 960   306053371  Delivery Station (Station Code, City, State): ...
# 1301  306513260  Delivery Station (Station Code, City, State): ...
# 1665  305627468  Delivery Station: DPH1     DSP: Same Day Deliv...
# 2503  305803436  Delivery Station (Station Code, City, State): ...
# 2702  306410897  Delivery Station (Station Code, City, State): ...
# 2912  306453736  Delivery Station (Station Code, City, State): ...
# 2916  306413049  Delivery Station (Station Code, City, State): ...
# 2966  306453194  Delivery Station (Station Code, City, State): ...
# ...
