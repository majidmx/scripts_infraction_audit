# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('scanned business closed')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()



df['Second_Status']=df['Additional_Details_Data'].str.contains('when the school was open|address is the post office and it was not closed but driver incorrectly scanned as business closed|business closed for an apartment|business was not closed when driver attempted the delivery|driver scanned as business closed when the business open|business and the front door was open|business is very open|business was closed but it was open|business closed while it''s opened at the time of delivery|business closed when it was open|waiting for this order|business is still open|business is open|business was open|business is not closed|there are people|building is open|business hours have been updated')



df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Scanned business closed.csv',columns=('ShortId','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)
df
# Out:
#         ShortId                                            details  \
# 382   306054504  Delivery Station (Station Code, City, State): ...
# 485   306052982  Delivery Station (Station Code, City, State): ...
# 505   305929623  Delivery Station (Station Code, City, State): ...
# 768   305936019  Delivery Station (Station Code, City, State): ...
# 980   306053509  ****Station submitted TTs will need to have da...
# 1255  306467268  Delivery Station (Station Code, City, State): ...
# 1358  306460587  Delivery Station: DTO3    Contact ID: AO85MXO5...
# 1734  305788225  Delivery Station (Station Code, City, State): ...
# 1816  305751356  Delivery Station (Station Code, City, State): ...
# 2339  305793897  Delivery Station (Station Code, City, State): ...
# 2391  305795317  Delivery Station: XOR5    Contact ID: A3B6ZVQS...
# 2997  306449044  Delivery Station (Station Code, City, State): ...
# 3041  306443119  Delivery Station (Station Code, City, State): ...
# 3045  306440919  Delivery Station (Station Code, City, State): ...
# 3227  306433735  Delivery Station (Station Code, City, State): ...
# 3495  305739767  Delivery Station (Station Code, City, State): ...
# 4933  305921950  Delivery Station (Station Code, City, State): ...
# 5532  306166077  Delivery Station (Station Code, City, State): ...
# 6076  306336705  Delivery Station (Station Code, City, State): ...
# 6331  306275429  Delivery Station (Station Code, City, State): ...
# 6378  306321347  Delivery Station (Station Code, City, State): ...
# 6711  306326057  Delivery Station (Station Code, City, State): ...
# 6748  306310888  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 382   t2 - behavioral - scanned business closed (bc)...  TBA853165568000
# 485   t2 - behavioral - scanned business closed (bc)...  TBA861280186000
# 505   t2 - behavioral - scanned business closed (bc)...  TBA850258857000
# 768   t2 - behavioral - scanned business closed (bc)...  TBA843962945000
# 980   t2 - behavioral - scanned business closed (bc)...              NaN
# 1255  t2 - behavioral - scanned business closed (bc)...  TBA876110847000
# 1358  t2 - behavioral - scanned business closed (bc)...              NaN
# 1734  t2 - behavioral - scanned business closed (bc)...  TBA841914674000
# 1816  t2 - behavioral - scanned business closed (bc)...  TBA828602240000
# 2339  t2 - behavioral - scanned business closed (bc)...  TBA843214269000
# 2391  t2 - behavioral - scanned business closed (bc)...              NaN
# 2997  t2 - behavioral - scanned business closed (bc)...  TBA881451666000
# 3041  t2 - behavioral - scanned business closed (bc)...  TBA881259142000
# 3045  t2 - behavioral - scanned business closed (bc)...  TBA880004506000
# 3227  t2 - behavioral - scanned business closed (bc)...  TBA879557074000
# 3495  t2 - behavioral - scanned business closed (bc)...  TBA836913833000
# 4933  t2 - behavioral - scanned business closed (bc)...  TBA852650180000
# 5532  t2 - behavioral - scanned business closed (bc)...  TBA851324841000
# 6076  t2 - behavioral - scanned business closed (bc)...  TBA868074289000
# 6331  t2 - behavioral - scanned business closed (bc)...  TBA864205432000
# 6378  t2 - behavioral - scanned business closed (bc)...  TBA873463977000
# 6711  t2 - behavioral - scanned business closed (bc)...  TBA869247305000
# 6748  t2 - behavioral - scanned business closed (bc)...  TBA872417190000
#
#                                                    Data  \
# 382   contact id: als2sn7qlxkgx\r\n\r\nduplicate tic...
# 485   **checked with scan co-ordinates and business ...
# 505   contact id: aqbhju6nqyq9n\r\n\r\nduplicate tic...
# 768   contact id:a2ypu97p44p62c\r\n\r\nattached pod ...
# 980                                   no data available
# 1255  contact id: a1calagdt3jqbv\r\n\r\nduplicate tt...
# 1358  additional details:driver marked the package a...
# 1734  contact id:a2nvhfla0ls48b\r\n\r\nattached pod ...
# 1816  contact id:   a2f7uparc2v8pu\r\n\r\nduplicate ...
# 2339  tier 2:da reputation - behavioral - scanned bu...
# 2391  contact id:a3jlzif8b64g9e\r\n\r\nduplicate tic...
# 2997  customer is saying that the business was open ...
# 3041  contact id: a2jb2jfuq4nd9f\r\n\r\nattached pod...
# 3045  \r\n\r\ncontact id:a19myt471jg595\r\n \r\n\r\n...
# 3227  contact id:a23x90v11i1czx\r\n\r\nduplicate tic...
# 3495  contact id:a358zbrcjnknhc\r\n\r\nduplicate tic...
# 4933  driver marked the package as business closed a...
# 5532  contact id: a116iepej1ppwe\r\n\r\nduplicate ti...
# 6076  contact id:a2uxona1pee5tp\r\n\r\nduplicate tic...
# 6331  contact id: a324g2htswanvx\r\n\r\nattached pod...
# 6378  contact id: a2jt8fogivdhae\r\n\r\nduplicate ti...
# 6711  contact id:ab4jgt9wuf9qv\r\n\r\nduplicate tick...
# 6748  contact id: a1dehht4ypt08z\r\n \r\nattached po...
#
#                                         Infraction_Data  \
# 382    da reputation - behavioral - scanned business...
# 485     da reputation - behavioral - scanned busines...
# 505    tier 2da reputation - behavioral - scanned bu...
# 768   da reputation - behavioral - scanned business ...
# 980                                              ailabl
# 1255   da reputation - behavioral - scanned business...
# 1358                                                NaN
# 1734  da reputation - behavioral - scanned business ...
# 1816   da reputation - behavioral - scanned business...
# 2339  da reputation - behavioral - scanned business ...
# 2391  tier 2da reputation - behavioral - scanned bus...
# 2997  da reputation - behavioral - scanned business ...
# 3041    da reputation - behavioral - scanned busines...
# 3045  da reputation - behavioral - scanned business ...
# 3227  da reputation - behavioral - scanned business ...
# 3495  tier 2da reputation - behavioral - scanned bus...
# 4933  da reputation - behavioral - scanned business ...
# 5532  da reputation - behavioral - scanned business ...
# 6076  da reputation - behavioral - scanned business ...
# 6331   da reputation - behavioral - scanned business...
# 6378   tier 2da reputation - behavioral - scanned bu...
# 6711  tier 2 da reputation - behavioral - scanned bu...
# 6748   da reputation - behavioral - scanned business...
#
#                                 Additional_Details_Data  \
# 382   additional details: driver scanned as business...
# 485   additional details: driver marked business clo...
# 505   additional details: driver marked the package ...
# 768   additional details:the business was open and d...
# 980                                                 NaN
# 1255  additional details: the driver marked the pack...
# 1358  additional details:driver marked the package a...
# 1734  additional details:customer complaining that t...
# 1816  additional details: customer reached out compl...
# 2339  additional details:business was open but the d...
# 2391  additional details:the customer says the busin...
# 2997  additional details: customer is saying that th...
# 3041  additional details: the customer was waiting a...
# 3045  additional details:driver scanned the package ...
# 3227  additional details:customer complaining that d...
# 3495  additional details:the mailroom where the pack...
# 4933  additional details:customer stated that the dr...
# 5532  additional details:customer states delivery ad...
# 6076  additional details:customer saying business wa...
# 6331  additional details: package was scanned as bc ...
# 6378  additional details: marked business closed whe...
# 6711  additional details:customer stated that the dr...
# 6748  additional details: customer complained that t...
#
#                                              Infraction  \
# 382   da reputation - behavioral - scanned business ...
# 485   da reputation - behavioral - scanned business ...
# 505   tier 2da reputation - behavioral - scanned bus...
# 768   da reputation - behavioral - scanned business ...
# 980                                              ailabl
# 1255  da reputation - behavioral - scanned business ...
# 1358                                                NaN
# 1734  da reputation - behavioral - scanned business ...
# 1816  da reputation - behavioral - scanned business ...
# 2339  da reputation - behavioral - scanned business ...
# 2391  tier 2da reputation - behavioral - scanned bus...
# 2997  da reputation - behavioral - scanned business ...
# 3041  da reputation - behavioral - scanned business ...
# 3045  da reputation - behavioral - scanned business ...
# 3227  da reputation - behavioral - scanned business ...
# 3495  tier 2da reputation - behavioral - scanned bus...
# 4933  da reputation - behavioral - scanned business ...
# 5532  da reputation - behavioral - scanned business ...
# 6076  da reputation - behavioral - scanned business ...
# 6331  da reputation - behavioral - scanned business ...
# 6378  tier 2da reputation - behavioral - scanned bus...
# 6711  tier 2 da reputation - behavioral - scanned bu...
# 6748  da reputation - behavioral - scanned business ...
#
#                                      Additional Details      Infraction1  \
# 382   Additional Details: Driver scanned as Business...  business closed
# 485   Additional Details: driver marked business clo...  business closed
# 505   Additional Details: Driver marked the package ...  business closed
# 768   Additional Details:the business was open and d...  business closed
# 980                                                 NaN  business closed
# 1255  Additional Details: The driver marked the pack...  business closed
# 1358  Additional Details:Driver marked the package a...  business closed
# 1734  Additional Details:Customer complaining that t...  business closed
# 1816  Additional Details: Customer reached out compl...  business closed
# 2339  Additional Details:Business was open but the d...  business closed
# 2391  Additional Details:The customer says the busin...  business closed
# 2997  Additional Details: Customer is saying that th...  business closed
# 3041  Additional Details: The customer was waiting a...  business closed
# 3045  Additional Details:Driver scanned the package ...  business closed
# 3227  Additional Details:Customer complaining that D...  business closed
# 3495  Additional Details:The mailroom where the pack...  business closed
# 4933  Additional Details:Customer stated that the dr...  business closed
# 5532  Additional Details:Customer states delivery ad...  business closed
# 6076  Additional Details:customer saying business wa...  business closed
# 6331  Additional Details: Package was scanned as BC ...  business closed
# 6378  Additional Details: Marked business closed whe...  business closed
# 6711  Additional Details:Customer stated that the dr...  business closed
# 6748  Additional Details: Customer complained that t...  business closed
#
#           Infraction2  First_Status Second_Status
# 382   business closed          True          True
# 485   business closed          True          True
# 505   business closed          True         False
# 768   business closed          True          True
# 980               NaN         False           NaN
# 1255  business closed          True          True
# 1358              NaN         False          True
# 1734  business closed          True          True
# 1816  business closed          True          True
# 2339  business closed          True          True
# 2391  business closed          True          True
# 2997  business closed          True          True
# 3041  business closed          True          True
# 3045  business closed          True          True
# 3227  business closed          True          True
# 3495  business closed          True          True
# 4933  business closed          True          True
# 5532  business closed          True          True
# 6076  business closed          True          True
# 6331  business closed          True          True
# 6378  business closed          True          True
# 6711  business closed          True          True
# 6748  business closed          True         False
