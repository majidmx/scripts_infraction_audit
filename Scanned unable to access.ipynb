# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('scanned unable to access')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()



df['Status']=df['Additional_Details_Data'].str.contains('nothing to block access to the home|residential address|residential properties|falsely marked packages uta|customer provide driver with code driver scan customer package as unable to access|customer mentioned there is no dog, fence, gate nor construction going|no access code in the address|no access needed|there is no access code|there are no access codes|address is residential|never attempted to deliver|access is not needed|no access code required|no access code needed|effort was not made|unlocked door|no access barrier|notes has access code|provided instruction|not need any access code|door is always open|no access required|no access problem|no access code that is needed|no access code is required|residential home|no access code to front door')



df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_Scanned unable to access.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)
df
# Out:
# C:\Users\majidmm\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#         ShortId                                            details  \
# 74    306035141  Delivery Station (Station Code, City, State): ...
# 502   305939442  Delivery Station (Station Code, City, State): ...
# 589   306039126  Delivery Station (Station Code, City, State): ...
# 629   305938771  Delivery Station (Station Code, City, State): ...
# 1185  306468825  Delivery Station (Station Code, City, State): ...
# 1427  306475543  Delivery Station (Station Code, City, State): ...
# 1552  306458296  Delivery Station (Station Code, City, State): ...
# 1592  306460573  Delivery Station (Station Code, City, State): ...
# 2654  306425621  Delivery Station (Station Code, City, State): ...
# 2830  306359271  Delivery Station (Station Code, City, State): ...
# 3708  305739972  Delivery Station (Station Code, City, State): ...
# 4043  305739367  Delivery Station (Station Code, City, State): ...
# 4316  305919011  ****Station submitted TTs will need to have da...
# 4406  305809285  Delivery Station (Station Code, City, State): ...
# 4631  305907158  ****Station submitted TTs will need to have da...
# 4884  305812564  Delivery Station (Station Code, City, State): ...
# 4955  305918903  ****Station submitted TTs will need to have da...
# 6680  306327159  Delivery Station (Station Code, City, State): ...
#
#                                              root_cause              tid  \
# 74    t2 - behavioral - scanned unable to access (ut...  TBA856203273000
# 502   t2 - behavioral - scanned unable to access (ut...  TBA842896025000
# 589   t2 - behavioral - scanned unable to access (ut...  TBA856687077000
# 629   t2 - behavioral - scanned unable to access (ut...  TBA848817526000
# 1185  t2 - behavioral - scanned unable to access (ut...  TBA876035444000
# 1427  t2 - behavioral - scanned unable to access (ut...  TBA881938804000
# 1552  t2 - behavioral - scanned unable to access (ut...  TBA879856493000
# 1592  t2 - behavioral - scanned unable to access (ut...  TBA877985898000
# 2654  t2 - behavioral - scanned unable to access (ut...  TBA875377858000
# 2830  t2 - behavioral - scanned unable to access (ut...  TBA881586872000
# 3708  t2 - behavioral - scanned unable to access (ut...  TBA841445656000
# 4043  t2 - behavioral - scanned unable to access (ut...  TBA839775629000
# 4316  t2 - behavioral - scanned unable to access (ut...  TBA845120729000
# 4406  t2 - behavioral - scanned unable to access (ut...  TBA846455541000
# 4631  t2 - behavioral - scanned unable to access (ut...  TBA844398466000
# 4884  t2 - behavioral - scanned unable to access (ut...  TBA847852516000
# 4955  t2 - behavioral - scanned unable to access (ut...  TBA848488835000
# 6680  t2 - behavioral - scanned unable to access (ut...  TBA868160944000
#
#                                                    Data  \
# 74    contact id:a1gl9cwutlanth\r\n\r\nduplicate tic...
# 502   contact id: a33jmjwjzje75u\r\n\r\nattached pod...
# 589   contact id:aixf63iw1kqq7\r\n\r\nduplicate tick...
# 629   contact id: a347szputoctws\r\n\r\nduplicate ti...
# 1185  contact id: ai482cmr8x7c\r\n\r\nduplicate tick...
# 1427                                  no data available
# 1552  contact id:a10s4dksxaq0jz\r\n\r\nduplicate tic...
# 1592  contact id: a1wf0jb9dl36w2\r\n\r\nduplicate ti...
# 2654  as per the contact information a49h2pwr3vs80, ...
# 2830  contact id: a2nk53b9h327nj\r\n\r\nduplicate ti...
# 3708  contact id:a12uc53pnh3c2e\r\n\r\nduplicate tic...
# 4043  tier 2:da reputation \u2013 behavioral \u2013 ...
# 4316  no tbas attached to this infraction, also plea...
# 4406  contact id:a2q0vuvn6ywnng\r\n\r\nattached pod ...
# 4631  can you provide more insight on this infractio...
# 4884  contact id:a3j62niep874me\r\n\r\nattached pod ...
# 4955  can you provide more insight on this infractio...
# 6680  contact id: a17gpnnih1cvz5\r\n\r\nduplicate ti...
#
#                                         Infraction_Data  \
# 74    da reputation \u2013 behavioral \u2013 scanned...
# 502    da reputation \u2013 behavioral \u2013 scanne...
# 589   tier 2da reputation \u2013 behavioral \u2013 s...
# 629    da reputation \u2013 behavioral \u2013 scanne...
# 1185  da reputation \u2013 behavioral \u2013 scanned...
# 1427                                             ailabl
# 1552  da reputation \u2013 behavioral \u2013 scanned...
# 1592  da reputation \u2013 behavioral \u2013 scanned...
# 2654   da reputation \u2013 behavioral \u2013 scanne...
# 2830   da reputation \u2013 behavioral \u2013 scanne...
# 3708  da reputation \u2013 behavioral \u2013 scanned...
# 4043  da reputation \u2013 behavioral \u2013 scanned...
# 4316  tier 2da reputation \u2013 behavioral \u2013 s...
# 4406  da reputation \u2013 behavioral \u2013 scanned...
# 4631  tier 2da reputation \u2013 behavioral \u2013 s...
# 4884  da reputation \u2013 behavioral \u2013 scanned...
# 4955    da reputation \u2013 behavioral \u2013 scann...
# 6680   da reputation \u2013 behavioral \u2013 scanne...
#
#                                 Additional_Details_Data  \
# 74    additional details: customer states no access ...
# 502   additional details: the driver did not follow ...
# 589   additional details:the customer says there are...
# 629   additional details: the driver who marked his ...
# 1185  additional details: the customer is saying tha...
# 1427                                                NaN
# 1552  additional details:da scanned package as uta w...
# 1592  additional details: there is no access code in...
# 2654  additional details: customer's package was sca...
# 2830  additional details: driver scanned as uta at t...
# 3708  additional details:driver marked unable to acc...
# 4043  additional details:driver call customer for ac...
# 4316  additional details:customer complains that dri...
# 4406  additional details:the driver scan the package...
# 4631  additional details:driver falsely marked packa...
# 4884  additional details:customer is upset that the ...
# 4955  additional details: driver falsely marked pack...
# 6680  additional details: the customer lives down a ...
#
#                                              Infraction  \
# 74    da reputation \u2013 behavioral \u2013 scanned...
# 502   da reputation \u2013 behavioral \u2013 scanned...
# 589   tier 2da reputation \u2013 behavioral \u2013 s...
# 629   da reputation \u2013 behavioral \u2013 scanned...
# 1185  da reputation \u2013 behavioral \u2013 scanned...
# 1427                                             ailabl
# 1552  da reputation \u2013 behavioral \u2013 scanned...
# 1592  da reputation \u2013 behavioral \u2013 scanned...
# 2654  da reputation \u2013 behavioral \u2013 scanned...
# 2830  da reputation \u2013 behavioral \u2013 scanned...
# 3708  da reputation \u2013 behavioral \u2013 scanned...
# 4043  da reputation \u2013 behavioral \u2013 scanned...
# 4316  tier 2da reputation \u2013 behavioral \u2013 s...
# 4406  da reputation \u2013 behavioral \u2013 scanned...
# 4631  tier 2da reputation \u2013 behavioral \u2013 s...
# 4884  da reputation \u2013 behavioral \u2013 scanned...
# 4955  da reputation \u2013 behavioral \u2013 scanned...
# 6680  da reputation \u2013 behavioral \u2013 scanned...
#
#                                      Additional Details       Infraction1  \
# 74    Additional Details: Customer states no access ...  unable to access
# 502   Additional Details: The driver did not follow ...  unable to access
# 589   Additional Details:The customer says there are...  unable to access
# 629   Additional Details: The driver who marked his ...  unable to access
# 1185  Additional Details: The customer is saying tha...  unable to access
# 1427                                                NaN  unable to access
# 1552  Additional Details:DA scanned package as UTA w...  unable to access
# 1592  Additional Details: There is no access code in...  unable to access
# 2654  Additional Details: Customer's package was sca...  unable to access
# 2830  Additional Details: Driver scanned as UTA at t...  unable to access
# 3708  Additional Details:Driver marked unable to acc...  unable to access
# 4043  Additional Details:Driver call customer for ac...  unable to access
# 4316  Additional Details:Customer complains that dri...  unable to access
# 4406  Additional Details:The driver scan the package...  unable to access
# 4631  Additional Details:Driver falsely marked packa...  unable to access
# 4884  Additional Details:Customer is upset that the ...  unable to access
# 4955  Additional Details: Driver falsely marked pack...  unable to access
# 6680  Additional Details: The customer lives down a ...  unable to access
#
#            Infraction2  First_Status Status
# 74    unable to access          True   True
# 502   unable to access          True  False
# 589   unable to access          True  False
# 629   unable to access          True   True
# 1185  unable to access          True   True
# 1427               NaN         False    NaN
# 1552  unable to access          True   True
# 1592  unable to access          True   True
# 2654  unable to access          True   True
# 2830  unable to access          True   True
# 3708  unable to access          True   True
# 4043  unable to access          True   True
# 4316  unable to access          True   True
# 4406  unable to access          True  False
# 4631  unable to access          True   True
# 4884  unable to access          True   True
# 4955  unable to access          True   True
# 6680  unable to access          True   True
