# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\majidmm\Documents\MTI\verified_allcol.csv')
df=df[df['root_cause'].str.contains('left in lawn')==True]

df['Data']=df['Data'].str.lower() 
df['Infraction_Data']=df['Infraction_Data'].str.lower() 
df['Additional_Details_Data']=df['Additional_Details_Data'].str.lower()

word_list=('should not place the packages in the rain','under the tree','under the mailbox','outside his gate','front of mailbox','in the alley','by the mail box','next to the mailbox','left in the plants','walk way','near mailbox','under the mailbox','left the package in the garden','in the tree','bush','flower bed','grass','in leaves','lawn','left it in the front gate','left package at gate','on planter','on the ground','pond',
    'river bed','side walk','sidewalk','snow','walkway','water','yard')


df['attribute'] = df.Additional_Details_Data.str.extract('({})'.format('|'.join(word_list)), 
                        expand=False).str.lower()

df['Second_Status']=df['attribute'].str.contains('should not place the packages in the rain|under the tree|under the mailbox|outside his gate|front of mailbox|in the alley|by the mail box|next to the mailbox|left in the plants|walk way|near mailbox|under the mailbox|left the package in the garden|in the tree|in leaves|on planter|lawn|pond|sidewalk|grass|walkway|yard|side walk|water|bush|flower bed|left package at gate|left it in the front gate|river bed|on the ground|snow')

df.to_csv(r'C:\Users\majidmm\Documents\MTI\verified_left_in_lawn.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)


df
# Out:
#         ShortId                                            details  \
# 96    305992283  Delivery Station (Station Code, City, State): ...
# 211   306033196  Delivery Station (Station Code, City, State): ...
# 507   306004675  Delivery Station (Station Code, City, State): ...
# 572   305945404  Delivery Station (Station Code, City, State): ...
# 773   305944363  Delivery Station (Station Code, City, State): ...
# 972   305935896  Delivery Station (Station Code, City, State): ...
# 984   306042051  Delivery Station (Station Code, City, State): ...
# 1398  306462501  Delivery Station (Station Code, City, State): ...
# 2128  305794378  Delivery Station (Station Code, City, State): ...
# 2140  305792166  Delivery Station (Station Code, City, State): ...
# 2188  305758136  Delivery Station (Station Code, City, State): ...
# 2280  305793415  Delivery Station (Station Code, City, State): ...
# 2331  305805307  Delivery Station (Station Code, City, State): ...
# ...
