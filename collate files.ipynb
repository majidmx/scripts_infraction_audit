# %%
import pandas as pd

df1=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Delivering in or on a USPS mail box.csv')
df2=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Dumping packages inside lobby.csv')
df3=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Dumping packages outside locker.csv')
df4=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_left in driveway.csv')
df5=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_left_in_lawn.csv')
df6=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_near garbage or recycling.csv')
df7=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Package Mishandling - Throwing.csv')
df8=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_property_damage.csv')
df9=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Scanned business closed.csv')
df10=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Scanned unable to access.csv')
df11=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_unattended_in_mailroom.csv')
df12=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Unauthorized entry of entryway garage foyer.csv')
df13=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Unprofessional behavior towards a customer.csv')
df14=pd.read_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\verified_Unsafe driving behavior.csv')




df = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], ignore_index=True)
df.to_csv(r'C:\Users\majidmm\Documents\MTI and RC\SAMPLE AUDIT\WEEK_07_2020\Collated.csv',columns=('ShortId','tid','root_cause','Infraction','Additional Details','First_Status','Second_Status'),index = False)
df
# Out:
# C:\Users\majidmm\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                      Additional Details  First_Status  \
# 0     Additional Details:Driver delivered the packag...          True
# 1     Additional Details:The package from AMZL shows...          True
# 2     Additional Details:driver tagged the parcel as...          True
# 3     Additional Details: Customer complained driver...          True
# 4     Additional Details: cx got the notification my...          True
# ...                                                 ...           ...
# 1104  Additional Details: please inform the driver n...         False
# ...
